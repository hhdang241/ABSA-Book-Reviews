# %%
# !pip install -q gensim
# !pip install -q gdown

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Dropout, Concatenate, LSTM, Embedding, Bidirectional, GRU, SpatialDropout1D, Conv1D, GlobalAveragePooling1D, GlobalMaxPooling1D
from tensorflow.keras.initializers import Constant
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.losses import BinaryCrossentropy, CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, classification_report, f1_score
from sklearn.utils.class_weight import compute_class_weight

import transformers
from transformers import AutoTokenizer, AutoModel

import torch
import matplotlib.pyplot as plt
import gensim
import gdown
# Out:
# 2024-07-14 06:07:55.351312: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-14 06:07:55.351487: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-14 06:07:55.504966: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !sudo apt-get update
# !sudo apt-get install openjdk-11-jdk-headless -qq > /dev/null
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1581 B]
# Get:2 https://packages.cloud.google.com/apt gcsfuse-focal InRelease [1225 B]
# Get:3 https://packages.cloud.google.com/apt cloud-sdk InRelease [1616 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1556 kB]
# Get:5 https://packages.cloud.google.com/apt google-fast-socket InRelease [1071 B]
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:7 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [3745 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1530 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [3895 kB]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3776 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1245 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [4245 kB]
# Fetched 20.3 MB in 4s (5450 kB/s)
# Reading package lists... Done

# %%
# !git clone https://github.com/hhdang241/kltn
# Out:
# Cloning into 'kltn'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 104 (delta 45), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (104/104), 3.12 MiB | 2.61 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %% [markdown]
# # Accelerator

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# Found GPU at: /device:GPU:0
# 'Tesla P100-PCIE-16GB'

# %% [markdown]
# # Import & Preprocess datasets

# %%
TRAIN_PATH = 'kltn/Data/Sách/book_reviews_train.csv'
VAL_PATH = 'kltn/Data/Sách/book_reviews_val.csv'
TEST_PATH = 'kltn/Data/Sách/book_reviews_test.csv'
MAX_LENGTH = 128
BATCH_SIZE = 32

# %%
df_train = pd.read_csv(TRAIN_PATH, encoding='utf8')
df_val = pd.read_csv(VAL_PATH, encoding='utf8')
df_test = pd.read_csv(TEST_PATH, encoding='utf8')

# %%
df_train.head(10)
# Out:
#                                               review  content_related  author  \
# 0  là tuổi_thơ Năm nay ra tập kỷ_niệm nên mình nổ...                0       0
# 1             Đóng_gói hàng rất cẩn bọc sách rất đẹp                0       0
# 2                                      rất đáng tiền                0       0
# 3            giao hang nhanh san pham dung nhu mo ta                0       0
# 4  Đóng_gói kỹ sách đẹp dù bị cấn gáy và trầy 1 t...                1       0
# 5  Mình đặt 2 cuốn hãng luật và Xứ_Cát vào buổi s...                0       0
# 6  Sách không còn gì để bàn_cãi rồi giao hàng đỉn...                0       0
# 7  Sách to và dày hơn mình nghĩ Dịch_thuật chất_l...                1       1
# 8  Sách in tốt Bìa đẹp Tuy là bìa mềm mà khổ sách...                1       0
# 9  Nội_dung sách hay đọc rất cuốn và buồn để lại ...                1       0
#
#    quality_and_appearance  manufacture_and_distribution  \
# 0                       0                             0
# 1                       1                             0
# 2                       0                             0
# 3                       0                             0
# 4                       1                             0
# 5                       1                             0
# 6                       1                             0
# 7                       3                             0
# 8                       1                             0
# 9                       2                             0
#
#    packaging_and_delivery  price_and_preference  customer_service  \
# 0                       0                     1                 0
# 1                       1                     0                 0
# 2                       0                     1                 0
# 3                       1                     0                 0
# 4                       1                     0                 0
# 5                       1                     0                 0
# 6                       1                     0                 0
# 7                       0                     1                 0
# 8                       0                     0                 0
# 9                       3                     0                 0
#
#    overall_experience
# 0                   0
# 1                   0
# 2                   0
# 3                   1
# 4                   0
# 5                   1
# 6                   1
# 7                   0
# 8                   0
# 9                   0

# %% [markdown]
# # Get labels

# %%
def get_label_aspect(df):
    
    label_aspect = df.iloc[:, 1:].values

    # Replace -1 with 0 and other values with 1
    label_aspect[label_aspect == -1] = 0
    label_aspect[label_aspect != 0] = 1

    return label_aspect


def get_label_sentiment(df):
    
    # detect sentiment cua tung aspect
    content_related = df.content_related
    author = df.author
    quality_and_appearance = df.quality_and_appearance
    manufacture_and_distribution = df.manufacture_and_distribution
    packaging_and_delivery = df.packaging_and_delivery
    price_and_preference = df.price_and_preference
    customer_service = df.customer_service
    overall_experience = df.overall_experience

    sentiment_dict = {
        'content_related': content_related, 
        'author': author,
        'quality_and_appearance': quality_and_appearance,
        'manufacture_and_distribution': manufacture_and_distribution,
        'packaging_and_delivery': packaging_and_delivery,
        'price_and_preference': price_and_preference,
        'customer_service': customer_service, 
        'overall_experience': overall_experience
    }
    
    df_sentiment = pd.DataFrame(sentiment_dict)

    return df_sentiment


def get_aspect_sentiment_label(label_dict, num_classes):
    content_related = to_categorical(label_dict['content_related'], num_classes=num_classes)
    author = to_categorical(label_dict['author'], num_classes=num_classes)
    quality_and_appearance = to_categorical(label_dict['quality_and_appearance'], num_classes=num_classes)
    manufacture_and_distribution = to_categorical(label_dict['manufacture_and_distribution'], num_classes=num_classes)
    packaging_and_delivery = to_categorical(label_dict['packaging_and_delivery'], num_classes=num_classes)
    price_and_preference = to_categorical(label_dict['price_and_preference'], num_classes=num_classes)
    customer_service = to_categorical(label_dict['customer_service'], num_classes=num_classes)
    overall_experience = to_categorical(label_dict['overall_experience'], num_classes=num_classes)
    
    return (
        content_related,
        author,
        quality_and_appearance,
        manufacture_and_distribution,
        packaging_and_delivery,
        price_and_preference,
        customer_service,
        overall_experience
    )

# %%
label_aspect_train = get_label_aspect(df_train)
label_aspect_val = get_label_aspect(df_val)
label_aspect_test = get_label_aspect(df_test)

# %%
label_sentiment_train = get_label_sentiment(df_train)
label_sentiment_val = get_label_sentiment(df_val)
label_sentiment_test = get_label_sentiment(df_test)

# %%
label_aspect_train.shape
# Out:
# (5415, 8)

# %%
label_sentiment_train.shape
# Out:
# (5415, 8)

# %%
content_related_train, author_train, quality_and_appearance_train, manufacture_and_distribution_train, packaging_and_delivery_train, price_and_preference_train, customer_service_train, overall_experience_train = get_aspect_sentiment_label(label_sentiment_train, num_classes=4)

content_related_val, author_val, quality_and_appearance_val, manufacture_and_distribution_val, packaging_and_delivery_val, price_and_preference_val, customer_service_val, overall_experience_val = get_aspect_sentiment_label(label_sentiment_val, num_classes=4)

content_related_test, author_test, quality_and_appearance_test, manufacture_and_distribution_test, packaging_and_delivery_test, price_and_preference_test, customer_service_test, overall_experience_test = get_aspect_sentiment_label(label_sentiment_test, num_classes=4)

# %% [markdown]
# # Create word embedding matrix

# %%
cmt_train = df_train['review'].astype('str').to_list()
cmt_val = df_val['review'].astype('str').to_list()
cmt_test = df_test['review'].astype('str').to_list()

# %%
# !gdown 1RC0HFzPvO3PslYRXzDMCiIA7q_Rb15dB
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1RC0HFzPvO3PslYRXzDMCiIA7q_Rb15dB
# From (redirected): https://drive.google.com/uc?id=1RC0HFzPvO3PslYRXzDMCiIA7q_Rb15dB&confirm=t&uuid=0bbe037f-0064-4447-a9b7-e09c7a6ffbb3
# To: /kaggle/working/elmo_embeddings_large.txt
# 100%|███████████████████████████████████████| 1.94G/1.94G [00:13<00:00, 144MB/s]

# %%
w2c_model = gensim.models.KeyedVectors.load_word2vec_format('elmo_embeddings_large.txt', binary = False)

# %%
vocab =  w2c_model.key_to_index
word_vec_dict = {}

for word in vocab:
    word_vec_dict[word] = w2c_model.get_vector(word)

# %%
tok = Tokenizer(filters='')
tok.fit_on_texts(cmt_train)
tok.fit_on_texts(cmt_val)
tok.fit_on_texts(cmt_test)

vocab_size = len(tok.word_index) + 1

tokenized_train = tok.texts_to_sequences(cmt_train)
tokenized_val = tok.texts_to_sequences(cmt_val)
tokenized_test = tok.texts_to_sequences(cmt_test)

embedding_dim = 1024

padded_train = pad_sequences(tokenized_train, padding = 'post', maxlen=MAX_LENGTH)
padded_val = pad_sequences(tokenized_val, padding = 'post', maxlen=MAX_LENGTH)
padded_test = pad_sequences(tokenized_test, padding = 'post', maxlen=MAX_LENGTH)

# %%
padded_train
# Out:
# array([[   9,  491,  251, ...,    0,    0,    0],
#        [  36,    5,    8, ...,    0,    0,    0],
#        [   8,  128,  179, ...,    0,    0,    0],
#        ...,
#        [1161,   15,  505, ...,    0,    0,    0],
#        [   1,   13,  341, ...,    0,    0,    0],
#        [   1,   13,  668, ...,    0,    0,    0]], dtype=int32)

# %%
padded_train.shape
# Out:
# (5415, 128)

# %%
embedding_matrix = np.zeros(shape=(vocab_size, embedding_dim))

for word, i in tok.word_index.items():
    embedding_vector = word_vec_dict.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
embedding_matrix.shape
# Out:
# (7504, 1024)

# %% [markdown]
# # Model building

# %% [markdown]
# ## BiLSTM

# %%
with device:

    # Number of labels
    num_label = 8

    # Input layer
    inputs = Input(shape=(MAX_LENGTH,))

    # Embedding layer
    embed = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        embeddings_initializer=Constant(embedding_matrix),
        trainable=True
    )(inputs)
    
    lstm = Bidirectional(LSTM(units = 200, activation = 'tanh'))(embed)
    dense2 = Dense(units = 128, activation = 'relu')(lstm)
    dropout1 = Dropout(rate = 0.2)(dense2)
    dense3 = Dense(units = 64, activation = 'relu')(dropout1)
    dense4 = Dense(units = 32, activation = 'relu')(dense3)

    # Output layers
    out_aspect = Dense(units=num_label, activation='sigmoid', name='out_aspect')(dense4)

    # Helper function to concatenate aspect and dense4 output
    def create_output_layer(aspect_index, name):
        aspect_slice = out_aspect[:, aspect_index:aspect_index + 1]
        concatenated = tf.keras.layers.Concatenate(axis=1)([aspect_slice, dense4])
        output_layer = Dense(units=4, activation='softmax', name=name)(concatenated)
        return output_layer

    out_content_related = create_output_layer(0, 'out_content_related')
    out_author = create_output_layer(1, 'out_author')
    out_quality_and_appearance = create_output_layer(2, 'out_quality_and_appearance')
    out_manufacture_and_distribution = create_output_layer(3, 'out_manufacture_and_distribution')
    out_packaging_and_delivery = create_output_layer(4, 'out_packaging_and_delivery')
    out_price_and_preference = create_output_layer(5, 'out_price_and_preference')
    out_customer_service = create_output_layer(6, 'out_customer_service')
    out_overall_experience = create_output_layer(7, 'out_overall_experience')

    # Define the model
    model = Model(
        inputs=inputs,
        outputs=[
            out_aspect, out_content_related, out_author, out_quality_and_appearance,
            out_manufacture_and_distribution, out_packaging_and_delivery,
            out_price_and_preference, out_customer_service, out_overall_experience
        ]
    )
    
    losses = {
        "out_aspect": "binary_crossentropy",
        "out_content_related": "categorical_crossentropy",
        "out_author": "categorical_crossentropy",
        "out_quality_and_appearance": "categorical_crossentropy",
        "out_manufacture_and_distribution": "categorical_crossentropy",
        "out_packaging_and_delivery": "categorical_crossentropy",
        "out_price_and_preference": "categorical_crossentropy",
        "out_customer_service": "categorical_crossentropy",
        "out_overall_experience": "categorical_crossentropy"
    }
 
    metrics={
        "out_aspect": 'accuracy',
        "out_content_related": 'accuracy',
        "out_author": 'accuracy',
        "out_quality_and_appearance": 'accuracy',
        "out_manufacture_and_distribution": 'accuracy',
        "out_packaging_and_delivery": 'accuracy',
        "out_price_and_preference": 'accuracy',
        "out_customer_service": 'accuracy',
        "out_overall_experience": 'accuracy'
    }
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=losses,
        metrics=metrics
    )

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 128, 1024) │  7,684,096 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 400)       │  1,960,000 │ embedding[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     51,328 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 32)        │      2,080 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_aspect (Dense)  │ (None, 8)         │        264 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 1)         │          0 │ out_aspect[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_4          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_5          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_6          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_7          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 33)        │          0 │ get_item[0][0],   │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 33)        │          0 │ get_item_1[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 33)        │          0 │ get_item_2[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 33)        │          0 │ get_item_3[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 33)        │          0 │ get_item_4[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 33)        │          0 │ get_item_5[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 33)        │          0 │ get_item_6[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 33)        │          0 │ get_item_7[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_content_related │ (None, 4)         │        136 │ concatenate[0][0] │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_author (Dense)  │ (None, 4)         │        136 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_quality_and_ap… │ (None, 4)         │        136 │ concatenate_2[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_manufacture_an… │ (None, 4)         │        136 │ concatenate_3[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_packaging_and_… │ (None, 4)         │        136 │ concatenate_4[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_price_and_pref… │ (None, 4)         │        136 │ concatenate_5[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_customer_servi… │ (None, 4)         │        136 │ concatenate_6[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_overall_experi… │ (None, 4)         │        136 │ concatenate_7[0]… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,707,112 (37.03 MB)
#  Trainable params: 9,707,112 (37.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit model
history = model.fit(
    x=padded_train,
    y={
        "out_aspect": label_aspect_train,
        "out_content_related": content_related_train,
        "out_author": author_train,
        "out_quality_and_appearance": quality_and_appearance_train,
        "out_manufacture_and_distribution": manufacture_and_distribution_train,
        "out_packaging_and_delivery": packaging_and_delivery_train,
        "out_price_and_preference": price_and_preference_train,
        "out_customer_service": customer_service_train,
        "out_overall_experience": overall_experience_train
    },
    validation_data=(
        padded_val,
        {
            "out_aspect": label_aspect_val,
            "out_content_related": content_related_val,
            "out_author": author_val,
            "out_quality_and_appearance": quality_and_appearance_val,
            "out_manufacture_and_distribution": manufacture_and_distribution_val,
            "out_packaging_and_delivery": packaging_and_delivery_val,
            "out_price_and_preference": price_and_preference_val,
            "out_customer_service": customer_service_val,
            "out_overall_experience": overall_experience_val
        }
    ),
    batch_size=BATCH_SIZE,
    epochs=100,
    callbacks=EarlyStopping(
        monitor='val_loss', 
        patience=3,
        min_delta=0.001,
        mode='min',
        verbose=1
    ),
    verbose=1
)
# Out:
# Epoch 1/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 17s 44ms/step - loss: 9.0672 - out_aspect_accuracy: 0.0292 - out_author_accuracy: 0.7918 - out_content_related_accuracy: 0.6617 - out_customer_service_accuracy: 0.5876 - out_manufacture_and_distribution_accuracy: 0.8886 - out_overall_experience_accuracy: 0.3522 - out_packaging_and_delivery_accuracy: 0.5670 - out_price_and_preference_accuracy: 0.2407 - out_quality_and_appearance_accuracy: 0.3657 - val_loss: 5.5451 - val_out_aspect_accuracy: 0.0766 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7312 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7124 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5043
# Epoch 2/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 5.3233 - out_aspect_accuracy: 0.1613 - out_author_accuracy: 0.9568 - out_content_related_accuracy: 0.7464 - out_customer_service_accuracy: 0.9723 - out_manufacture_and_distribution_accuracy: 0.9888 - out_overall_experience_accuracy: 0.7095 - out_packaging_and_delivery_accuracy: 0.7162 - out_price_and_preference_accuracy: 0.9036 - out_quality_and_appearance_accuracy: 0.5252 - val_loss: 4.0577 - val_out_aspect_accuracy: 0.3439 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7847 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7977 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6416
# Epoch 3/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 4.0229 - out_aspect_accuracy: 0.3227 - out_author_accuracy: 0.9578 - out_content_related_accuracy: 0.7682 - out_customer_service_accuracy: 0.9681 - out_manufacture_and_distribution_accuracy: 0.9848 - out_overall_experience_accuracy: 0.7251 - out_packaging_and_delivery_accuracy: 0.8159 - out_price_and_preference_accuracy: 0.9060 - out_quality_and_appearance_accuracy: 0.6747 - val_loss: 3.5322 - val_out_aspect_accuracy: 0.3815 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8049 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7312 - val_out_packaging_and_delivery_accuracy: 0.8237 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.7514
# Epoch 4/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 3.4973 - out_aspect_accuracy: 0.3632 - out_author_accuracy: 0.9550 - out_content_related_accuracy: 0.8045 - out_customer_service_accuracy: 0.9704 - out_manufacture_and_distribution_accuracy: 0.9870 - out_overall_experience_accuracy: 0.7327 - out_packaging_and_delivery_accuracy: 0.8469 - out_price_and_preference_accuracy: 0.9175 - out_quality_and_appearance_accuracy: 0.7363 - val_loss: 3.2742 - val_out_aspect_accuracy: 0.4147 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8092 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.8410 - val_out_price_and_preference_accuracy: 0.9191 - val_out_quality_and_appearance_accuracy: 0.7818
# Epoch 5/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 3.1832 - out_aspect_accuracy: 0.4075 - out_author_accuracy: 0.9576 - out_content_related_accuracy: 0.8108 - out_customer_service_accuracy: 0.9713 - out_manufacture_and_distribution_accuracy: 0.9870 - out_overall_experience_accuracy: 0.7454 - out_packaging_and_delivery_accuracy: 0.8719 - out_price_and_preference_accuracy: 0.9173 - out_quality_and_appearance_accuracy: 0.7870 - val_loss: 3.1163 - val_out_aspect_accuracy: 0.4942 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8165 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7399 - val_out_packaging_and_delivery_accuracy: 0.8598 - val_out_price_and_preference_accuracy: 0.9220 - val_out_quality_and_appearance_accuracy: 0.7789
# Epoch 6/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 2.9650 - out_aspect_accuracy: 0.4886 - out_author_accuracy: 0.9540 - out_content_related_accuracy: 0.8245 - out_customer_service_accuracy: 0.9706 - out_manufacture_and_distribution_accuracy: 0.9859 - out_overall_experience_accuracy: 0.7649 - out_packaging_and_delivery_accuracy: 0.8877 - out_price_and_preference_accuracy: 0.9142 - out_quality_and_appearance_accuracy: 0.8019 - val_loss: 3.0969 - val_out_aspect_accuracy: 0.5246 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8035 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7514 - val_out_packaging_and_delivery_accuracy: 0.8526 - val_out_price_and_preference_accuracy: 0.9249 - val_out_quality_and_appearance_accuracy: 0.7789
# Epoch 7/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 2.6877 - out_aspect_accuracy: 0.4931 - out_author_accuracy: 0.9590 - out_content_related_accuracy: 0.8466 - out_customer_service_accuracy: 0.9702 - out_manufacture_and_distribution_accuracy: 0.9852 - out_overall_experience_accuracy: 0.7697 - out_packaging_and_delivery_accuracy: 0.9080 - out_price_and_preference_accuracy: 0.9310 - out_quality_and_appearance_accuracy: 0.8329 - val_loss: 3.0367 - val_out_aspect_accuracy: 0.5014 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8107 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7514 - val_out_packaging_and_delivery_accuracy: 0.8468 - val_out_price_and_preference_accuracy: 0.9306 - val_out_quality_and_appearance_accuracy: 0.7818
# Epoch 8/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 2.4691 - out_aspect_accuracy: 0.5483 - out_author_accuracy: 0.9583 - out_content_related_accuracy: 0.8624 - out_customer_service_accuracy: 0.9727 - out_manufacture_and_distribution_accuracy: 0.9841 - out_overall_experience_accuracy: 0.7870 - out_packaging_and_delivery_accuracy: 0.9178 - out_price_and_preference_accuracy: 0.9469 - out_quality_and_appearance_accuracy: 0.8510 - val_loss: 2.9944 - val_out_aspect_accuracy: 0.5246 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8150 - val_out_customer_service_accuracy: 0.9711 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7616 - val_out_packaging_and_delivery_accuracy: 0.8584 - val_out_price_and_preference_accuracy: 0.9335 - val_out_quality_and_appearance_accuracy: 0.8035
# Epoch 9/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 2.2508 - out_aspect_accuracy: 0.5614 - out_author_accuracy: 0.9625 - out_content_related_accuracy: 0.8755 - out_customer_service_accuracy: 0.9706 - out_manufacture_and_distribution_accuracy: 0.9858 - out_overall_experience_accuracy: 0.8181 - out_packaging_and_delivery_accuracy: 0.9253 - out_price_and_preference_accuracy: 0.9414 - out_quality_and_appearance_accuracy: 0.8663 - val_loss: 3.0225 - val_out_aspect_accuracy: 0.5462 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8179 - val_out_customer_service_accuracy: 0.9711 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7500 - val_out_packaging_and_delivery_accuracy: 0.8584 - val_out_price_and_preference_accuracy: 0.9321 - val_out_quality_and_appearance_accuracy: 0.7962
# Epoch 10/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 2.0668 - out_aspect_accuracy: 0.5569 - out_author_accuracy: 0.9589 - out_content_related_accuracy: 0.8884 - out_customer_service_accuracy: 0.9716 - out_manufacture_and_distribution_accuracy: 0.9881 - out_overall_experience_accuracy: 0.8308 - out_packaging_and_delivery_accuracy: 0.9296 - out_price_and_preference_accuracy: 0.9524 - out_quality_and_appearance_accuracy: 0.8793 - val_loss: 3.0901 - val_out_aspect_accuracy: 0.5332 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8078 - val_out_customer_service_accuracy: 0.9711 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7500 - val_out_packaging_and_delivery_accuracy: 0.8483 - val_out_price_and_preference_accuracy: 0.9335 - val_out_quality_and_appearance_accuracy: 0.7962
# Epoch 11/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 1.9432 - out_aspect_accuracy: 0.5829 - out_author_accuracy: 0.9588 - out_content_related_accuracy: 0.9004 - out_customer_service_accuracy: 0.9726 - out_manufacture_and_distribution_accuracy: 0.9883 - out_overall_experience_accuracy: 0.8451 - out_packaging_and_delivery_accuracy: 0.9294 - out_price_and_preference_accuracy: 0.9497 - out_quality_and_appearance_accuracy: 0.8911 - val_loss: 3.1122 - val_out_aspect_accuracy: 0.5607 - val_out_author_accuracy: 0.9552 - val_out_content_related_accuracy: 0.8092 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7442 - val_out_packaging_and_delivery_accuracy: 0.8642 - val_out_price_and_preference_accuracy: 0.9350 - val_out_quality_and_appearance_accuracy: 0.7876
# Epoch 11: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(padded_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step

# %%
pred_aspect_test = round(pd.DataFrame(pred_test[0]), 0)
aspect_true = label_aspect_test.flatten()
aspect_predict = pred_aspect_test.values.flatten()

weighted_f1_aspect = f1_score(aspect_true, aspect_predict, average='weighted')
print(f'Weighted F1 Score for aspect detection: {weighted_f1_aspect}')
# Out:
# Weighted F1 Score for aspect detection: 0.8829411847567259

# %%
pred_content_related_test = np.where(np.argmax(pred_test[1], axis=1)==3, -1, np.argmax(pred_test[1], axis=1))
pred_author_test = np.where(np.argmax(pred_test[2], axis=1)==3, -1, np.argmax(pred_test[2], axis=1))
pred_quality_and_appearance_test = np.where(np.argmax(pred_test[3], axis=1)==3, -1, np.argmax(pred_test[3], axis=1))
pred_manufacture_and_distribution_test = np.where(np.argmax(pred_test[4], axis=1)==3, -1, np.argmax(pred_test[4], axis=1))
pred_packaging_and_delivery_test = np.where(np.argmax(pred_test[5], axis=1)==3, -1, np.argmax(pred_test[5], axis=1))
pred_price_and_preference_test = np.where(np.argmax(pred_test[6], axis=1)==3, -1, np.argmax(pred_test[6], axis=1))
pred_customer_service_test = np.where(np.argmax(pred_test[7], axis=1)==3, -1, np.argmax(pred_test[7], axis=1))
pred_overall_experience_test = np.where(np.argmax(pred_test[8], axis=1)==3, -1, np.argmax(pred_test[8], axis=1))

predict_test = pd.DataFrame({
    'content_related': pred_content_related_test,
    'author': pred_author_test,
    'quality_and_appearance': pred_quality_and_appearance_test,
    'manufacture_and_distribution': pred_manufacture_and_distribution_test,
    'packaging_and_delivery': pred_packaging_and_delivery_test,
    'price_and_preference': pred_price_and_preference_test,
    'customer_service': pred_customer_service_test,
    'overall_experience': pred_overall_experience_test
})

sentiment_true = df_test.iloc[:, 1:].values.flatten()
sentiment_predict = predict_test.values.flatten()

weighted_f1_sentiment = f1_score(sentiment_true, sentiment_predict, average='weighted')
print(f'Weighted F1 Score for sentiment classification: {weighted_f1_sentiment}')
# Out:
# Weighted F1 Score for sentiment classification: 0.8736693213089738

# %%
del model

# %% [markdown]
# ## BiLSTM + Conv1D

# %%
with device:

    # Number of labels
    num_label = 8

    # Input layer
    inputs = Input(shape=(MAX_LENGTH,))

    # Embedding layer
    embed = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        embeddings_initializer=Constant(embedding_matrix),
        trainable=True
    )(inputs)
    
    dropout1 = SpatialDropout1D(0.2)(embed)

    lstm = Bidirectional(LSTM(units = 200, activation = 'tanh', return_sequences = True))(dropout1)
    conv = Conv1D(128, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(lstm)

    avg_pool1 = GlobalAveragePooling1D()(conv)
    max_pool1 = GlobalMaxPooling1D()(conv)


    concat = Concatenate(axis=-1)([avg_pool1, max_pool1])

    dense2 = Dense(units = 128, activation = 'relu')(concat)
    dropout1 = Dropout(rate = 0.2)(dense2)
    dense3 = Dense(units = 64, activation = 'relu')(dropout1)
    dense4 = Dense(units = 32, activation = 'relu')(dense3)
    
    # Output layers
    out_aspect = Dense(units=num_label, activation='sigmoid', name='out_aspect')(dense4)

    # Helper function to concatenate aspect and dense4 output
    def create_output_layer(aspect_index, name):
        aspect_slice = out_aspect[:, aspect_index:aspect_index + 1]
        concatenated = tf.keras.layers.Concatenate(axis=1)([aspect_slice, dense4])
        output_layer = Dense(units=4, activation='softmax', name=name)(concatenated)
        return output_layer

    out_content_related = create_output_layer(0, 'out_content_related')
    out_author = create_output_layer(1, 'out_author')
    out_quality_and_appearance = create_output_layer(2, 'out_quality_and_appearance')
    out_manufacture_and_distribution = create_output_layer(3, 'out_manufacture_and_distribution')
    out_packaging_and_delivery = create_output_layer(4, 'out_packaging_and_delivery')
    out_price_and_preference = create_output_layer(5, 'out_price_and_preference')
    out_customer_service = create_output_layer(6, 'out_customer_service')
    out_overall_experience = create_output_layer(7, 'out_overall_experience')

    # Define the model
    model = Model(
        inputs=inputs,
        outputs=[
            out_aspect, out_content_related, out_author, out_quality_and_appearance,
            out_manufacture_and_distribution, out_packaging_and_delivery,
            out_price_and_preference, out_customer_service, out_overall_experience
        ]
    )
    
    losses = {
        "out_aspect": "binary_crossentropy",
        "out_content_related": "categorical_crossentropy",
        "out_author": "categorical_crossentropy",
        "out_quality_and_appearance": "categorical_crossentropy",
        "out_manufacture_and_distribution": "categorical_crossentropy",
        "out_packaging_and_delivery": "categorical_crossentropy",
        "out_price_and_preference": "categorical_crossentropy",
        "out_customer_service": "categorical_crossentropy",
        "out_overall_experience": "categorical_crossentropy"
    }
 
    metrics={
        "out_aspect": 'accuracy',
        "out_content_related": 'accuracy',
        "out_author": 'accuracy',
        "out_quality_and_appearance": 'accuracy',
        "out_manufacture_and_distribution": 'accuracy',
        "out_packaging_and_delivery": 'accuracy',
        "out_price_and_preference": 'accuracy',
        "out_customer_service": 'accuracy',
        "out_overall_experience": 'accuracy'
    }
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=losses,
        metrics=metrics
    )

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 128, 1024) │  7,684,096 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d   │ (None, 128, 1024) │          0 │ embedding_1[0][0] │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 128, 400)  │  1,960,000 │ spatial_dropout1… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 127, 128)  │    102,528 │ bidirectional_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv1d[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ conv1d[0][0]      │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 256)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │     32,896 │ concatenate_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 32)        │      2,080 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_aspect (Dense)  │ (None, 8)         │        264 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_8          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_9          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_10         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_11         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_12         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_13         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_14         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_15         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 33)        │          0 │ get_item_8[0][0], │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 33)        │          0 │ get_item_9[0][0], │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 33)        │          0 │ get_item_10[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 33)        │          0 │ get_item_11[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 33)        │          0 │ get_item_12[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 33)        │          0 │ get_item_13[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 33)        │          0 │ get_item_14[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 33)        │          0 │ get_item_15[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_content_related │ (None, 4)         │        136 │ concatenate_9[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_author (Dense)  │ (None, 4)         │        136 │ concatenate_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_quality_and_ap… │ (None, 4)         │        136 │ concatenate_11[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_manufacture_an… │ (None, 4)         │        136 │ concatenate_12[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_packaging_and_… │ (None, 4)         │        136 │ concatenate_13[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_price_and_pref… │ (None, 4)         │        136 │ concatenate_14[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_customer_servi… │ (None, 4)         │        136 │ concatenate_15[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_overall_experi… │ (None, 4)         │        136 │ concatenate_16[0… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,791,208 (37.35 MB)
#  Trainable params: 9,791,208 (37.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit model
history = model.fit(
    x=padded_train,
    y={
        "out_aspect": label_aspect_train,
        "out_content_related": content_related_train,
        "out_author": author_train,
        "out_quality_and_appearance": quality_and_appearance_train,
        "out_manufacture_and_distribution": manufacture_and_distribution_train,
        "out_packaging_and_delivery": packaging_and_delivery_train,
        "out_price_and_preference": price_and_preference_train,
        "out_customer_service": customer_service_train,
        "out_overall_experience": overall_experience_train
    },
    validation_data=(
        padded_val,
        {
            "out_aspect": label_aspect_val,
            "out_content_related": content_related_val,
            "out_author": author_val,
            "out_quality_and_appearance": quality_and_appearance_val,
            "out_manufacture_and_distribution": manufacture_and_distribution_val,
            "out_packaging_and_delivery": packaging_and_delivery_val,
            "out_price_and_preference": price_and_preference_val,
            "out_customer_service": customer_service_val,
            "out_overall_experience": overall_experience_val
        }
    ),
    batch_size=BATCH_SIZE,
    epochs=100,
    callbacks=EarlyStopping(
        monitor='val_loss', 
        patience=3,
        min_delta=0.001,
        mode='min',
        verbose=1
    ),
    verbose=1
)
# Out:
# Epoch 1/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - loss: 8.5521 - out_aspect_accuracy: 0.2650 - out_author_accuracy: 0.9152 - out_content_related_accuracy: 0.5073 - out_customer_service_accuracy: 0.7285 - out_manufacture_and_distribution_accuracy: 0.7343 - out_overall_experience_accuracy: 0.7250 - out_packaging_and_delivery_accuracy: 0.4915 - out_price_and_preference_accuracy: 0.8358 - out_quality_and_appearance_accuracy: 0.3251 - val_loss: 5.4416 - val_out_aspect_accuracy: 0.4090 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.6676 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.3483
# Epoch 2/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 5.4703 - out_aspect_accuracy: 0.3462 - out_author_accuracy: 0.9529 - out_content_related_accuracy: 0.6704 - out_customer_service_accuracy: 0.9696 - out_manufacture_and_distribution_accuracy: 0.9877 - out_overall_experience_accuracy: 0.7310 - out_packaging_and_delivery_accuracy: 0.6977 - out_price_and_preference_accuracy: 0.9058 - out_quality_and_appearance_accuracy: 0.4342 - val_loss: 4.2118 - val_out_aspect_accuracy: 0.2803 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7384 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7341 - val_out_packaging_and_delivery_accuracy: 0.8064 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6633
# Epoch 3/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 4.3723 - out_aspect_accuracy: 0.2889 - out_author_accuracy: 0.9573 - out_content_related_accuracy: 0.7533 - out_customer_service_accuracy: 0.9678 - out_manufacture_and_distribution_accuracy: 0.9868 - out_overall_experience_accuracy: 0.7255 - out_packaging_and_delivery_accuracy: 0.7851 - out_price_and_preference_accuracy: 0.9140 - out_quality_and_appearance_accuracy: 0.6484 - val_loss: 3.5960 - val_out_aspect_accuracy: 0.3627 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8078 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7341 - val_out_packaging_and_delivery_accuracy: 0.8338 - val_out_price_and_preference_accuracy: 0.9191 - val_out_quality_and_appearance_accuracy: 0.7760
# Epoch 4/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 3.8659 - out_aspect_accuracy: 0.3627 - out_author_accuracy: 0.9597 - out_content_related_accuracy: 0.7893 - out_customer_service_accuracy: 0.9698 - out_manufacture_and_distribution_accuracy: 0.9862 - out_overall_experience_accuracy: 0.7110 - out_packaging_and_delivery_accuracy: 0.8333 - out_price_and_preference_accuracy: 0.9147 - out_quality_and_appearance_accuracy: 0.7223 - val_loss: 3.2924 - val_out_aspect_accuracy: 0.4624 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8208 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7312 - val_out_packaging_and_delivery_accuracy: 0.8512 - val_out_price_and_preference_accuracy: 0.9321 - val_out_quality_and_appearance_accuracy: 0.7962
# Epoch 5/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 3.3796 - out_aspect_accuracy: 0.4621 - out_author_accuracy: 0.9559 - out_content_related_accuracy: 0.8067 - out_customer_service_accuracy: 0.9693 - out_manufacture_and_distribution_accuracy: 0.9864 - out_overall_experience_accuracy: 0.7358 - out_packaging_and_delivery_accuracy: 0.8622 - out_price_and_preference_accuracy: 0.9265 - out_quality_and_appearance_accuracy: 0.7691 - val_loss: 3.0947 - val_out_aspect_accuracy: 0.4957 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8194 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7327 - val_out_packaging_and_delivery_accuracy: 0.8598 - val_out_price_and_preference_accuracy: 0.9364 - val_out_quality_and_appearance_accuracy: 0.8121
# Epoch 6/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 3.1101 - out_aspect_accuracy: 0.4880 - out_author_accuracy: 0.9532 - out_content_related_accuracy: 0.8244 - out_customer_service_accuracy: 0.9697 - out_manufacture_and_distribution_accuracy: 0.9864 - out_overall_experience_accuracy: 0.7318 - out_packaging_and_delivery_accuracy: 0.8858 - out_price_and_preference_accuracy: 0.9312 - out_quality_and_appearance_accuracy: 0.7996 - val_loss: 2.9635 - val_out_aspect_accuracy: 0.5000 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8251 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7413 - val_out_packaging_and_delivery_accuracy: 0.8671 - val_out_price_and_preference_accuracy: 0.9436 - val_out_quality_and_appearance_accuracy: 0.8266
# Epoch 7/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 2.8893 - out_aspect_accuracy: 0.5100 - out_author_accuracy: 0.9569 - out_content_related_accuracy: 0.8338 - out_customer_service_accuracy: 0.9705 - out_manufacture_and_distribution_accuracy: 0.9890 - out_overall_experience_accuracy: 0.7507 - out_packaging_and_delivery_accuracy: 0.8815 - out_price_and_preference_accuracy: 0.9410 - out_quality_and_appearance_accuracy: 0.8203 - val_loss: 2.8643 - val_out_aspect_accuracy: 0.5159 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8251 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7514 - val_out_packaging_and_delivery_accuracy: 0.8656 - val_out_price_and_preference_accuracy: 0.9436 - val_out_quality_and_appearance_accuracy: 0.8295
# Epoch 8/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 2.7020 - out_aspect_accuracy: 0.5354 - out_author_accuracy: 0.9628 - out_content_related_accuracy: 0.8373 - out_customer_service_accuracy: 0.9700 - out_manufacture_and_distribution_accuracy: 0.9891 - out_overall_experience_accuracy: 0.7649 - out_packaging_and_delivery_accuracy: 0.9031 - out_price_and_preference_accuracy: 0.9444 - out_quality_and_appearance_accuracy: 0.8366 - val_loss: 2.8041 - val_out_aspect_accuracy: 0.5145 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8194 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7486 - val_out_packaging_and_delivery_accuracy: 0.8656 - val_out_price_and_preference_accuracy: 0.9465 - val_out_quality_and_appearance_accuracy: 0.8324
# Epoch 9/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 2.5158 - out_aspect_accuracy: 0.5331 - out_author_accuracy: 0.9587 - out_content_related_accuracy: 0.8463 - out_customer_service_accuracy: 0.9739 - out_manufacture_and_distribution_accuracy: 0.9895 - out_overall_experience_accuracy: 0.7730 - out_packaging_and_delivery_accuracy: 0.9108 - out_price_and_preference_accuracy: 0.9580 - out_quality_and_appearance_accuracy: 0.8480 - val_loss: 2.7509 - val_out_aspect_accuracy: 0.5578 - val_out_author_accuracy: 0.9509 - val_out_content_related_accuracy: 0.8251 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7645 - val_out_packaging_and_delivery_accuracy: 0.8829 - val_out_price_and_preference_accuracy: 0.9451 - val_out_quality_and_appearance_accuracy: 0.8280
# Epoch 10/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 2.3544 - out_aspect_accuracy: 0.5468 - out_author_accuracy: 0.9614 - out_content_related_accuracy: 0.8661 - out_customer_service_accuracy: 0.9709 - out_manufacture_and_distribution_accuracy: 0.9860 - out_overall_experience_accuracy: 0.7876 - out_packaging_and_delivery_accuracy: 0.9227 - out_price_and_preference_accuracy: 0.9625 - out_quality_and_appearance_accuracy: 0.8639 - val_loss: 2.6720 - val_out_aspect_accuracy: 0.5564 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8280 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7659 - val_out_packaging_and_delivery_accuracy: 0.8815 - val_out_price_and_preference_accuracy: 0.9465 - val_out_quality_and_appearance_accuracy: 0.8338
# Epoch 11/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 2.2362 - out_aspect_accuracy: 0.5635 - out_author_accuracy: 0.9615 - out_content_related_accuracy: 0.8703 - out_customer_service_accuracy: 0.9721 - out_manufacture_and_distribution_accuracy: 0.9854 - out_overall_experience_accuracy: 0.8063 - out_packaging_and_delivery_accuracy: 0.9198 - out_price_and_preference_accuracy: 0.9641 - out_quality_and_appearance_accuracy: 0.8681 - val_loss: 2.6608 - val_out_aspect_accuracy: 0.5390 - val_out_author_accuracy: 0.9566 - val_out_content_related_accuracy: 0.8382 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7746 - val_out_packaging_and_delivery_accuracy: 0.8685 - val_out_price_and_preference_accuracy: 0.9436 - val_out_quality_and_appearance_accuracy: 0.8223
# Epoch 12/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 2.1143 - out_aspect_accuracy: 0.5738 - out_author_accuracy: 0.9586 - out_content_related_accuracy: 0.8804 - out_customer_service_accuracy: 0.9745 - out_manufacture_and_distribution_accuracy: 0.9868 - out_overall_experience_accuracy: 0.8204 - out_packaging_and_delivery_accuracy: 0.9229 - out_price_and_preference_accuracy: 0.9665 - out_quality_and_appearance_accuracy: 0.8751 - val_loss: 2.6480 - val_out_aspect_accuracy: 0.5491 - val_out_author_accuracy: 0.9566 - val_out_content_related_accuracy: 0.8353 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7616 - val_out_packaging_and_delivery_accuracy: 0.8801 - val_out_price_and_preference_accuracy: 0.9465 - val_out_quality_and_appearance_accuracy: 0.8309
# Epoch 13/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 2.0233 - out_aspect_accuracy: 0.5915 - out_author_accuracy: 0.9641 - out_content_related_accuracy: 0.8871 - out_customer_service_accuracy: 0.9719 - out_manufacture_and_distribution_accuracy: 0.9872 - out_overall_experience_accuracy: 0.8170 - out_packaging_and_delivery_accuracy: 0.9310 - out_price_and_preference_accuracy: 0.9622 - out_quality_and_appearance_accuracy: 0.8810 - val_loss: 2.6519 - val_out_aspect_accuracy: 0.5592 - val_out_author_accuracy: 0.9566 - val_out_content_related_accuracy: 0.8280 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7818 - val_out_packaging_and_delivery_accuracy: 0.8801 - val_out_price_and_preference_accuracy: 0.9451 - val_out_quality_and_appearance_accuracy: 0.8266
# Epoch 14/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 1.8994 - out_aspect_accuracy: 0.6044 - out_author_accuracy: 0.9577 - out_content_related_accuracy: 0.8966 - out_customer_service_accuracy: 0.9726 - out_manufacture_and_distribution_accuracy: 0.9855 - out_overall_experience_accuracy: 0.8330 - out_packaging_and_delivery_accuracy: 0.9380 - out_price_and_preference_accuracy: 0.9699 - out_quality_and_appearance_accuracy: 0.8906 - val_loss: 2.6224 - val_out_aspect_accuracy: 0.5520 - val_out_author_accuracy: 0.9595 - val_out_content_related_accuracy: 0.8353 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7775 - val_out_packaging_and_delivery_accuracy: 0.8829 - val_out_price_and_preference_accuracy: 0.9480 - val_out_quality_and_appearance_accuracy: 0.8309
# Epoch 15/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 1.7104 - out_aspect_accuracy: 0.6083 - out_author_accuracy: 0.9676 - out_content_related_accuracy: 0.9022 - out_customer_service_accuracy: 0.9714 - out_manufacture_and_distribution_accuracy: 0.9888 - out_overall_experience_accuracy: 0.8504 - out_packaging_and_delivery_accuracy: 0.9449 - out_price_and_preference_accuracy: 0.9691 - out_quality_and_appearance_accuracy: 0.9036 - val_loss: 2.6124 - val_out_aspect_accuracy: 0.5650 - val_out_author_accuracy: 0.9595 - val_out_content_related_accuracy: 0.8338 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7832 - val_out_packaging_and_delivery_accuracy: 0.8844 - val_out_price_and_preference_accuracy: 0.9480 - val_out_quality_and_appearance_accuracy: 0.8280
# Epoch 16/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 1.6757 - out_aspect_accuracy: 0.6194 - out_author_accuracy: 0.9645 - out_content_related_accuracy: 0.9159 - out_customer_service_accuracy: 0.9660 - out_manufacture_and_distribution_accuracy: 0.9873 - out_overall_experience_accuracy: 0.8630 - out_packaging_and_delivery_accuracy: 0.9495 - out_price_and_preference_accuracy: 0.9711 - out_quality_and_appearance_accuracy: 0.8972 - val_loss: 2.7133 - val_out_aspect_accuracy: 0.5824 - val_out_author_accuracy: 0.9610 - val_out_content_related_accuracy: 0.8353 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7861 - val_out_packaging_and_delivery_accuracy: 0.8945 - val_out_price_and_preference_accuracy: 0.9480 - val_out_quality_and_appearance_accuracy: 0.8295
# Epoch 17/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 1.5411 - out_aspect_accuracy: 0.6128 - out_author_accuracy: 0.9642 - out_content_related_accuracy: 0.9174 - out_customer_service_accuracy: 0.9728 - out_manufacture_and_distribution_accuracy: 0.9836 - out_overall_experience_accuracy: 0.8712 - out_packaging_and_delivery_accuracy: 0.9505 - out_price_and_preference_accuracy: 0.9764 - out_quality_and_appearance_accuracy: 0.9188 - val_loss: 2.6641 - val_out_aspect_accuracy: 0.5520 - val_out_author_accuracy: 0.9581 - val_out_content_related_accuracy: 0.8382 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7688 - val_out_packaging_and_delivery_accuracy: 0.8844 - val_out_price_and_preference_accuracy: 0.9465 - val_out_quality_and_appearance_accuracy: 0.8237
# Epoch 18/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 1.4265 - out_aspect_accuracy: 0.6165 - out_author_accuracy: 0.9719 - out_content_related_accuracy: 0.9285 - out_customer_service_accuracy: 0.9724 - out_manufacture_and_distribution_accuracy: 0.9884 - out_overall_experience_accuracy: 0.8755 - out_packaging_and_delivery_accuracy: 0.9532 - out_price_and_preference_accuracy: 0.9747 - out_quality_and_appearance_accuracy: 0.9266 - val_loss: 2.7299 - val_out_aspect_accuracy: 0.5751 - val_out_author_accuracy: 0.9610 - val_out_content_related_accuracy: 0.8353 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7876 - val_out_packaging_and_delivery_accuracy: 0.8815 - val_out_price_and_preference_accuracy: 0.9509 - val_out_quality_and_appearance_accuracy: 0.8194
# Epoch 18: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(padded_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step

# %%
pred_aspect_test = round(pd.DataFrame(pred_test[0]), 0)
aspect_true = label_aspect_test.flatten()
aspect_predict = pred_aspect_test.values.flatten()

weighted_f1_aspect = f1_score(aspect_true, aspect_predict, average='weighted')
print(f'Weighted F1 Score for aspect detection: {weighted_f1_aspect}')
# Out:
# Weighted F1 Score for aspect detection: 0.8953765855569289

# %%
pred_content_related_test = np.where(np.argmax(pred_test[1], axis=1)==3, -1, np.argmax(pred_test[1], axis=1))
pred_author_test = np.where(np.argmax(pred_test[2], axis=1)==3, -1, np.argmax(pred_test[2], axis=1))
pred_quality_and_appearance_test = np.where(np.argmax(pred_test[3], axis=1)==3, -1, np.argmax(pred_test[3], axis=1))
pred_manufacture_and_distribution_test = np.where(np.argmax(pred_test[4], axis=1)==3, -1, np.argmax(pred_test[4], axis=1))
pred_packaging_and_delivery_test = np.where(np.argmax(pred_test[5], axis=1)==3, -1, np.argmax(pred_test[5], axis=1))
pred_price_and_preference_test = np.where(np.argmax(pred_test[6], axis=1)==3, -1, np.argmax(pred_test[6], axis=1))
pred_customer_service_test = np.where(np.argmax(pred_test[7], axis=1)==3, -1, np.argmax(pred_test[7], axis=1))
pred_overall_experience_test = np.where(np.argmax(pred_test[8], axis=1)==3, -1, np.argmax(pred_test[8], axis=1))

predict_test = pd.DataFrame({
    'content_related': pred_content_related_test,
    'author': pred_author_test,
    'quality_and_appearance': pred_quality_and_appearance_test,
    'manufacture_and_distribution': pred_manufacture_and_distribution_test,
    'packaging_and_delivery': pred_packaging_and_delivery_test,
    'price_and_preference': pred_price_and_preference_test,
    'customer_service': pred_customer_service_test,
    'overall_experience': pred_overall_experience_test
})

sentiment_true = df_test.iloc[:, 1:].values.flatten()
sentiment_predict = predict_test.values.flatten()

weighted_f1_sentiment = f1_score(sentiment_true, sentiment_predict, average='weighted')
print(f'Weighted F1 Score for sentiment classification: {weighted_f1_sentiment}')
# Out:
# Weighted F1 Score for sentiment classification: 0.8882632276012081

# %%
del model

# %% [markdown]
# ## BiGRU

# %%
with device:

    # Number of labels
    num_label = 8

    # Input layer
    inputs = Input(shape=(MAX_LENGTH,))

    # Embedding layer
    embed = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        embeddings_initializer=Constant(embedding_matrix),
        trainable=True
    )(inputs)
    
    lstm = Bidirectional(GRU(units = 200, activation = 'tanh'))(embed)
    dense2 = Dense(units = 128, activation = 'relu')(lstm)
    dropout1 = Dropout(rate = 0.2)(dense2)
    dense3 = Dense(units = 64, activation = 'relu')(dropout1)
    dense4 = Dense(units = 32, activation = 'relu')(dense3)
    
    # Output layers
    out_aspect = Dense(units=num_label, activation='sigmoid', name='out_aspect')(dense4)

    # Helper function to concatenate aspect and dense4 output
    def create_output_layer(aspect_index, name):
        aspect_slice = out_aspect[:, aspect_index:aspect_index + 1]
        concatenated = tf.keras.layers.Concatenate(axis=1)([aspect_slice, dense4])
        output_layer = Dense(units=4, activation='softmax', name=name)(concatenated)
        return output_layer

    out_content_related = create_output_layer(0, 'out_content_related')
    out_author = create_output_layer(1, 'out_author')
    out_quality_and_appearance = create_output_layer(2, 'out_quality_and_appearance')
    out_manufacture_and_distribution = create_output_layer(3, 'out_manufacture_and_distribution')
    out_packaging_and_delivery = create_output_layer(4, 'out_packaging_and_delivery')
    out_price_and_preference = create_output_layer(5, 'out_price_and_preference')
    out_customer_service = create_output_layer(6, 'out_customer_service')
    out_overall_experience = create_output_layer(7, 'out_overall_experience')

    # Define the model
    model = Model(
        inputs=inputs,
        outputs=[
            out_aspect, out_content_related, out_author, out_quality_and_appearance,
            out_manufacture_and_distribution, out_packaging_and_delivery,
            out_price_and_preference, out_customer_service, out_overall_experience
        ]
    )
    
    losses = {
        "out_aspect": "binary_crossentropy",
        "out_content_related": "categorical_crossentropy",
        "out_author": "categorical_crossentropy",
        "out_quality_and_appearance": "categorical_crossentropy",
        "out_manufacture_and_distribution": "categorical_crossentropy",
        "out_packaging_and_delivery": "categorical_crossentropy",
        "out_price_and_preference": "categorical_crossentropy",
        "out_customer_service": "categorical_crossentropy",
        "out_overall_experience": "categorical_crossentropy"
    }
 
    metrics={
        "out_aspect": 'accuracy',
        "out_content_related": 'accuracy',
        "out_author": 'accuracy',
        "out_quality_and_appearance": 'accuracy',
        "out_manufacture_and_distribution": 'accuracy',
        "out_packaging_and_delivery": 'accuracy',
        "out_price_and_preference": 'accuracy',
        "out_customer_service": 'accuracy',
        "out_overall_experience": 'accuracy'
    }
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=losses,
        metrics=metrics
    )

model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 128, 1024) │  7,684,096 │ input_layer_2[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_2     │ (None, 400)       │  1,471,200 │ embedding_2[0][0] │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │     51,328 │ bidirectional_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64)        │      8,256 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 32)        │      2,080 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_aspect (Dense)  │ (None, 8)         │        264 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_16         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_17         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_18         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_19         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_20         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_21         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_22         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_23         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 33)        │          0 │ get_item_16[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 33)        │          0 │ get_item_17[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 33)        │          0 │ get_item_18[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 33)        │          0 │ get_item_19[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 33)        │          0 │ get_item_20[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 33)        │          0 │ get_item_21[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 33)        │          0 │ get_item_22[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, 33)        │          0 │ get_item_23[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_content_related │ (None, 4)         │        136 │ concatenate_17[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_author (Dense)  │ (None, 4)         │        136 │ concatenate_18[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_quality_and_ap… │ (None, 4)         │        136 │ concatenate_19[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_manufacture_an… │ (None, 4)         │        136 │ concatenate_20[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_packaging_and_… │ (None, 4)         │        136 │ concatenate_21[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_price_and_pref… │ (None, 4)         │        136 │ concatenate_22[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_customer_servi… │ (None, 4)         │        136 │ concatenate_23[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_overall_experi… │ (None, 4)         │        136 │ concatenate_24[0… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,218,312 (35.17 MB)
#  Trainable params: 9,218,312 (35.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit model
history = model.fit(
    x=padded_train,
    y={
        "out_aspect": label_aspect_train,
        "out_content_related": content_related_train,
        "out_author": author_train,
        "out_quality_and_appearance": quality_and_appearance_train,
        "out_manufacture_and_distribution": manufacture_and_distribution_train,
        "out_packaging_and_delivery": packaging_and_delivery_train,
        "out_price_and_preference": price_and_preference_train,
        "out_customer_service": customer_service_train,
        "out_overall_experience": overall_experience_train
    },
    validation_data=(
        padded_val,
        {
            "out_aspect": label_aspect_val,
            "out_content_related": content_related_val,
            "out_author": author_val,
            "out_quality_and_appearance": quality_and_appearance_val,
            "out_manufacture_and_distribution": manufacture_and_distribution_val,
            "out_packaging_and_delivery": packaging_and_delivery_val,
            "out_price_and_preference": price_and_preference_val,
            "out_customer_service": customer_service_val,
            "out_overall_experience": overall_experience_val
        }
    ),
    batch_size=BATCH_SIZE,
    epochs=100,
    callbacks=EarlyStopping(
        monitor='val_loss', 
        patience=3,
        min_delta=0.001,
        mode='min',
        verbose=1
    ),
    verbose=1
)
# Out:
# Epoch 1/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 43ms/step - loss: 9.3364 - out_aspect_accuracy: 0.0457 - out_author_accuracy: 0.5553 - out_content_related_accuracy: 0.6057 - out_customer_service_accuracy: 0.8173 - out_manufacture_and_distribution_accuracy: 0.9734 - out_overall_experience_accuracy: 0.2786 - out_packaging_and_delivery_accuracy: 0.2996 - out_price_and_preference_accuracy: 0.8802 - out_quality_and_appearance_accuracy: 0.2936 - val_loss: 6.2403 - val_out_aspect_accuracy: 0.0607 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7211 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.6301 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4957
# Epoch 2/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 6.1533 - out_aspect_accuracy: 0.0790 - out_author_accuracy: 0.9584 - out_content_related_accuracy: 0.6824 - out_customer_service_accuracy: 0.9675 - out_manufacture_and_distribution_accuracy: 0.9877 - out_overall_experience_accuracy: 0.7151 - out_packaging_and_delivery_accuracy: 0.5879 - out_price_and_preference_accuracy: 0.9137 - out_quality_and_appearance_accuracy: 0.4608 - val_loss: 4.9836 - val_out_aspect_accuracy: 0.2399 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7760 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.6344 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5751
# Epoch 3/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 5.0424 - out_aspect_accuracy: 0.2725 - out_author_accuracy: 0.9606 - out_content_related_accuracy: 0.7253 - out_customer_service_accuracy: 0.9675 - out_manufacture_and_distribution_accuracy: 0.9862 - out_overall_experience_accuracy: 0.7197 - out_packaging_and_delivery_accuracy: 0.6541 - out_price_and_preference_accuracy: 0.9127 - out_quality_and_appearance_accuracy: 0.5414 - val_loss: 4.3677 - val_out_aspect_accuracy: 0.3266 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7890 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7399 - val_out_packaging_and_delivery_accuracy: 0.6821 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6040
# Epoch 4/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 4.4554 - out_aspect_accuracy: 0.2994 - out_author_accuracy: 0.9588 - out_content_related_accuracy: 0.7655 - out_customer_service_accuracy: 0.9672 - out_manufacture_and_distribution_accuracy: 0.9868 - out_overall_experience_accuracy: 0.7284 - out_packaging_and_delivery_accuracy: 0.6909 - out_price_and_preference_accuracy: 0.9118 - out_quality_and_appearance_accuracy: 0.6171 - val_loss: 3.9282 - val_out_aspect_accuracy: 0.3425 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8136 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7514 - val_out_packaging_and_delivery_accuracy: 0.7471 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6618
# Epoch 5/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - loss: 4.0180 - out_aspect_accuracy: 0.3479 - out_author_accuracy: 0.9542 - out_content_related_accuracy: 0.7800 - out_customer_service_accuracy: 0.9705 - out_manufacture_and_distribution_accuracy: 0.9856 - out_overall_experience_accuracy: 0.7312 - out_packaging_and_delivery_accuracy: 0.7728 - out_price_and_preference_accuracy: 0.9125 - out_quality_and_appearance_accuracy: 0.6884 - val_loss: 3.5881 - val_out_aspect_accuracy: 0.3656 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8150 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7500 - val_out_packaging_and_delivery_accuracy: 0.8006 - val_out_price_and_preference_accuracy: 0.9205 - val_out_quality_and_appearance_accuracy: 0.6994
# Epoch 6/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 3.5596 - out_aspect_accuracy: 0.3992 - out_author_accuracy: 0.9558 - out_content_related_accuracy: 0.7979 - out_customer_service_accuracy: 0.9730 - out_manufacture_and_distribution_accuracy: 0.9861 - out_overall_experience_accuracy: 0.7292 - out_packaging_and_delivery_accuracy: 0.8353 - out_price_and_preference_accuracy: 0.9202 - out_quality_and_appearance_accuracy: 0.7418 - val_loss: 3.3925 - val_out_aspect_accuracy: 0.4653 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8208 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7543 - val_out_packaging_and_delivery_accuracy: 0.8266 - val_out_price_and_preference_accuracy: 0.9220 - val_out_quality_and_appearance_accuracy: 0.7587
# Epoch 7/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 3.2698 - out_aspect_accuracy: 0.4609 - out_author_accuracy: 0.9535 - out_content_related_accuracy: 0.8268 - out_customer_service_accuracy: 0.9698 - out_manufacture_and_distribution_accuracy: 0.9833 - out_overall_experience_accuracy: 0.7480 - out_packaging_and_delivery_accuracy: 0.8546 - out_price_and_preference_accuracy: 0.9249 - out_quality_and_appearance_accuracy: 0.7823 - val_loss: 3.2446 - val_out_aspect_accuracy: 0.4827 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8367 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7529 - val_out_packaging_and_delivery_accuracy: 0.8483 - val_out_price_and_preference_accuracy: 0.9306 - val_out_quality_and_appearance_accuracy: 0.7471
# Epoch 8/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 3.0538 - out_aspect_accuracy: 0.4813 - out_author_accuracy: 0.9574 - out_content_related_accuracy: 0.8385 - out_customer_service_accuracy: 0.9706 - out_manufacture_and_distribution_accuracy: 0.9862 - out_overall_experience_accuracy: 0.7475 - out_packaging_and_delivery_accuracy: 0.8734 - out_price_and_preference_accuracy: 0.9212 - out_quality_and_appearance_accuracy: 0.8081 - val_loss: 3.1364 - val_out_aspect_accuracy: 0.5101 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8410 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7659 - val_out_packaging_and_delivery_accuracy: 0.8598 - val_out_price_and_preference_accuracy: 0.9379 - val_out_quality_and_appearance_accuracy: 0.7775
# Epoch 9/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 2.8092 - out_aspect_accuracy: 0.5542 - out_author_accuracy: 0.9595 - out_content_related_accuracy: 0.8519 - out_customer_service_accuracy: 0.9711 - out_manufacture_and_distribution_accuracy: 0.9854 - out_overall_experience_accuracy: 0.7591 - out_packaging_and_delivery_accuracy: 0.8907 - out_price_and_preference_accuracy: 0.9303 - out_quality_and_appearance_accuracy: 0.8353 - val_loss: 3.0821 - val_out_aspect_accuracy: 0.5419 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8324 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7616 - val_out_packaging_and_delivery_accuracy: 0.8642 - val_out_price_and_preference_accuracy: 0.9350 - val_out_quality_and_appearance_accuracy: 0.7760
# Epoch 10/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 2.6229 - out_aspect_accuracy: 0.5583 - out_author_accuracy: 0.9572 - out_content_related_accuracy: 0.8588 - out_customer_service_accuracy: 0.9739 - out_manufacture_and_distribution_accuracy: 0.9872 - out_overall_experience_accuracy: 0.7607 - out_packaging_and_delivery_accuracy: 0.9040 - out_price_and_preference_accuracy: 0.9384 - out_quality_and_appearance_accuracy: 0.8478 - val_loss: 3.0098 - val_out_aspect_accuracy: 0.5434 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8338 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7587 - val_out_packaging_and_delivery_accuracy: 0.8728 - val_out_price_and_preference_accuracy: 0.9364 - val_out_quality_and_appearance_accuracy: 0.7832
# Epoch 11/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 2.4032 - out_aspect_accuracy: 0.5682 - out_author_accuracy: 0.9629 - out_content_related_accuracy: 0.8866 - out_customer_service_accuracy: 0.9668 - out_manufacture_and_distribution_accuracy: 0.9870 - out_overall_experience_accuracy: 0.7870 - out_packaging_and_delivery_accuracy: 0.9239 - out_price_and_preference_accuracy: 0.9450 - out_quality_and_appearance_accuracy: 0.8462 - val_loss: 2.9739 - val_out_aspect_accuracy: 0.5853 - val_out_author_accuracy: 0.9494 - val_out_content_related_accuracy: 0.8367 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7673 - val_out_packaging_and_delivery_accuracy: 0.8815 - val_out_price_and_preference_accuracy: 0.9393 - val_out_quality_and_appearance_accuracy: 0.7905
# Epoch 12/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 2.2943 - out_aspect_accuracy: 0.5825 - out_author_accuracy: 0.9577 - out_content_related_accuracy: 0.8800 - out_customer_service_accuracy: 0.9720 - out_manufacture_and_distribution_accuracy: 0.9866 - out_overall_experience_accuracy: 0.7882 - out_packaging_and_delivery_accuracy: 0.9176 - out_price_and_preference_accuracy: 0.9443 - out_quality_and_appearance_accuracy: 0.8678 - val_loss: 2.9818 - val_out_aspect_accuracy: 0.5867 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8382 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7500 - val_out_packaging_and_delivery_accuracy: 0.8786 - val_out_price_and_preference_accuracy: 0.9364 - val_out_quality_and_appearance_accuracy: 0.7876
# Epoch 13/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 2.0747 - out_aspect_accuracy: 0.6111 - out_author_accuracy: 0.9611 - out_content_related_accuracy: 0.8937 - out_customer_service_accuracy: 0.9723 - out_manufacture_and_distribution_accuracy: 0.9875 - out_overall_experience_accuracy: 0.8077 - out_packaging_and_delivery_accuracy: 0.9335 - out_price_and_preference_accuracy: 0.9515 - out_quality_and_appearance_accuracy: 0.8827 - val_loss: 3.0478 - val_out_aspect_accuracy: 0.5780 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8396 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7702 - val_out_packaging_and_delivery_accuracy: 0.8656 - val_out_price_and_preference_accuracy: 0.9408 - val_out_quality_and_appearance_accuracy: 0.7847
# Epoch 14/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 2.0398 - out_aspect_accuracy: 0.6282 - out_author_accuracy: 0.9570 - out_content_related_accuracy: 0.8983 - out_customer_service_accuracy: 0.9759 - out_manufacture_and_distribution_accuracy: 0.9828 - out_overall_experience_accuracy: 0.8067 - out_packaging_and_delivery_accuracy: 0.9327 - out_price_and_preference_accuracy: 0.9525 - out_quality_and_appearance_accuracy: 0.8931 - val_loss: 3.0340 - val_out_aspect_accuracy: 0.5679 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8194 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7673 - val_out_packaging_and_delivery_accuracy: 0.8714 - val_out_price_and_preference_accuracy: 0.9465 - val_out_quality_and_appearance_accuracy: 0.7775
# Epoch 14: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(padded_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
pred_aspect_test = round(pd.DataFrame(pred_test[0]), 0)
aspect_true = label_aspect_test.flatten()
aspect_predict = pred_aspect_test.values.flatten()

weighted_f1_aspect = f1_score(aspect_true, aspect_predict, average='weighted')
print(f'Weighted F1 Score for aspect detection: {weighted_f1_aspect}')
# Out:
# Weighted F1 Score for aspect detection: 0.8824290503452086

# %%
pred_content_related_test = np.where(np.argmax(pred_test[1], axis=1)==3, -1, np.argmax(pred_test[1], axis=1))
pred_author_test = np.where(np.argmax(pred_test[2], axis=1)==3, -1, np.argmax(pred_test[2], axis=1))
pred_quality_and_appearance_test = np.where(np.argmax(pred_test[3], axis=1)==3, -1, np.argmax(pred_test[3], axis=1))
pred_manufacture_and_distribution_test = np.where(np.argmax(pred_test[4], axis=1)==3, -1, np.argmax(pred_test[4], axis=1))
pred_packaging_and_delivery_test = np.where(np.argmax(pred_test[5], axis=1)==3, -1, np.argmax(pred_test[5], axis=1))
pred_price_and_preference_test = np.where(np.argmax(pred_test[6], axis=1)==3, -1, np.argmax(pred_test[6], axis=1))
pred_customer_service_test = np.where(np.argmax(pred_test[7], axis=1)==3, -1, np.argmax(pred_test[7], axis=1))
pred_overall_experience_test = np.where(np.argmax(pred_test[8], axis=1)==3, -1, np.argmax(pred_test[8], axis=1))

predict_test = pd.DataFrame({
    'content_related': pred_content_related_test,
    'author': pred_author_test,
    'quality_and_appearance': pred_quality_and_appearance_test,
    'manufacture_and_distribution': pred_manufacture_and_distribution_test,
    'packaging_and_delivery': pred_packaging_and_delivery_test,
    'price_and_preference': pred_price_and_preference_test,
    'customer_service': pred_customer_service_test,
    'overall_experience': pred_overall_experience_test
})

sentiment_true = df_test.iloc[:, 1:].values.flatten()
sentiment_predict = predict_test.values.flatten()

weighted_f1_sentiment = f1_score(sentiment_true, sentiment_predict, average='weighted')
print(f'Weighted F1 Score for sentiment classification: {weighted_f1_sentiment}')
# Out:
# Weighted F1 Score for sentiment classification: 0.8718936799548983

# %%
del model

# %% [markdown]
# ## BiGRU + Conv1D

# %%
with device:

    # Number of labels
    num_label = 8

    # Input layer
    inputs = Input(shape=(MAX_LENGTH,))

    # Embedding layer
    embed = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        embeddings_initializer=Constant(embedding_matrix),
        trainable=True
    )(inputs)
    
    dropout1 = SpatialDropout1D(0.2)(embed)

    lstm = Bidirectional(GRU(units = 200, activation = 'tanh', return_sequences = True))(dropout1)
    conv = Conv1D(128, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(lstm)

    avg_pool1 = GlobalAveragePooling1D()(conv)
    max_pool1 = GlobalMaxPooling1D()(conv)


    concat = Concatenate(axis=-1)([avg_pool1, max_pool1])

    dense2 = Dense(units = 128, activation = 'relu')(concat)
    dropout1 = Dropout(rate = 0.2)(dense2)
    dense3 = Dense(units = 64, activation = 'relu')(dropout1)
    dense4 = Dense(units = 32, activation = 'relu')(dense3)
    
    # Output layers
    out_aspect = Dense(units=num_label, activation='sigmoid', name='out_aspect')(dense4)

    # Helper function to concatenate aspect and dense4 output
    def create_output_layer(aspect_index, name):
        aspect_slice = out_aspect[:, aspect_index:aspect_index + 1]
        concatenated = tf.keras.layers.Concatenate(axis=1)([aspect_slice, dense4])
        output_layer = Dense(units=4, activation='softmax', name=name)(concatenated)
        return output_layer

    out_content_related = create_output_layer(0, 'out_content_related')
    out_author = create_output_layer(1, 'out_author')
    out_quality_and_appearance = create_output_layer(2, 'out_quality_and_appearance')
    out_manufacture_and_distribution = create_output_layer(3, 'out_manufacture_and_distribution')
    out_packaging_and_delivery = create_output_layer(4, 'out_packaging_and_delivery')
    out_price_and_preference = create_output_layer(5, 'out_price_and_preference')
    out_customer_service = create_output_layer(6, 'out_customer_service')
    out_overall_experience = create_output_layer(7, 'out_overall_experience')

    # Define the model
    model = Model(
        inputs=inputs,
        outputs=[
            out_aspect, out_content_related, out_author, out_quality_and_appearance,
            out_manufacture_and_distribution, out_packaging_and_delivery,
            out_price_and_preference, out_customer_service, out_overall_experience
        ]
    )
    
    losses = {
        "out_aspect": "binary_crossentropy",
        "out_content_related": "categorical_crossentropy",
        "out_author": "categorical_crossentropy",
        "out_quality_and_appearance": "categorical_crossentropy",
        "out_manufacture_and_distribution": "categorical_crossentropy",
        "out_packaging_and_delivery": "categorical_crossentropy",
        "out_price_and_preference": "categorical_crossentropy",
        "out_customer_service": "categorical_crossentropy",
        "out_overall_experience": "categorical_crossentropy"
    }
 
    metrics={
        "out_aspect": 'accuracy',
        "out_content_related": 'accuracy',
        "out_author": 'accuracy',
        "out_quality_and_appearance": 'accuracy',
        "out_manufacture_and_distribution": 'accuracy',
        "out_packaging_and_delivery": 'accuracy',
        "out_price_and_preference": 'accuracy',
        "out_customer_service": 'accuracy',
        "out_overall_experience": 'accuracy'
    }
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=losses,
        metrics=metrics
    )

model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, 128, 1024) │  7,684,096 │ input_layer_3[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_1 │ (None, 128, 1024) │          0 │ embedding_3[0][0] │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_3     │ (None, 128, 400)  │  1,471,200 │ spatial_dropout1… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 127, 128)  │    102,528 │ bidirectional_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv1d_1[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ conv1d_1[0][0]    │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_25      │ (None, 256)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 128)       │     32,896 │ concatenate_25[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 64)        │      8,256 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 32)        │      2,080 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_aspect (Dense)  │ (None, 8)         │        264 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_24         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_25         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_26         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_27         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_28         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_29         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_30         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_31         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, 33)        │          0 │ get_item_24[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_27      │ (None, 33)        │          0 │ get_item_25[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_28      │ (None, 33)        │          0 │ get_item_26[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_29      │ (None, 33)        │          0 │ get_item_27[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_30      │ (None, 33)        │          0 │ get_item_28[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_31      │ (None, 33)        │          0 │ get_item_29[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_32      │ (None, 33)        │          0 │ get_item_30[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_33      │ (None, 33)        │          0 │ get_item_31[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_content_related │ (None, 4)         │        136 │ concatenate_26[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_author (Dense)  │ (None, 4)         │        136 │ concatenate_27[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_quality_and_ap… │ (None, 4)         │        136 │ concatenate_28[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_manufacture_an… │ (None, 4)         │        136 │ concatenate_29[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_packaging_and_… │ (None, 4)         │        136 │ concatenate_30[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_price_and_pref… │ (None, 4)         │        136 │ concatenate_31[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_customer_servi… │ (None, 4)         │        136 │ concatenate_32[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_overall_experi… │ (None, 4)         │        136 │ concatenate_33[0… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,302,408 (35.49 MB)
#  Trainable params: 9,302,408 (35.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit model
history = model.fit(
    x=padded_train,
    y={
        "out_aspect": label_aspect_train,
        "out_content_related": content_related_train,
        "out_author": author_train,
        "out_quality_and_appearance": quality_and_appearance_train,
        "out_manufacture_and_distribution": manufacture_and_distribution_train,
        "out_packaging_and_delivery": packaging_and_delivery_train,
        "out_price_and_preference": price_and_preference_train,
        "out_customer_service": customer_service_train,
        "out_overall_experience": overall_experience_train
    },
    validation_data=(
        padded_val,
        {
            "out_aspect": label_aspect_val,
            "out_content_related": content_related_val,
            "out_author": author_val,
            "out_quality_and_appearance": quality_and_appearance_val,
            "out_manufacture_and_distribution": manufacture_and_distribution_val,
            "out_packaging_and_delivery": packaging_and_delivery_val,
            "out_price_and_preference": price_and_preference_val,
            "out_customer_service": customer_service_val,
            "out_overall_experience": overall_experience_val
        }
    ),
    batch_size=BATCH_SIZE,
    epochs=100,
    callbacks=EarlyStopping(
        monitor='val_loss', 
        patience=3,
        min_delta=0.001,
        mode='min',
        verbose=1
    ),
    verbose=1
)
# Out:
# Epoch 1/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - loss: 9.5192 - out_aspect_accuracy: 0.0315 - out_author_accuracy: 0.5285 - out_content_related_accuracy: 0.5687 - out_customer_service_accuracy: 0.8800 - out_manufacture_and_distribution_accuracy: 0.7937 - out_overall_experience_accuracy: 0.5285 - out_packaging_and_delivery_accuracy: 0.4787 - out_price_and_preference_accuracy: 0.2555 - out_quality_and_appearance_accuracy: 0.3405 - val_loss: 5.6542 - val_out_aspect_accuracy: 0.0101 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.6980 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5376
# Epoch 2/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 5.8007 - out_aspect_accuracy: 0.0054 - out_author_accuracy: 0.9607 - out_content_related_accuracy: 0.6735 - out_customer_service_accuracy: 0.9709 - out_manufacture_and_distribution_accuracy: 0.9874 - out_overall_experience_accuracy: 0.7058 - out_packaging_and_delivery_accuracy: 0.6604 - out_price_and_preference_accuracy: 0.8995 - out_quality_and_appearance_accuracy: 0.5216 - val_loss: 4.7259 - val_out_aspect_accuracy: 0.0101 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7688 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7457 - val_out_packaging_and_delivery_accuracy: 0.7760 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6604
# Epoch 3/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 4.9064 - out_aspect_accuracy: 0.0070 - out_author_accuracy: 0.9533 - out_content_related_accuracy: 0.7293 - out_customer_service_accuracy: 0.9703 - out_manufacture_and_distribution_accuracy: 0.9865 - out_overall_experience_accuracy: 0.7247 - out_packaging_and_delivery_accuracy: 0.7698 - out_price_and_preference_accuracy: 0.9077 - out_quality_and_appearance_accuracy: 0.6303 - val_loss: 4.1047 - val_out_aspect_accuracy: 0.0202 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7977 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7442 - val_out_packaging_and_delivery_accuracy: 0.8194 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.7225
# Epoch 4/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 4.1487 - out_aspect_accuracy: 0.0931 - out_author_accuracy: 0.9595 - out_content_related_accuracy: 0.7768 - out_customer_service_accuracy: 0.9742 - out_manufacture_and_distribution_accuracy: 0.9879 - out_overall_experience_accuracy: 0.7365 - out_packaging_and_delivery_accuracy: 0.8135 - out_price_and_preference_accuracy: 0.9164 - out_quality_and_appearance_accuracy: 0.6842 - val_loss: 3.5874 - val_out_aspect_accuracy: 0.4581 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8006 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7514 - val_out_packaging_and_delivery_accuracy: 0.8237 - val_out_price_and_preference_accuracy: 0.9220 - val_out_quality_and_appearance_accuracy: 0.7731
# Epoch 5/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 3.6675 - out_aspect_accuracy: 0.4638 - out_author_accuracy: 0.9553 - out_content_related_accuracy: 0.7889 - out_customer_service_accuracy: 0.9725 - out_manufacture_and_distribution_accuracy: 0.9879 - out_overall_experience_accuracy: 0.7370 - out_packaging_and_delivery_accuracy: 0.8384 - out_price_and_preference_accuracy: 0.9204 - out_quality_and_appearance_accuracy: 0.7425 - val_loss: 3.2314 - val_out_aspect_accuracy: 0.5636 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8179 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7543 - val_out_packaging_and_delivery_accuracy: 0.8483 - val_out_price_and_preference_accuracy: 0.9263 - val_out_quality_and_appearance_accuracy: 0.8035
# Epoch 6/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 3.3516 - out_aspect_accuracy: 0.5572 - out_author_accuracy: 0.9549 - out_content_related_accuracy: 0.8082 - out_customer_service_accuracy: 0.9696 - out_manufacture_and_distribution_accuracy: 0.9859 - out_overall_experience_accuracy: 0.7559 - out_packaging_and_delivery_accuracy: 0.8576 - out_price_and_preference_accuracy: 0.9336 - out_quality_and_appearance_accuracy: 0.7621 - val_loss: 3.0251 - val_out_aspect_accuracy: 0.5621 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8179 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7572 - val_out_packaging_and_delivery_accuracy: 0.8627 - val_out_price_and_preference_accuracy: 0.9306 - val_out_quality_and_appearance_accuracy: 0.8136
# Epoch 7/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 3.1121 - out_aspect_accuracy: 0.5694 - out_author_accuracy: 0.9483 - out_content_related_accuracy: 0.8160 - out_customer_service_accuracy: 0.9697 - out_manufacture_and_distribution_accuracy: 0.9880 - out_overall_experience_accuracy: 0.7606 - out_packaging_and_delivery_accuracy: 0.8668 - out_price_and_preference_accuracy: 0.9277 - out_quality_and_appearance_accuracy: 0.7991 - val_loss: 2.9075 - val_out_aspect_accuracy: 0.5766 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8309 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7688 - val_out_packaging_and_delivery_accuracy: 0.8728 - val_out_price_and_preference_accuracy: 0.9364 - val_out_quality_and_appearance_accuracy: 0.8150
# Epoch 8/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 2.8722 - out_aspect_accuracy: 0.5883 - out_author_accuracy: 0.9608 - out_content_related_accuracy: 0.8326 - out_customer_service_accuracy: 0.9685 - out_manufacture_and_distribution_accuracy: 0.9872 - out_overall_experience_accuracy: 0.7900 - out_packaging_and_delivery_accuracy: 0.8685 - out_price_and_preference_accuracy: 0.9405 - out_quality_and_appearance_accuracy: 0.7987 - val_loss: 2.7859 - val_out_aspect_accuracy: 0.5751 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8425 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7717 - val_out_packaging_and_delivery_accuracy: 0.8671 - val_out_price_and_preference_accuracy: 0.9306 - val_out_quality_and_appearance_accuracy: 0.8295
# Epoch 9/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 2.7197 - out_aspect_accuracy: 0.5957 - out_author_accuracy: 0.9579 - out_content_related_accuracy: 0.8355 - out_customer_service_accuracy: 0.9747 - out_manufacture_and_distribution_accuracy: 0.9859 - out_overall_experience_accuracy: 0.7831 - out_packaging_and_delivery_accuracy: 0.8925 - out_price_and_preference_accuracy: 0.9478 - out_quality_and_appearance_accuracy: 0.8088 - val_loss: 2.7410 - val_out_aspect_accuracy: 0.6040 - val_out_author_accuracy: 0.9566 - val_out_content_related_accuracy: 0.8396 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7731 - val_out_packaging_and_delivery_accuracy: 0.8540 - val_out_price_and_preference_accuracy: 0.9321 - val_out_quality_and_appearance_accuracy: 0.8237
# Epoch 10/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 2.5329 - out_aspect_accuracy: 0.6004 - out_author_accuracy: 0.9581 - out_content_related_accuracy: 0.8552 - out_customer_service_accuracy: 0.9686 - out_manufacture_and_distribution_accuracy: 0.9870 - out_overall_experience_accuracy: 0.8057 - out_packaging_and_delivery_accuracy: 0.9043 - out_price_and_preference_accuracy: 0.9445 - out_quality_and_appearance_accuracy: 0.8306 - val_loss: 2.6652 - val_out_aspect_accuracy: 0.5882 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8512 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7876 - val_out_packaging_and_delivery_accuracy: 0.8642 - val_out_price_and_preference_accuracy: 0.9364 - val_out_quality_and_appearance_accuracy: 0.8309
# Epoch 11/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 2.3827 - out_aspect_accuracy: 0.6226 - out_author_accuracy: 0.9543 - out_content_related_accuracy: 0.8658 - out_customer_service_accuracy: 0.9725 - out_manufacture_and_distribution_accuracy: 0.9861 - out_overall_experience_accuracy: 0.8130 - out_packaging_and_delivery_accuracy: 0.9055 - out_price_and_preference_accuracy: 0.9528 - out_quality_and_appearance_accuracy: 0.8421 - val_loss: 2.6228 - val_out_aspect_accuracy: 0.5939 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8396 - val_out_customer_service_accuracy: 0.9740 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7803 - val_out_packaging_and_delivery_accuracy: 0.8743 - val_out_price_and_preference_accuracy: 0.9393 - val_out_quality_and_appearance_accuracy: 0.8454
# Epoch 12/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 2.3234 - out_aspect_accuracy: 0.6235 - out_author_accuracy: 0.9599 - out_content_related_accuracy: 0.8605 - out_customer_service_accuracy: 0.9709 - out_manufacture_and_distribution_accuracy: 0.9874 - out_overall_experience_accuracy: 0.8148 - out_packaging_and_delivery_accuracy: 0.9064 - out_price_and_preference_accuracy: 0.9538 - out_quality_and_appearance_accuracy: 0.8514 - val_loss: 2.6048 - val_out_aspect_accuracy: 0.6026 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8497 - val_out_customer_service_accuracy: 0.9740 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7890 - val_out_packaging_and_delivery_accuracy: 0.8786 - val_out_price_and_preference_accuracy: 0.9393 - val_out_quality_and_appearance_accuracy: 0.8526
# Epoch 13/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 2.1470 - out_aspect_accuracy: 0.6320 - out_author_accuracy: 0.9557 - out_content_related_accuracy: 0.8785 - out_customer_service_accuracy: 0.9766 - out_manufacture_and_distribution_accuracy: 0.9886 - out_overall_experience_accuracy: 0.8322 - out_packaging_and_delivery_accuracy: 0.9129 - out_price_and_preference_accuracy: 0.9537 - out_quality_and_appearance_accuracy: 0.8608 - val_loss: 2.5834 - val_out_aspect_accuracy: 0.6069 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8497 - val_out_customer_service_accuracy: 0.9754 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7803 - val_out_packaging_and_delivery_accuracy: 0.8714 - val_out_price_and_preference_accuracy: 0.9408 - val_out_quality_and_appearance_accuracy: 0.8497
# Epoch 14/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 1.9988 - out_aspect_accuracy: 0.6398 - out_author_accuracy: 0.9605 - out_content_related_accuracy: 0.8851 - out_customer_service_accuracy: 0.9760 - out_manufacture_and_distribution_accuracy: 0.9887 - out_overall_experience_accuracy: 0.8544 - out_packaging_and_delivery_accuracy: 0.9239 - out_price_and_preference_accuracy: 0.9518 - out_quality_and_appearance_accuracy: 0.8722 - val_loss: 2.5610 - val_out_aspect_accuracy: 0.5766 - val_out_author_accuracy: 0.9566 - val_out_content_related_accuracy: 0.8512 - val_out_customer_service_accuracy: 0.9783 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7731 - val_out_packaging_and_delivery_accuracy: 0.8772 - val_out_price_and_preference_accuracy: 0.9436 - val_out_quality_and_appearance_accuracy: 0.8396
# Epoch 15/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 1.9375 - out_aspect_accuracy: 0.6317 - out_author_accuracy: 0.9585 - out_content_related_accuracy: 0.8858 - out_customer_service_accuracy: 0.9764 - out_manufacture_and_distribution_accuracy: 0.9875 - out_overall_experience_accuracy: 0.8643 - out_packaging_and_delivery_accuracy: 0.9272 - out_price_and_preference_accuracy: 0.9637 - out_quality_and_appearance_accuracy: 0.8750 - val_loss: 2.5428 - val_out_aspect_accuracy: 0.6185 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8569 - val_out_customer_service_accuracy: 0.9769 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7847 - val_out_packaging_and_delivery_accuracy: 0.8844 - val_out_price_and_preference_accuracy: 0.9422 - val_out_quality_and_appearance_accuracy: 0.8468
# Epoch 16/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 1.8785 - out_aspect_accuracy: 0.6506 - out_author_accuracy: 0.9613 - out_content_related_accuracy: 0.9016 - out_customer_service_accuracy: 0.9702 - out_manufacture_and_distribution_accuracy: 0.9852 - out_overall_experience_accuracy: 0.8642 - out_packaging_and_delivery_accuracy: 0.9345 - out_price_and_preference_accuracy: 0.9649 - out_quality_and_appearance_accuracy: 0.8756 - val_loss: 2.5431 - val_out_aspect_accuracy: 0.6012 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8526 - val_out_customer_service_accuracy: 0.9783 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7775 - val_out_packaging_and_delivery_accuracy: 0.8801 - val_out_price_and_preference_accuracy: 0.9408 - val_out_quality_and_appearance_accuracy: 0.8512
# Epoch 17/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 1.7401 - out_aspect_accuracy: 0.6481 - out_author_accuracy: 0.9607 - out_content_related_accuracy: 0.9063 - out_customer_service_accuracy: 0.9760 - out_manufacture_and_distribution_accuracy: 0.9884 - out_overall_experience_accuracy: 0.8803 - out_packaging_and_delivery_accuracy: 0.9389 - out_price_and_preference_accuracy: 0.9647 - out_quality_and_appearance_accuracy: 0.8820 - val_loss: 2.5933 - val_out_aspect_accuracy: 0.5910 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8512 - val_out_customer_service_accuracy: 0.9783 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7717 - val_out_packaging_and_delivery_accuracy: 0.8772 - val_out_price_and_preference_accuracy: 0.9451 - val_out_quality_and_appearance_accuracy: 0.8382
# Epoch 18/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 1.6163 - out_aspect_accuracy: 0.6692 - out_author_accuracy: 0.9645 - out_content_related_accuracy: 0.9197 - out_customer_service_accuracy: 0.9709 - out_manufacture_and_distribution_accuracy: 0.9880 - out_overall_experience_accuracy: 0.8827 - out_packaging_and_delivery_accuracy: 0.9366 - out_price_and_preference_accuracy: 0.9671 - out_quality_and_appearance_accuracy: 0.9034 - val_loss: 2.5324 - val_out_aspect_accuracy: 0.5968 - val_out_author_accuracy: 0.9566 - val_out_content_related_accuracy: 0.8526 - val_out_customer_service_accuracy: 0.9783 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7890 - val_out_packaging_and_delivery_accuracy: 0.8772 - val_out_price_and_preference_accuracy: 0.9422 - val_out_quality_and_appearance_accuracy: 0.8324
# Epoch 19/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 1.5158 - out_aspect_accuracy: 0.6695 - out_author_accuracy: 0.9657 - out_content_related_accuracy: 0.9196 - out_customer_service_accuracy: 0.9746 - out_manufacture_and_distribution_accuracy: 0.9877 - out_overall_experience_accuracy: 0.8956 - out_packaging_and_delivery_accuracy: 0.9494 - out_price_and_preference_accuracy: 0.9719 - out_quality_and_appearance_accuracy: 0.9054 - val_loss: 2.5903 - val_out_aspect_accuracy: 0.5954 - val_out_author_accuracy: 0.9595 - val_out_content_related_accuracy: 0.8598 - val_out_customer_service_accuracy: 0.9783 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7861 - val_out_packaging_and_delivery_accuracy: 0.8743 - val_out_price_and_preference_accuracy: 0.9494 - val_out_quality_and_appearance_accuracy: 0.8353
# Epoch 20/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 1.5420 - out_aspect_accuracy: 0.6675 - out_author_accuracy: 0.9632 - out_content_related_accuracy: 0.9160 - out_customer_service_accuracy: 0.9752 - out_manufacture_and_distribution_accuracy: 0.9867 - out_overall_experience_accuracy: 0.8968 - out_packaging_and_delivery_accuracy: 0.9454 - out_price_and_preference_accuracy: 0.9664 - out_quality_and_appearance_accuracy: 0.9025 - val_loss: 2.5991 - val_out_aspect_accuracy: 0.6113 - val_out_author_accuracy: 0.9581 - val_out_content_related_accuracy: 0.8642 - val_out_customer_service_accuracy: 0.9754 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7948 - val_out_packaging_and_delivery_accuracy: 0.8772 - val_out_price_and_preference_accuracy: 0.9408 - val_out_quality_and_appearance_accuracy: 0.8324
# Epoch 21/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - loss: 1.3691 - out_aspect_accuracy: 0.6710 - out_author_accuracy: 0.9673 - out_content_related_accuracy: 0.9253 - out_customer_service_accuracy: 0.9754 - out_manufacture_and_distribution_accuracy: 0.9893 - out_overall_experience_accuracy: 0.9065 - out_packaging_and_delivery_accuracy: 0.9438 - out_price_and_preference_accuracy: 0.9766 - out_quality_and_appearance_accuracy: 0.9155 - val_loss: 2.6574 - val_out_aspect_accuracy: 0.6084 - val_out_author_accuracy: 0.9581 - val_out_content_related_accuracy: 0.8569 - val_out_customer_service_accuracy: 0.9783 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7818 - val_out_packaging_and_delivery_accuracy: 0.8829 - val_out_price_and_preference_accuracy: 0.9509 - val_out_quality_and_appearance_accuracy: 0.8280
# Epoch 21: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(padded_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step

# %%
pred_aspect_test = round(pd.DataFrame(pred_test[0]), 0)
aspect_true = label_aspect_test.flatten()
aspect_predict = pred_aspect_test.values.flatten()

weighted_f1_aspect = f1_score(aspect_true, aspect_predict, average='weighted')
print(f'Weighted F1 Score for aspect detection: {weighted_f1_aspect}')
# Out:
# Weighted F1 Score for aspect detection: 0.9045389657179955

# %%
pred_content_related_test = np.where(np.argmax(pred_test[1], axis=1)==3, -1, np.argmax(pred_test[1], axis=1))
pred_author_test = np.where(np.argmax(pred_test[2], axis=1)==3, -1, np.argmax(pred_test[2], axis=1))
pred_quality_and_appearance_test = np.where(np.argmax(pred_test[3], axis=1)==3, -1, np.argmax(pred_test[3], axis=1))
pred_manufacture_and_distribution_test = np.where(np.argmax(pred_test[4], axis=1)==3, -1, np.argmax(pred_test[4], axis=1))
pred_packaging_and_delivery_test = np.where(np.argmax(pred_test[5], axis=1)==3, -1, np.argmax(pred_test[5], axis=1))
pred_price_and_preference_test = np.where(np.argmax(pred_test[6], axis=1)==3, -1, np.argmax(pred_test[6], axis=1))
pred_customer_service_test = np.where(np.argmax(pred_test[7], axis=1)==3, -1, np.argmax(pred_test[7], axis=1))
pred_overall_experience_test = np.where(np.argmax(pred_test[8], axis=1)==3, -1, np.argmax(pred_test[8], axis=1))

predict_test = pd.DataFrame({
    'content_related': pred_content_related_test,
    'author': pred_author_test,
    'quality_and_appearance': pred_quality_and_appearance_test,
    'manufacture_and_distribution': pred_manufacture_and_distribution_test,
    'packaging_and_delivery': pred_packaging_and_delivery_test,
    'price_and_preference': pred_price_and_preference_test,
    'customer_service': pred_customer_service_test,
    'overall_experience': pred_overall_experience_test
})

sentiment_true = df_test.iloc[:, 1:].values.flatten()
sentiment_predict = predict_test.values.flatten()

weighted_f1_sentiment = f1_score(sentiment_true, sentiment_predict, average='weighted')
print(f'Weighted F1 Score for sentiment classification: {weighted_f1_sentiment}')
# Out:
# Weighted F1 Score for sentiment classification: 0.8949503218277929

# %%
df_true = pd.DataFrame(label_aspect_test, columns=['content_related', 'author', 'quality_and_appearance', 'manufacture_and_distribution', 'packaging_and_delivery', 'price_and_preference', 'customer_service', 'overall_experience'])
df_pred = pd.DataFrame(pred_aspect_test.values, columns=['content_related', 'author', 'quality_and_appearance', 'manufacture_and_distribution', 'packaging_and_delivery', 'price_and_preference', 'customer_service', 'overall_experience'])

for aspect in ['content_related', 'author', 'quality_and_appearance', 'manufacture_and_distribution', 'packaging_and_delivery', 'price_and_preference', 'customer_service', 'overall_experience']:
    print(f'Classification report for aspect: {aspect}\n')
    print(classification_report(df_true[aspect], df_pred[aspect], digits=5))
    print()
# Out:
# Classification report for aspect: content_related
#
#               precision    recall  f1-score   support
#
#            0    0.90476   0.88079   0.89262       453
#            1    0.78486   0.82427   0.80408       239
#
#     accuracy                        0.86127       692
#    macro avg    0.84481   0.85253   0.84835       692
# weighted avg    0.86335   0.86127   0.86204       692
#
#
# Classification report for aspect: author
#
#               precision    recall  f1-score   support
#
#            0    0.96377   0.99850   0.98083       666
#            1    0.50000   0.03846   0.07143        26
#
#     accuracy                        0.96243       692
#    macro avg    0.73188   0.51848   0.52613       692
# weighted avg    0.94634   0.96243   0.94666       692
#
#
# Classification report for aspect: quality_and_appearance
#
#               precision    recall  f1-score   support
#
#            0    0.86735   0.83062   0.84859       307
#            1    0.86935   0.89870   0.88378       385
#
#     accuracy                        0.86850       692
#    macro avg    0.86835   0.86466   0.86618       692
# weighted avg    0.86846   0.86850   0.86817       692
#
#
# Classification report for aspect: manufacture_and_distribution
#
#               precision    recall  f1-score   support
#
#            0    0.97977   1.00000   0.98978       678
#            1    0.00000   0.00000   0.00000        14
#
#     accuracy                        0.97977       692
#    macro avg    0.48988   0.50000   0.49489       692
# weighted avg    0.95995   0.97977   0.96976       692
#
#
# Classification report for aspect: packaging_and_delivery
#
#               precision    recall  f1-score   support
#
#            0    0.93923   0.91644   0.92769       371
#            1    0.90606   0.93146   0.91859       321
#
#     accuracy                        0.92341       692
#    macro avg    0.92264   0.92395   0.92314       692
# weighted avg    0.92384   0.92341   0.92347       692
#
#
# Classification report for aspect: price_and_preference
#
#               precision    recall  f1-score   support
#
#            0    0.92353   0.99683   0.95878       630
#            1    0.83333   0.16129   0.27027        62
#
#     accuracy                        0.92197       692
#    macro avg    0.87843   0.57906   0.61452       692
# weighted avg    0.91545   0.92197   0.89709       692
#
#
# Classification report for aspect: customer_service
#
#               precision    recall  f1-score   support
#
#            0    0.97110   1.00000   0.98534       672
#            1    0.00000   0.00000   0.00000        20
#
#     accuracy                        0.97110       692
#    macro avg    0.48555   0.50000   0.49267       692
# weighted avg    0.94303   0.97110   0.95686       692
#
#
# Classification report for aspect: overall_experience
#
#               precision    recall  f1-score   support
#
#            0    0.79474   0.90782   0.84752       499
#            1    0.62295   0.39378   0.48254       193
#
#     accuracy                        0.76445       692
#    macro avg    0.70884   0.65080   0.66503       692
# weighted avg    0.74683   0.76445   0.74573       692

# %%
df_true = df_test.iloc[:, 1:]
df_pred = predict_test

for aspect in ['content_related', 'author', 'quality_and_appearance', 'manufacture_and_distribution', 'packaging_and_delivery', 'price_and_preference', 'customer_service', 'overall_experience']:
    print(f'Classification report for aspect: {aspect}\n')
    print(classification_report(df_true[aspect], df_pred[aspect], digits=5))
    print()
# Out:
# Classification report for aspect: content_related
#
#               precision    recall  f1-score   support
#
#           -1    0.00000   0.00000   0.00000         0
#            0    0.90359   0.88962   0.89655       453
#            1    0.71154   0.82682   0.76486       179
#            2    0.71429   0.50000   0.58824        40
#            3    0.00000   0.00000   0.00000        20
#
#     accuracy                        0.82514       692
#    macro avg    0.46588   0.44329   0.44993       692
# weighted avg    0.81685   0.82514   0.81875       692
#
#
# Classification report for aspect: author
#
#               precision    recall  f1-score   support
#
#            0    0.96366   0.99550   0.97932       666
#            1    0.00000   0.00000   0.00000        19
#            2    0.33333   0.16667   0.22222         6
#            3    0.00000   0.00000   0.00000         1
#
#     accuracy                        0.95954       692
#    macro avg    0.32425   0.29054   0.30039       692
# weighted avg    0.93035   0.95954   0.94445       692
#
#
# Classification report for aspect: quality_and_appearance
#
#               precision    recall  f1-score   support
#
#            0    0.85350   0.87296   0.86312       307
#            1    0.83178   0.82028   0.82599       217
#            2    0.78659   0.78659   0.78659       164
#            3    0.00000   0.00000   0.00000         4
#
#     accuracy                        0.83092       692
#    macro avg    0.61797   0.61996   0.61892       692
# weighted avg    0.82590   0.83092   0.82835       692
#
#
# Classification report for aspect: manufacture_and_distribution
#
#               precision    recall  f1-score   support
#
#            0    0.97977   1.00000   0.98978       678
#            1    0.00000   0.00000   0.00000        12
#            2    0.00000   0.00000   0.00000         2
#
#     accuracy                        0.97977       692
#    macro avg    0.32659   0.33333   0.32993       692
# weighted avg    0.95995   0.97977   0.96976       692
#
#
# Classification report for aspect: packaging_and_delivery
#
#               precision    recall  f1-score   support
#
#            0    0.93207   0.92453   0.92828       371
#            1    0.88584   0.91943   0.90233       211
#            2    0.75238   0.72477   0.73832       109
#            3    0.00000   0.00000   0.00000         1
#
#     accuracy                        0.89017       692
#    macro avg    0.64257   0.64218   0.64223       692
# weighted avg    0.88832   0.89017   0.88910       692
#
#
# Classification report for aspect: price_and_preference
#
#               precision    recall  f1-score   support
#
#            0    0.95686   0.98571   0.97107       630
#            1    0.82051   0.64000   0.71910        50
#            2    0.25000   0.09091   0.13333        11
#            3    0.00000   0.00000   0.00000         1
#
#     accuracy                        0.94509       692
#    macro avg    0.50684   0.42916   0.45588       692
# weighted avg    0.93439   0.94509   0.93815       692
#
#
# Classification report for aspect: customer_service
#
#               precision    recall  f1-score   support
#
#            0    0.97671   0.99851   0.98749       672
#            1    0.66667   0.28571   0.40000         7
#            2    1.00000   0.16667   0.28571        12
#            3    0.00000   0.00000   0.00000         1
#
#     accuracy                        0.97543       692
#    macro avg    0.66084   0.36272   0.41830       692
# weighted avg    0.97257   0.97543   0.96795       692
#
#
# Classification report for aspect: overall_experience
#
#               precision    recall  f1-score   support
#
#            0    0.84261   0.87976   0.86078       499
#            1    0.65152   0.56579   0.60563       152
#            2    0.38462   0.42857   0.40541        35
#            3    0.00000   0.00000   0.00000         6
#
#     accuracy                        0.78035       692
#    macro avg    0.46969   0.46853   0.46796       692
# weighted avg    0.77017   0.78035   0.77424       692

# %%
del model

# %% [markdown]
# ## BiLSTM + BiGRU + Conv1D

# %%
with device:

    # Number of labels
    num_label = 8

    # Input layer
    inputs = Input(shape=(MAX_LENGTH,))

    # Embedding layer
    embed = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        embeddings_initializer=Constant(embedding_matrix),
        trainable=True
    )(inputs)
    
    dropout1 = SpatialDropout1D(0.2)(embed)

    lstm = Bidirectional(LSTM(units = 200, activation = 'tanh', return_sequences = True))(dropout1)
    conv_lstm = Conv1D(128, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(lstm)

    gru = Bidirectional(GRU(units = 200, activation = 'tanh', return_sequences = True))(dropout1)
    conv_gru = Conv1D(128, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(gru)


    avg_pool1 = GlobalAveragePooling1D()(conv_lstm)
    max_pool1 = GlobalMaxPooling1D()(conv_lstm)

    avg_pool2 = GlobalAveragePooling1D()(conv_gru)
    max_pool2 = GlobalMaxPooling1D()(conv_gru)


    concat = Concatenate(axis=-1)([avg_pool1, max_pool1, avg_pool2, max_pool2])
    dense1 = Dense(units = 256, activation = 'relu')(concat)
    dense2 = Dense(units = 128, activation = 'relu')(dense1)
    dropout1 = Dropout(rate = 0.2)(dense2)
    dense3 = Dense(units = 64, activation = 'relu')(dropout1)
    dense4 = Dense(units = 32, activation = 'relu')(dense3)
    
    # Output layers
    out_aspect = Dense(units=num_label, activation='sigmoid', name='out_aspect')(dense4)

    # Helper function to concatenate aspect and dense4 output
    def create_output_layer(aspect_index, name):
        aspect_slice = out_aspect[:, aspect_index:aspect_index + 1]
        concatenated = tf.keras.layers.Concatenate(axis=1)([aspect_slice, dense4])
        output_layer = Dense(units=4, activation='softmax', name=name)(concatenated)
        return output_layer

    out_content_related = create_output_layer(0, 'out_content_related')
    out_author = create_output_layer(1, 'out_author')
    out_quality_and_appearance = create_output_layer(2, 'out_quality_and_appearance')
    out_manufacture_and_distribution = create_output_layer(3, 'out_manufacture_and_distribution')
    out_packaging_and_delivery = create_output_layer(4, 'out_packaging_and_delivery')
    out_price_and_preference = create_output_layer(5, 'out_price_and_preference')
    out_customer_service = create_output_layer(6, 'out_customer_service')
    out_overall_experience = create_output_layer(7, 'out_overall_experience')

    # Define the model
    model = Model(
        inputs=inputs,
        outputs=[
            out_aspect, out_content_related, out_author, out_quality_and_appearance,
            out_manufacture_and_distribution, out_packaging_and_delivery,
            out_price_and_preference, out_customer_service, out_overall_experience
        ]
    )
    
    losses = {
        "out_aspect": "binary_crossentropy",
        "out_content_related": "categorical_crossentropy",
        "out_author": "categorical_crossentropy",
        "out_quality_and_appearance": "categorical_crossentropy",
        "out_manufacture_and_distribution": "categorical_crossentropy",
        "out_packaging_and_delivery": "categorical_crossentropy",
        "out_price_and_preference": "categorical_crossentropy",
        "out_customer_service": "categorical_crossentropy",
        "out_overall_experience": "categorical_crossentropy"
    }
 
    metrics={
        "out_aspect": 'accuracy',
        "out_content_related": 'accuracy',
        "out_author": 'accuracy',
        "out_quality_and_appearance": 'accuracy',
        "out_manufacture_and_distribution": 'accuracy',
        "out_packaging_and_delivery": 'accuracy',
        "out_price_and_preference": 'accuracy',
        "out_customer_service": 'accuracy',
        "out_overall_experience": 'accuracy'
    }
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=losses,
        metrics=metrics
    )

model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_4         │ (None, 128, 1024) │  7,684,096 │ input_layer_4[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_2 │ (None, 128, 1024) │          0 │ embedding_4[0][0] │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_4     │ (None, 128, 400)  │  1,960,000 │ spatial_dropout1… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_5     │ (None, 128, 400)  │  1,471,200 │ spatial_dropout1… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 127, 128)  │    102,528 │ bidirectional_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 127, 128)  │    102,528 │ bidirectional_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv1d_2[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ conv1d_2[0][0]    │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv1d_3[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ conv1d_3[0][0]    │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_34      │ (None, 512)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# │                     │                   │            │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 256)       │    131,328 │ concatenate_34[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 128)       │     32,896 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 64)        │      8,256 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 32)        │      2,080 │ dense_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_aspect (Dense)  │ (None, 8)         │        264 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_32         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_33         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_34         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_35         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_36         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_37         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_38         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_39         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_35      │ (None, 33)        │          0 │ get_item_32[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_36      │ (None, 33)        │          0 │ get_item_33[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_37      │ (None, 33)        │          0 │ get_item_34[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_38      │ (None, 33)        │          0 │ get_item_35[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_39      │ (None, 33)        │          0 │ get_item_36[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_40      │ (None, 33)        │          0 │ get_item_37[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_41      │ (None, 33)        │          0 │ get_item_38[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_42      │ (None, 33)        │          0 │ get_item_39[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_content_related │ (None, 4)         │        136 │ concatenate_35[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_author (Dense)  │ (None, 4)         │        136 │ concatenate_36[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_quality_and_ap… │ (None, 4)         │        136 │ concatenate_37[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_manufacture_an… │ (None, 4)         │        136 │ concatenate_38[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_packaging_and_… │ (None, 4)         │        136 │ concatenate_39[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_price_and_pref… │ (None, 4)         │        136 │ concatenate_40[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_customer_servi… │ (None, 4)         │        136 │ concatenate_41[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_overall_experi… │ (None, 4)         │        136 │ concatenate_42[0… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,496,264 (43.85 MB)
#  Trainable params: 11,496,264 (43.85 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit model
history = model.fit(
    x=padded_train,
    y={
        "out_aspect": label_aspect_train,
        "out_content_related": content_related_train,
        "out_author": author_train,
        "out_quality_and_appearance": quality_and_appearance_train,
        "out_manufacture_and_distribution": manufacture_and_distribution_train,
        "out_packaging_and_delivery": packaging_and_delivery_train,
        "out_price_and_preference": price_and_preference_train,
        "out_customer_service": customer_service_train,
        "out_overall_experience": overall_experience_train
    },
    validation_data=(
        padded_val,
        {
            "out_aspect": label_aspect_val,
            "out_content_related": content_related_val,
            "out_author": author_val,
            "out_quality_and_appearance": quality_and_appearance_val,
            "out_manufacture_and_distribution": manufacture_and_distribution_val,
            "out_packaging_and_delivery": packaging_and_delivery_val,
            "out_price_and_preference": price_and_preference_val,
            "out_customer_service": customer_service_val,
            "out_overall_experience": overall_experience_val
        }
    ),
    batch_size=BATCH_SIZE,
    epochs=100,
    callbacks=EarlyStopping(
        monitor='val_loss', 
        patience=3,
        min_delta=0.001,
        mode='min',
        verbose=1
    ),
    verbose=1
)
# Out:
# Epoch 1/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 22s 77ms/step - loss: 8.1406 - out_aspect_accuracy: 0.0032 - out_author_accuracy: 0.8676 - out_content_related_accuracy: 0.3707 - out_customer_service_accuracy: 0.9675 - out_manufacture_and_distribution_accuracy: 0.9244 - out_overall_experience_accuracy: 0.6484 - out_packaging_and_delivery_accuracy: 0.4283 - out_price_and_preference_accuracy: 0.7135 - out_quality_and_appearance_accuracy: 0.3123 - val_loss: 5.1042 - val_out_aspect_accuracy: 0.0014 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7673 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7384 - val_out_packaging_and_delivery_accuracy: 0.7601 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5564
# Epoch 2/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 5.1751 - out_aspect_accuracy: 0.0303 - out_author_accuracy: 0.9511 - out_content_related_accuracy: 0.7533 - out_customer_service_accuracy: 0.9719 - out_manufacture_and_distribution_accuracy: 0.9896 - out_overall_experience_accuracy: 0.7170 - out_packaging_and_delivery_accuracy: 0.7254 - out_price_and_preference_accuracy: 0.9166 - out_quality_and_appearance_accuracy: 0.5716 - val_loss: 4.2015 - val_out_aspect_accuracy: 0.1445 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8078 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7399 - val_out_packaging_and_delivery_accuracy: 0.7630 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6633
# Epoch 3/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 4.2346 - out_aspect_accuracy: 0.1444 - out_author_accuracy: 0.9573 - out_content_related_accuracy: 0.7970 - out_customer_service_accuracy: 0.9706 - out_manufacture_and_distribution_accuracy: 0.9878 - out_overall_experience_accuracy: 0.7242 - out_packaging_and_delivery_accuracy: 0.7852 - out_price_and_preference_accuracy: 0.9159 - out_quality_and_appearance_accuracy: 0.6943 - val_loss: 3.6622 - val_out_aspect_accuracy: 0.3179 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8035 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7529 - val_out_packaging_and_delivery_accuracy: 0.8613 - val_out_price_and_preference_accuracy: 0.9191 - val_out_quality_and_appearance_accuracy: 0.7370
# Epoch 4/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 3.6617 - out_aspect_accuracy: 0.3511 - out_author_accuracy: 0.9585 - out_content_related_accuracy: 0.8084 - out_customer_service_accuracy: 0.9686 - out_manufacture_and_distribution_accuracy: 0.9899 - out_overall_experience_accuracy: 0.7517 - out_packaging_and_delivery_accuracy: 0.8419 - out_price_and_preference_accuracy: 0.9199 - out_quality_and_appearance_accuracy: 0.7423 - val_loss: 3.3047 - val_out_aspect_accuracy: 0.5275 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8107 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7529 - val_out_packaging_and_delivery_accuracy: 0.8671 - val_out_price_and_preference_accuracy: 0.9249 - val_out_quality_and_appearance_accuracy: 0.7934
# Epoch 5/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 3.3314 - out_aspect_accuracy: 0.4963 - out_author_accuracy: 0.9583 - out_content_related_accuracy: 0.8266 - out_customer_service_accuracy: 0.9644 - out_manufacture_and_distribution_accuracy: 0.9839 - out_overall_experience_accuracy: 0.7447 - out_packaging_and_delivery_accuracy: 0.8614 - out_price_and_preference_accuracy: 0.9181 - out_quality_and_appearance_accuracy: 0.7922 - val_loss: 3.0899 - val_out_aspect_accuracy: 0.5246 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8309 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7630 - val_out_packaging_and_delivery_accuracy: 0.8685 - val_out_price_and_preference_accuracy: 0.9277 - val_out_quality_and_appearance_accuracy: 0.7977
# Epoch 6/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 2.9540 - out_aspect_accuracy: 0.5513 - out_author_accuracy: 0.9603 - out_content_related_accuracy: 0.8352 - out_customer_service_accuracy: 0.9716 - out_manufacture_and_distribution_accuracy: 0.9881 - out_overall_experience_accuracy: 0.7599 - out_packaging_and_delivery_accuracy: 0.8723 - out_price_and_preference_accuracy: 0.9271 - out_quality_and_appearance_accuracy: 0.8071 - val_loss: 2.9250 - val_out_aspect_accuracy: 0.5882 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8208 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7514 - val_out_packaging_and_delivery_accuracy: 0.8728 - val_out_price_and_preference_accuracy: 0.9379 - val_out_quality_and_appearance_accuracy: 0.8020
# Epoch 7/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 2.7370 - out_aspect_accuracy: 0.5627 - out_author_accuracy: 0.9590 - out_content_related_accuracy: 0.8412 - out_customer_service_accuracy: 0.9707 - out_manufacture_and_distribution_accuracy: 0.9878 - out_overall_experience_accuracy: 0.7809 - out_packaging_and_delivery_accuracy: 0.8907 - out_price_and_preference_accuracy: 0.9412 - out_quality_and_appearance_accuracy: 0.8170 - val_loss: 2.8413 - val_out_aspect_accuracy: 0.5506 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8367 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7717 - val_out_packaging_and_delivery_accuracy: 0.8801 - val_out_price_and_preference_accuracy: 0.9393 - val_out_quality_and_appearance_accuracy: 0.7847
# Epoch 8/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 2.5086 - out_aspect_accuracy: 0.5670 - out_author_accuracy: 0.9565 - out_content_related_accuracy: 0.8700 - out_customer_service_accuracy: 0.9720 - out_manufacture_and_distribution_accuracy: 0.9887 - out_overall_experience_accuracy: 0.7843 - out_packaging_and_delivery_accuracy: 0.9059 - out_price_and_preference_accuracy: 0.9446 - out_quality_and_appearance_accuracy: 0.8408 - val_loss: 2.7400 - val_out_aspect_accuracy: 0.5824 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8454 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7803 - val_out_packaging_and_delivery_accuracy: 0.8743 - val_out_price_and_preference_accuracy: 0.9422 - val_out_quality_and_appearance_accuracy: 0.8035
# Epoch 9/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 2.2976 - out_aspect_accuracy: 0.6021 - out_author_accuracy: 0.9621 - out_content_related_accuracy: 0.8782 - out_customer_service_accuracy: 0.9720 - out_manufacture_and_distribution_accuracy: 0.9892 - out_overall_experience_accuracy: 0.8160 - out_packaging_and_delivery_accuracy: 0.9103 - out_price_and_preference_accuracy: 0.9443 - out_quality_and_appearance_accuracy: 0.8422 - val_loss: 2.7153 - val_out_aspect_accuracy: 0.5723 - val_out_author_accuracy: 0.9552 - val_out_content_related_accuracy: 0.8439 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7847 - val_out_packaging_and_delivery_accuracy: 0.8873 - val_out_price_and_preference_accuracy: 0.9538 - val_out_quality_and_appearance_accuracy: 0.7991
# Epoch 10/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 2.1806 - out_aspect_accuracy: 0.6043 - out_author_accuracy: 0.9602 - out_content_related_accuracy: 0.8911 - out_customer_service_accuracy: 0.9729 - out_manufacture_and_distribution_accuracy: 0.9826 - out_overall_experience_accuracy: 0.8250 - out_packaging_and_delivery_accuracy: 0.9173 - out_price_and_preference_accuracy: 0.9543 - out_quality_and_appearance_accuracy: 0.8608 - val_loss: 2.6859 - val_out_aspect_accuracy: 0.5578 - val_out_author_accuracy: 0.9552 - val_out_content_related_accuracy: 0.8555 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7861 - val_out_packaging_and_delivery_accuracy: 0.8858 - val_out_price_and_preference_accuracy: 0.9523 - val_out_quality_and_appearance_accuracy: 0.8006
# Epoch 11/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 2.0269 - out_aspect_accuracy: 0.5957 - out_author_accuracy: 0.9558 - out_content_related_accuracy: 0.9056 - out_customer_service_accuracy: 0.9723 - out_manufacture_and_distribution_accuracy: 0.9875 - out_overall_experience_accuracy: 0.8368 - out_packaging_and_delivery_accuracy: 0.9299 - out_price_and_preference_accuracy: 0.9587 - out_quality_and_appearance_accuracy: 0.8649 - val_loss: 2.7214 - val_out_aspect_accuracy: 0.6012 - val_out_author_accuracy: 0.9581 - val_out_content_related_accuracy: 0.8410 - val_out_customer_service_accuracy: 0.9769 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7919 - val_out_packaging_and_delivery_accuracy: 0.8858 - val_out_price_and_preference_accuracy: 0.9451 - val_out_quality_and_appearance_accuracy: 0.8165
# Epoch 12/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 1.8703 - out_aspect_accuracy: 0.6195 - out_author_accuracy: 0.9592 - out_content_related_accuracy: 0.9145 - out_customer_service_accuracy: 0.9759 - out_manufacture_and_distribution_accuracy: 0.9862 - out_overall_experience_accuracy: 0.8455 - out_packaging_and_delivery_accuracy: 0.9267 - out_price_and_preference_accuracy: 0.9560 - out_quality_and_appearance_accuracy: 0.8925 - val_loss: 2.7899 - val_out_aspect_accuracy: 0.6142 - val_out_author_accuracy: 0.9566 - val_out_content_related_accuracy: 0.8396 - val_out_customer_service_accuracy: 0.9740 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7413 - val_out_packaging_and_delivery_accuracy: 0.8815 - val_out_price_and_preference_accuracy: 0.9451 - val_out_quality_and_appearance_accuracy: 0.7803
# Epoch 13/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - loss: 1.8135 - out_aspect_accuracy: 0.6251 - out_author_accuracy: 0.9592 - out_content_related_accuracy: 0.9191 - out_customer_service_accuracy: 0.9734 - out_manufacture_and_distribution_accuracy: 0.9899 - out_overall_experience_accuracy: 0.8538 - out_packaging_and_delivery_accuracy: 0.9321 - out_price_and_preference_accuracy: 0.9560 - out_quality_and_appearance_accuracy: 0.8811 - val_loss: 2.7884 - val_out_aspect_accuracy: 0.5910 - val_out_author_accuracy: 0.9581 - val_out_content_related_accuracy: 0.8569 - val_out_customer_service_accuracy: 0.9740 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7832 - val_out_packaging_and_delivery_accuracy: 0.8829 - val_out_price_and_preference_accuracy: 0.9480 - val_out_quality_and_appearance_accuracy: 0.7948
# Epoch 13: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(padded_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step

# %%
pred_aspect_test = round(pd.DataFrame(pred_test[0]), 0)
aspect_true = label_aspect_test.flatten()
aspect_predict = pred_aspect_test.values.flatten()

weighted_f1_aspect = f1_score(aspect_true, aspect_predict, average='weighted')
print(f'Weighted F1 Score for aspect detection: {weighted_f1_aspect}')
# Out:
# Weighted F1 Score for aspect detection: 0.8996756072620897

# %%
pred_content_related_test = np.where(np.argmax(pred_test[1], axis=1)==3, -1, np.argmax(pred_test[1], axis=1))
pred_author_test = np.where(np.argmax(pred_test[2], axis=1)==3, -1, np.argmax(pred_test[2], axis=1))
pred_quality_and_appearance_test = np.where(np.argmax(pred_test[3], axis=1)==3, -1, np.argmax(pred_test[3], axis=1))
pred_manufacture_and_distribution_test = np.where(np.argmax(pred_test[4], axis=1)==3, -1, np.argmax(pred_test[4], axis=1))
pred_packaging_and_delivery_test = np.where(np.argmax(pred_test[5], axis=1)==3, -1, np.argmax(pred_test[5], axis=1))
pred_price_and_preference_test = np.where(np.argmax(pred_test[6], axis=1)==3, -1, np.argmax(pred_test[6], axis=1))
pred_customer_service_test = np.where(np.argmax(pred_test[7], axis=1)==3, -1, np.argmax(pred_test[7], axis=1))
pred_overall_experience_test = np.where(np.argmax(pred_test[8], axis=1)==3, -1, np.argmax(pred_test[8], axis=1))

predict_test = pd.DataFrame({
    'content_related': pred_content_related_test,
    'author': pred_author_test,
    'quality_and_appearance': pred_quality_and_appearance_test,
    'manufacture_and_distribution': pred_manufacture_and_distribution_test,
    'packaging_and_delivery': pred_packaging_and_delivery_test,
    'price_and_preference': pred_price_and_preference_test,
    'customer_service': pred_customer_service_test,
    'overall_experience': pred_overall_experience_test
})

sentiment_true = df_test.iloc[:, 1:].values.flatten()
sentiment_predict = predict_test.values.flatten()

weighted_f1_sentiment = f1_score(sentiment_true, sentiment_predict, average='weighted')
print(f'Weighted F1 Score for sentiment classification: {weighted_f1_sentiment}')
# Out:
# Weighted F1 Score for sentiment classification: 0.888194388802672

# %%
del model
