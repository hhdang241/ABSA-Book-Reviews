# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Dropout, Concatenate, LSTM, Embedding, Bidirectional, GRU, SpatialDropout1D, Conv1D, GlobalAveragePooling1D, GlobalMaxPooling1D
from tensorflow.keras.initializers import Constant
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.losses import BinaryCrossentropy, CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, classification_report, f1_score
from sklearn.utils.class_weight import compute_class_weight

import transformers
from transformers import AutoTokenizer, AutoModel, TFAutoModel

import torch
import matplotlib.pyplot as plt
# Out:
# 2024-07-14 05:12:08.276755: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-14 05:12:08.276876: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-14 05:12:08.413673: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !sudo apt-get update
# !sudo apt-get install openjdk-11-jdk-headless -qq > /dev/null
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1581 B]
# Hit:2 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Get:3 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Hit:4 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1556 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:7 https://packages.cloud.google.com/apt google-fast-socket InRelease
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [3745 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [3895 kB]
# Get:12 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3776 kB]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1245 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [4245 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1530 kB]
# Fetched 20.2 MB in 3s (7736 kB/s)
# Reading package lists... Done

# %%
# !git clone https://github.com/hhdang241/kltn
# Out:
# Cloning into 'kltn'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 104 (delta 45), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (104/104), 3.12 MiB | 3.62 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %% [markdown]
# # Accelerator

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# Found GPU at: /device:GPU:0
# 'Tesla P100-PCIE-16GB'

# %% [markdown]
# # Import & Preprocess datasets

# %%
TRAIN_PATH = 'kltn/Data/Sách/book_reviews_train.csv'
VAL_PATH = 'kltn/Data/Sách/book_reviews_val.csv'
TEST_PATH = 'kltn/Data/Sách/book_reviews_test.csv'
MAX_LENGTH = 128
BATCH_SIZE = 32

# %%
df_train = pd.read_csv(TRAIN_PATH, encoding='utf8')
df_val = pd.read_csv(VAL_PATH, encoding='utf8')
df_test = pd.read_csv(TEST_PATH, encoding='utf8')

# %%
df_train.head(10)
# Out:
#                                               review  content_related  author  \
# 0  là tuổi_thơ Năm nay ra tập kỷ_niệm nên mình nổ...                0       0
# 1             Đóng_gói hàng rất cẩn bọc sách rất đẹp                0       0
# 2                                      rất đáng tiền                0       0
# 3            giao hang nhanh san pham dung nhu mo ta                0       0
# 4  Đóng_gói kỹ sách đẹp dù bị cấn gáy và trầy 1 t...                1       0
# 5  Mình đặt 2 cuốn hãng luật và Xứ_Cát vào buổi s...                0       0
# 6  Sách không còn gì để bàn_cãi rồi giao hàng đỉn...                0       0
# 7  Sách to và dày hơn mình nghĩ Dịch_thuật chất_l...                1       1
# 8  Sách in tốt Bìa đẹp Tuy là bìa mềm mà khổ sách...                1       0
# 9  Nội_dung sách hay đọc rất cuốn và buồn để lại ...                1       0
#
#    quality_and_appearance  manufacture_and_distribution  \
# 0                       0                             0
# 1                       1                             0
# 2                       0                             0
# 3                       0                             0
# 4                       1                             0
# 5                       1                             0
# 6                       1                             0
# 7                       3                             0
# 8                       1                             0
# 9                       2                             0
#
#    packaging_and_delivery  price_and_preference  customer_service  \
# 0                       0                     1                 0
# 1                       1                     0                 0
# 2                       0                     1                 0
# 3                       1                     0                 0
# 4                       1                     0                 0
# 5                       1                     0                 0
# 6                       1                     0                 0
# 7                       0                     1                 0
# 8                       0                     0                 0
# 9                       3                     0                 0
#
#    overall_experience
# 0                   0
# 1                   0
# 2                   0
# 3                   1
# 4                   0
# 5                   1
# 6                   1
# 7                   0
# 8                   0
# 9                   0

# %% [markdown]
# # Get labels

# %%
def get_label_aspect(df):
    
    label_aspect = df.iloc[:, 1:].values

    # Replace -1 with 0 and other values with 1
    label_aspect[label_aspect == -1] = 0
    label_aspect[label_aspect != 0] = 1

    return label_aspect


def get_label_sentiment(df):
    
    content_related = df.content_related
    author = df.author
    quality_and_appearance = df.quality_and_appearance
    manufacture_and_distribution = df.manufacture_and_distribution
    packaging_and_delivery = df.packaging_and_delivery
    price_and_preference = df.price_and_preference
    customer_service = df.customer_service
    overall_experience = df.overall_experience

    sentiment_dict = {
        'content_related': content_related, 
        'author': author,
        'quality_and_appearance': quality_and_appearance,
        'manufacture_and_distribution': manufacture_and_distribution,
        'packaging_and_delivery': packaging_and_delivery,
        'price_and_preference': price_and_preference,
        'customer_service': customer_service, 
        'overall_experience': overall_experience
    }
    
    df_sentiment = pd.DataFrame(sentiment_dict)

    return df_sentiment


def get_aspect_sentiment_label(label_dict, num_classes):
    content_related = to_categorical(label_dict['content_related'], num_classes=num_classes)
    author = to_categorical(label_dict['author'], num_classes=num_classes)
    quality_and_appearance = to_categorical(label_dict['quality_and_appearance'], num_classes=num_classes)
    manufacture_and_distribution = to_categorical(label_dict['manufacture_and_distribution'], num_classes=num_classes)
    packaging_and_delivery = to_categorical(label_dict['packaging_and_delivery'], num_classes=num_classes)
    price_and_preference = to_categorical(label_dict['price_and_preference'], num_classes=num_classes)
    customer_service = to_categorical(label_dict['customer_service'], num_classes=num_classes)
    overall_experience = to_categorical(label_dict['overall_experience'], num_classes=num_classes)
    
    return (
        content_related,
        author,
        quality_and_appearance,
        manufacture_and_distribution,
        packaging_and_delivery,
        price_and_preference,
        customer_service,
        overall_experience
    )

# %%
label_aspect_train = get_label_aspect(df_train)
label_aspect_val = get_label_aspect(df_val)
label_aspect_test = get_label_aspect(df_test)

# %%
label_sentiment_train = get_label_sentiment(df_train)
label_sentiment_val = get_label_sentiment(df_val)
label_sentiment_test = get_label_sentiment(df_test)

# %%
label_aspect_train.shape
# Out:
# (5415, 8)

# %%
label_sentiment_train.shape
# Out:
# (5415, 8)

# %%
content_related_train, author_train, quality_and_appearance_train, manufacture_and_distribution_train, packaging_and_delivery_train, price_and_preference_train, customer_service_train, overall_experience_train = get_aspect_sentiment_label(label_sentiment_train, num_classes=4)

content_related_val, author_val, quality_and_appearance_val, manufacture_and_distribution_val, packaging_and_delivery_val, price_and_preference_val, customer_service_val, overall_experience_val = get_aspect_sentiment_label(label_sentiment_val, num_classes=4)

content_related_test, author_test, quality_and_appearance_test, manufacture_and_distribution_test, packaging_and_delivery_test, price_and_preference_test, customer_service_test, overall_experience_test = get_aspect_sentiment_label(label_sentiment_test, num_classes=4)

# %% [markdown]
# # Create word embedding matrix

# %%
cmt_train = df_train['review'].astype('str').to_list()
cmt_val = df_val['review'].astype('str').to_list()
cmt_test = df_test['review'].astype('str').to_list()

# %%
#tok = Tokenizer(filters='')
#tok.fit_on_texts(cmt_train)
#tok.fit_on_texts(cmt_val)
#tok.fit_on_texts(cmt_test)

#tokenized_train = tok.texts_to_sequences(cmt_train)
#tokenized_val = tok.texts_to_sequences(cmt_val)
#tokenized_test = tok.texts_to_sequences(cmt_test)

tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-large", use_fast=False)

#padded_train = pad_sequences(tokenized_train, padding='post', maxlen=MAX_LENGTH)
#padded_val = pad_sequences(tokenized_val, padding='post', maxlen=MAX_LENGTH)
#padded_test = pad_sequences(tokenized_test, padding='post', maxlen=MAX_LENGTH)

padded_train = tokenizer(cmt_train, padding='max_length', truncation=True, max_length=MAX_LENGTH, return_tensors="np")['input_ids']
padded_val = tokenizer(cmt_val, padding='max_length', truncation=True, max_length=MAX_LENGTH, return_tensors="np")['input_ids']
padded_test = tokenizer(cmt_test, padding='max_length', truncation=True, max_length=MAX_LENGTH, return_tensors="np")['input_ids']
# Out:
# config.json:   0%|          | 0.00/558 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.13M [00:00<?, ?B/s]

# %%
padded_train
# Out:
# array([[    0,     8,  6765, ...,     1,     1,     1],
#        [    0, 55662,  1685, ...,     1,     1,     1],
#        [    0,    59,   463, ...,     1,     1,     1],
#        ...,
#        [    0,  5947,    45, ...,     1,     1,     1],
#        [    0,  6042,     7, ...,     1,     1,     1],
#        [    0,  6042,     7, ...,     1,     1,     1]])

# %%
phobert = AutoModel.from_pretrained("vinai/phobert-large", output_hidden_states=True)
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.48G [00:00<?, ?B/s]

# %%
#tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-large", use_fast=False)

# Get the vocabulary and the size of the vocabulary
vocabulary = tokenizer.get_vocab()
vocab_size = len(vocabulary)

# Get the embedding dimension
embedding_dim = phobert.embeddings.word_embeddings.embedding_dim

# Extract the embedding weights directly and convert to NumPy array
embedding_matrix = phobert.embeddings.word_embeddings.weight.detach().cpu().numpy()

# %%
embedding_matrix.shape
# Out:
# (64001, 1024)

# %% [markdown]
# # Model building

# %% [markdown]
# ## BiLSTM

# %%
with device:

    # Number of labels
    num_label = 8

    # Input layer
    inputs = Input(shape=(MAX_LENGTH,))

    # Embedding layer
    embed = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        embeddings_initializer=Constant(embedding_matrix),
        trainable=True
    )(inputs)
    
    lstm = Bidirectional(LSTM(units = 200, activation = 'tanh'))(embed)
    dense2 = Dense(units = 128, activation = 'relu')(lstm)
    dropout1 = Dropout(rate = 0.2)(dense2)
    dense3 = Dense(units = 64, activation = 'relu')(dropout1)
    dense4 = Dense(units = 32, activation = 'relu')(dense3)

    # Output layers
    out_aspect = Dense(units=num_label, activation='sigmoid', name='out_aspect')(dense4)

    # Helper function to concatenate aspect and dense4 output
    def create_output_layer(aspect_index, name):
        aspect_slice = out_aspect[:, aspect_index:aspect_index + 1]
        concatenated = tf.keras.layers.Concatenate(axis=1)([aspect_slice, dense4])
        output_layer = Dense(units=4, activation='softmax', name=name)(concatenated)
        return output_layer

    out_content_related = create_output_layer(0, 'out_content_related')
    out_author = create_output_layer(1, 'out_author')
    out_quality_and_appearance = create_output_layer(2, 'out_quality_and_appearance')
    out_manufacture_and_distribution = create_output_layer(3, 'out_manufacture_and_distribution')
    out_packaging_and_delivery = create_output_layer(4, 'out_packaging_and_delivery')
    out_price_and_preference = create_output_layer(5, 'out_price_and_preference')
    out_customer_service = create_output_layer(6, 'out_customer_service')
    out_overall_experience = create_output_layer(7, 'out_overall_experience')

    # Define the model
    model = Model(
        inputs=inputs,
        outputs=[
            out_aspect, out_content_related, out_author, out_quality_and_appearance,
            out_manufacture_and_distribution, out_packaging_and_delivery,
            out_price_and_preference, out_customer_service, out_overall_experience
        ]
    )
    
    losses = {
        "out_aspect": "binary_crossentropy",
        "out_content_related": "categorical_crossentropy",
        "out_author": "categorical_crossentropy",
        "out_quality_and_appearance": "categorical_crossentropy",
        "out_manufacture_and_distribution": "categorical_crossentropy",
        "out_packaging_and_delivery": "categorical_crossentropy",
        "out_price_and_preference": "categorical_crossentropy",
        "out_customer_service": "categorical_crossentropy",
        "out_overall_experience": "categorical_crossentropy"
    }
 
    metrics={
        "out_aspect": 'accuracy',
        "out_content_related": 'accuracy',
        "out_author": 'accuracy',
        "out_quality_and_appearance": 'accuracy',
        "out_manufacture_and_distribution": 'accuracy',
        "out_packaging_and_delivery": 'accuracy',
        "out_price_and_preference": 'accuracy',
        "out_customer_service": 'accuracy',
        "out_overall_experience": 'accuracy'
    }
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=losses,
        metrics=metrics
    )

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 128, 1024) │ 65,537,024 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 400)       │  1,960,000 │ embedding[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     51,328 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 32)        │      2,080 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_aspect (Dense)  │ (None, 8)         │        264 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 1)         │          0 │ out_aspect[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_4          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_5          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_6          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_7          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 33)        │          0 │ get_item[0][0],   │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 33)        │          0 │ get_item_1[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 33)        │          0 │ get_item_2[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 33)        │          0 │ get_item_3[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 33)        │          0 │ get_item_4[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 33)        │          0 │ get_item_5[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 33)        │          0 │ get_item_6[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 33)        │          0 │ get_item_7[0][0], │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_content_related │ (None, 4)         │        136 │ concatenate[0][0] │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_author (Dense)  │ (None, 4)         │        136 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_quality_and_ap… │ (None, 4)         │        136 │ concatenate_2[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_manufacture_an… │ (None, 4)         │        136 │ concatenate_3[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_packaging_and_… │ (None, 4)         │        136 │ concatenate_4[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_price_and_pref… │ (None, 4)         │        136 │ concatenate_5[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_customer_servi… │ (None, 4)         │        136 │ concatenate_6[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_overall_experi… │ (None, 4)         │        136 │ concatenate_7[0]… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 67,560,040 (257.72 MB)
#  Trainable params: 67,560,040 (257.72 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit model
history = model.fit(
    x=padded_train,
    y={
        "out_aspect": label_aspect_train,
        "out_content_related": content_related_train,
        "out_author": author_train,
        "out_quality_and_appearance": quality_and_appearance_train,
        "out_manufacture_and_distribution": manufacture_and_distribution_train,
        "out_packaging_and_delivery": packaging_and_delivery_train,
        "out_price_and_preference": price_and_preference_train,
        "out_customer_service": customer_service_train,
        "out_overall_experience": overall_experience_train
    },
    validation_data=(
        padded_val,
        {
            "out_aspect": label_aspect_val,
            "out_content_related": content_related_val,
            "out_author": author_val,
            "out_quality_and_appearance": quality_and_appearance_val,
            "out_manufacture_and_distribution": manufacture_and_distribution_val,
            "out_packaging_and_delivery": packaging_and_delivery_val,
            "out_price_and_preference": price_and_preference_val,
            "out_customer_service": customer_service_val,
            "out_overall_experience": overall_experience_val
        }
    ),
    batch_size=BATCH_SIZE,
    epochs=100,
    callbacks=EarlyStopping(
        monitor='val_loss', 
        patience=3,
        min_delta=0.001,
        mode='min',
        verbose=1
    ),
    verbose=1
)
# Out:
# Epoch 1/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - loss: 9.4957 - out_aspect_accuracy: 0.0484 - out_author_accuracy: 0.9513 - out_content_related_accuracy: 0.6663 - out_customer_service_accuracy: 0.7102 - out_manufacture_and_distribution_accuracy: 0.5031 - out_overall_experience_accuracy: 0.1850 - out_packaging_and_delivery_accuracy: 0.4673 - out_price_and_preference_accuracy: 0.4897 - out_quality_and_appearance_accuracy: 0.3379 - val_loss: 5.9861 - val_out_aspect_accuracy: 0.4133 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.5694 - val_out_packaging_and_delivery_accuracy: 0.4986 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.3237
# Epoch 2/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 5.9846 - out_aspect_accuracy: 0.4000 - out_author_accuracy: 0.9528 - out_content_related_accuracy: 0.6710 - out_customer_service_accuracy: 0.9659 - out_manufacture_and_distribution_accuracy: 0.9894 - out_overall_experience_accuracy: 0.6178 - out_packaging_and_delivery_accuracy: 0.4379 - out_price_and_preference_accuracy: 0.9101 - out_quality_and_appearance_accuracy: 0.3651 - val_loss: 5.0395 - val_out_aspect_accuracy: 0.4133 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.4884 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4321
# Epoch 3/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 5.2629 - out_aspect_accuracy: 0.4058 - out_author_accuracy: 0.9555 - out_content_related_accuracy: 0.6557 - out_customer_service_accuracy: 0.9701 - out_manufacture_and_distribution_accuracy: 0.9857 - out_overall_experience_accuracy: 0.7144 - out_packaging_and_delivery_accuracy: 0.5076 - out_price_and_preference_accuracy: 0.9123 - out_quality_and_appearance_accuracy: 0.4130 - val_loss: 4.7543 - val_out_aspect_accuracy: 0.4133 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.6098 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4682
# Epoch 4/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 4.7841 - out_aspect_accuracy: 0.3822 - out_author_accuracy: 0.9550 - out_content_related_accuracy: 0.6475 - out_customer_service_accuracy: 0.9734 - out_manufacture_and_distribution_accuracy: 0.9880 - out_overall_experience_accuracy: 0.7277 - out_packaging_and_delivery_accuracy: 0.6982 - out_price_and_preference_accuracy: 0.9149 - out_quality_and_appearance_accuracy: 0.4904 - val_loss: 4.4199 - val_out_aspect_accuracy: 0.4133 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6994 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7312 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5217
# Epoch 5/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 4.4400 - out_aspect_accuracy: 0.3893 - out_author_accuracy: 0.9564 - out_content_related_accuracy: 0.6801 - out_customer_service_accuracy: 0.9674 - out_manufacture_and_distribution_accuracy: 0.9871 - out_overall_experience_accuracy: 0.7197 - out_packaging_and_delivery_accuracy: 0.7391 - out_price_and_preference_accuracy: 0.9088 - out_quality_and_appearance_accuracy: 0.5586 - val_loss: 3.9790 - val_out_aspect_accuracy: 0.5419 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7673 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7673 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6113
# Epoch 6/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 3.9709 - out_aspect_accuracy: 0.4417 - out_author_accuracy: 0.9588 - out_content_related_accuracy: 0.7380 - out_customer_service_accuracy: 0.9702 - out_manufacture_and_distribution_accuracy: 0.9878 - out_overall_experience_accuracy: 0.7222 - out_packaging_and_delivery_accuracy: 0.7748 - out_price_and_preference_accuracy: 0.9112 - out_quality_and_appearance_accuracy: 0.6300 - val_loss: 3.6835 - val_out_aspect_accuracy: 0.5159 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7861 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7948 - val_out_price_and_preference_accuracy: 0.9277 - val_out_quality_and_appearance_accuracy: 0.6546
# Epoch 7/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 3.6013 - out_aspect_accuracy: 0.4788 - out_author_accuracy: 0.9602 - out_content_related_accuracy: 0.7676 - out_customer_service_accuracy: 0.9673 - out_manufacture_and_distribution_accuracy: 0.9862 - out_overall_experience_accuracy: 0.7120 - out_packaging_and_delivery_accuracy: 0.8171 - out_price_and_preference_accuracy: 0.9148 - out_quality_and_appearance_accuracy: 0.7189 - val_loss: 3.4476 - val_out_aspect_accuracy: 0.4986 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7876 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.8107 - val_out_price_and_preference_accuracy: 0.9147 - val_out_quality_and_appearance_accuracy: 0.7298
# Epoch 8/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - loss: 3.2422 - out_aspect_accuracy: 0.5295 - out_author_accuracy: 0.9545 - out_content_related_accuracy: 0.8073 - out_customer_service_accuracy: 0.9710 - out_manufacture_and_distribution_accuracy: 0.9852 - out_overall_experience_accuracy: 0.7259 - out_packaging_and_delivery_accuracy: 0.8504 - out_price_and_preference_accuracy: 0.9158 - out_quality_and_appearance_accuracy: 0.7674 - val_loss: 3.3119 - val_out_aspect_accuracy: 0.5708 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7847 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.8439 - val_out_price_and_preference_accuracy: 0.9205 - val_out_quality_and_appearance_accuracy: 0.7601
# Epoch 9/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 3.0124 - out_aspect_accuracy: 0.5691 - out_author_accuracy: 0.9549 - out_content_related_accuracy: 0.8265 - out_customer_service_accuracy: 0.9718 - out_manufacture_and_distribution_accuracy: 0.9882 - out_overall_experience_accuracy: 0.7185 - out_packaging_and_delivery_accuracy: 0.8563 - out_price_and_preference_accuracy: 0.9178 - out_quality_and_appearance_accuracy: 0.8030 - val_loss: 3.2336 - val_out_aspect_accuracy: 0.5853 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7991 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7457 - val_out_packaging_and_delivery_accuracy: 0.8468 - val_out_price_and_preference_accuracy: 0.9249 - val_out_quality_and_appearance_accuracy: 0.7645
# Epoch 10/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.7043 - out_aspect_accuracy: 0.6051 - out_author_accuracy: 0.9612 - out_content_related_accuracy: 0.8465 - out_customer_service_accuracy: 0.9697 - out_manufacture_and_distribution_accuracy: 0.9875 - out_overall_experience_accuracy: 0.7396 - out_packaging_and_delivery_accuracy: 0.8822 - out_price_and_preference_accuracy: 0.9307 - out_quality_and_appearance_accuracy: 0.8288 - val_loss: 3.1529 - val_out_aspect_accuracy: 0.5607 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7991 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7428 - val_out_packaging_and_delivery_accuracy: 0.8367 - val_out_price_and_preference_accuracy: 0.9249 - val_out_quality_and_appearance_accuracy: 0.7861
# Epoch 11/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.5277 - out_aspect_accuracy: 0.5972 - out_author_accuracy: 0.9558 - out_content_related_accuracy: 0.8629 - out_customer_service_accuracy: 0.9727 - out_manufacture_and_distribution_accuracy: 0.9889 - out_overall_experience_accuracy: 0.7422 - out_packaging_and_delivery_accuracy: 0.8938 - out_price_and_preference_accuracy: 0.9337 - out_quality_and_appearance_accuracy: 0.8441 - val_loss: 3.1173 - val_out_aspect_accuracy: 0.5723 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8121 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7514 - val_out_packaging_and_delivery_accuracy: 0.8439 - val_out_price_and_preference_accuracy: 0.9263 - val_out_quality_and_appearance_accuracy: 0.7803
# Epoch 12/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - loss: 2.3860 - out_aspect_accuracy: 0.6417 - out_author_accuracy: 0.9550 - out_content_related_accuracy: 0.8771 - out_customer_service_accuracy: 0.9717 - out_manufacture_and_distribution_accuracy: 0.9881 - out_overall_experience_accuracy: 0.7587 - out_packaging_and_delivery_accuracy: 0.8985 - out_price_and_preference_accuracy: 0.9418 - out_quality_and_appearance_accuracy: 0.8518 - val_loss: 3.0897 - val_out_aspect_accuracy: 0.5853 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8150 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7587 - val_out_packaging_and_delivery_accuracy: 0.8598 - val_out_price_and_preference_accuracy: 0.9364 - val_out_quality_and_appearance_accuracy: 0.7948
# Epoch 13/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.2193 - out_aspect_accuracy: 0.6353 - out_author_accuracy: 0.9549 - out_content_related_accuracy: 0.8898 - out_customer_service_accuracy: 0.9720 - out_manufacture_and_distribution_accuracy: 0.9865 - out_overall_experience_accuracy: 0.7916 - out_packaging_and_delivery_accuracy: 0.9061 - out_price_and_preference_accuracy: 0.9521 - out_quality_and_appearance_accuracy: 0.8588 - val_loss: 3.2273 - val_out_aspect_accuracy: 0.6127 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8049 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7327 - val_out_packaging_and_delivery_accuracy: 0.8468 - val_out_price_and_preference_accuracy: 0.9321 - val_out_quality_and_appearance_accuracy: 0.7876
# Epoch 14/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.1320 - out_aspect_accuracy: 0.6594 - out_author_accuracy: 0.9564 - out_content_related_accuracy: 0.8901 - out_customer_service_accuracy: 0.9716 - out_manufacture_and_distribution_accuracy: 0.9875 - out_overall_experience_accuracy: 0.7960 - out_packaging_and_delivery_accuracy: 0.9083 - out_price_and_preference_accuracy: 0.9561 - out_quality_and_appearance_accuracy: 0.8639 - val_loss: 3.1827 - val_out_aspect_accuracy: 0.6026 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.7962 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7370 - val_out_packaging_and_delivery_accuracy: 0.8512 - val_out_price_and_preference_accuracy: 0.9364 - val_out_quality_and_appearance_accuracy: 0.7905
# Epoch 15/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 1.9628 - out_aspect_accuracy: 0.6629 - out_author_accuracy: 0.9562 - out_content_related_accuracy: 0.9040 - out_customer_service_accuracy: 0.9676 - out_manufacture_and_distribution_accuracy: 0.9877 - out_overall_experience_accuracy: 0.8186 - out_packaging_and_delivery_accuracy: 0.9219 - out_price_and_preference_accuracy: 0.9555 - out_quality_and_appearance_accuracy: 0.8744 - val_loss: 3.2479 - val_out_aspect_accuracy: 0.5708 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8092 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7630 - val_out_packaging_and_delivery_accuracy: 0.8382 - val_out_price_and_preference_accuracy: 0.9335 - val_out_quality_and_appearance_accuracy: 0.7832
# Epoch 15: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(padded_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step

# %%
pred_aspect_test = round(pd.DataFrame(pred_test[0]), 0)
aspect_true = label_aspect_test.flatten()
aspect_predict = pred_aspect_test.values.flatten()

weighted_f1_aspect = f1_score(aspect_true, aspect_predict, average='weighted')
print(f'Weighted F1 Score for aspect detection: {weighted_f1_aspect}')
# Out:
# Weighted F1 Score for aspect detection: 0.8869102248874658

# %%
pred_content_related_test = np.where(np.argmax(pred_test[1], axis=1)==3, -1, np.argmax(pred_test[1], axis=1))
pred_author_test = np.where(np.argmax(pred_test[2], axis=1)==3, -1, np.argmax(pred_test[2], axis=1))
pred_quality_and_appearance_test = np.where(np.argmax(pred_test[3], axis=1)==3, -1, np.argmax(pred_test[3], axis=1))
pred_manufacture_and_distribution_test = np.where(np.argmax(pred_test[4], axis=1)==3, -1, np.argmax(pred_test[4], axis=1))
pred_packaging_and_delivery_test = np.where(np.argmax(pred_test[5], axis=1)==3, -1, np.argmax(pred_test[5], axis=1))
pred_price_and_preference_test = np.where(np.argmax(pred_test[6], axis=1)==3, -1, np.argmax(pred_test[6], axis=1))
pred_customer_service_test = np.where(np.argmax(pred_test[7], axis=1)==3, -1, np.argmax(pred_test[7], axis=1))
pred_overall_experience_test = np.where(np.argmax(pred_test[8], axis=1)==3, -1, np.argmax(pred_test[8], axis=1))

predict_test = pd.DataFrame({
    'content_related': pred_content_related_test,
    'author': pred_author_test,
    'quality_and_appearance': pred_quality_and_appearance_test,
    'manufacture_and_distribution': pred_manufacture_and_distribution_test,
    'packaging_and_delivery': pred_packaging_and_delivery_test,
    'price_and_preference': pred_price_and_preference_test,
    'customer_service': pred_customer_service_test,
    'overall_experience': pred_overall_experience_test
})

sentiment_true = df_test.iloc[:, 1:].values.flatten()
sentiment_predict = predict_test.values.flatten()

weighted_f1_sentiment = f1_score(sentiment_true, sentiment_predict, average='weighted')
print(f'Weighted F1 Score for sentiment classification: {weighted_f1_sentiment}')
# Out:
# Weighted F1 Score for sentiment classification: 0.8670248142649625

# %%
del model

# %% [markdown]
# ## BiLSTM + Conv1D

# %%
with device:

    # Number of labels
    num_label = 8

    # Input layer
    inputs = Input(shape=(MAX_LENGTH,))

    # Embedding layer
    embed = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        embeddings_initializer=Constant(embedding_matrix),
        trainable=True
    )(inputs)
    
    dropout1 = SpatialDropout1D(0.2)(embed)

    lstm = Bidirectional(LSTM(units = 200, activation = 'tanh', return_sequences = True))(dropout1)
    conv = Conv1D(128, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(lstm)

    avg_pool1 = GlobalAveragePooling1D()(conv)
    max_pool1 = GlobalMaxPooling1D()(conv)


    concat = Concatenate(axis=-1)([avg_pool1, max_pool1])

    dense2 = Dense(units = 128, activation = 'relu')(concat)
    dropout1 = Dropout(rate = 0.2)(dense2)
    dense3 = Dense(units = 64, activation = 'relu')(dropout1)
    dense4 = Dense(units = 32, activation = 'relu')(dense3)
    
    # Output layers
    out_aspect = Dense(units=num_label, activation='sigmoid', name='out_aspect')(dense4)

    # Helper function to concatenate aspect and dense4 output
    def create_output_layer(aspect_index, name):
        aspect_slice = out_aspect[:, aspect_index:aspect_index + 1]
        concatenated = tf.keras.layers.Concatenate(axis=1)([aspect_slice, dense4])
        output_layer = Dense(units=4, activation='softmax', name=name)(concatenated)
        return output_layer

    out_content_related = create_output_layer(0, 'out_content_related')
    out_author = create_output_layer(1, 'out_author')
    out_quality_and_appearance = create_output_layer(2, 'out_quality_and_appearance')
    out_manufacture_and_distribution = create_output_layer(3, 'out_manufacture_and_distribution')
    out_packaging_and_delivery = create_output_layer(4, 'out_packaging_and_delivery')
    out_price_and_preference = create_output_layer(5, 'out_price_and_preference')
    out_customer_service = create_output_layer(6, 'out_customer_service')
    out_overall_experience = create_output_layer(7, 'out_overall_experience')

    # Define the model
    model = Model(
        inputs=inputs,
        outputs=[
            out_aspect, out_content_related, out_author, out_quality_and_appearance,
            out_manufacture_and_distribution, out_packaging_and_delivery,
            out_price_and_preference, out_customer_service, out_overall_experience
        ]
    )
    
    losses = {
        "out_aspect": "binary_crossentropy",
        "out_content_related": "categorical_crossentropy",
        "out_author": "categorical_crossentropy",
        "out_quality_and_appearance": "categorical_crossentropy",
        "out_manufacture_and_distribution": "categorical_crossentropy",
        "out_packaging_and_delivery": "categorical_crossentropy",
        "out_price_and_preference": "categorical_crossentropy",
        "out_customer_service": "categorical_crossentropy",
        "out_overall_experience": "categorical_crossentropy"
    }
 
    metrics={
        "out_aspect": 'accuracy',
        "out_content_related": 'accuracy',
        "out_author": 'accuracy',
        "out_quality_and_appearance": 'accuracy',
        "out_manufacture_and_distribution": 'accuracy',
        "out_packaging_and_delivery": 'accuracy',
        "out_price_and_preference": 'accuracy',
        "out_customer_service": 'accuracy',
        "out_overall_experience": 'accuracy'
    }
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=losses,
        metrics=metrics
    )

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 128, 1024) │ 65,537,024 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d   │ (None, 128, 1024) │          0 │ embedding_1[0][0] │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 128, 400)  │  1,960,000 │ spatial_dropout1… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 127, 128)  │    102,528 │ bidirectional_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv1d[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ conv1d[0][0]      │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 256)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │     32,896 │ concatenate_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 32)        │      2,080 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_aspect (Dense)  │ (None, 8)         │        264 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_8          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_9          │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_10         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_11         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_12         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_13         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_14         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_15         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 33)        │          0 │ get_item_8[0][0], │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 33)        │          0 │ get_item_9[0][0], │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 33)        │          0 │ get_item_10[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 33)        │          0 │ get_item_11[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 33)        │          0 │ get_item_12[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 33)        │          0 │ get_item_13[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 33)        │          0 │ get_item_14[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 33)        │          0 │ get_item_15[0][0… │
# │ (Concatenate)       │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_content_related │ (None, 4)         │        136 │ concatenate_9[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_author (Dense)  │ (None, 4)         │        136 │ concatenate_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_quality_and_ap… │ (None, 4)         │        136 │ concatenate_11[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_manufacture_an… │ (None, 4)         │        136 │ concatenate_12[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_packaging_and_… │ (None, 4)         │        136 │ concatenate_13[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_price_and_pref… │ (None, 4)         │        136 │ concatenate_14[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_customer_servi… │ (None, 4)         │        136 │ concatenate_15[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_overall_experi… │ (None, 4)         │        136 │ concatenate_16[0… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 67,644,136 (258.04 MB)
#  Trainable params: 67,644,136 (258.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit model
history = model.fit(
    x=padded_train,
    y={
        "out_aspect": label_aspect_train,
        "out_content_related": content_related_train,
        "out_author": author_train,
        "out_quality_and_appearance": quality_and_appearance_train,
        "out_manufacture_and_distribution": manufacture_and_distribution_train,
        "out_packaging_and_delivery": packaging_and_delivery_train,
        "out_price_and_preference": price_and_preference_train,
        "out_customer_service": customer_service_train,
        "out_overall_experience": overall_experience_train
    },
    validation_data=(
        padded_val,
        {
            "out_aspect": label_aspect_val,
            "out_content_related": content_related_val,
            "out_author": author_val,
            "out_quality_and_appearance": quality_and_appearance_val,
            "out_manufacture_and_distribution": manufacture_and_distribution_val,
            "out_packaging_and_delivery": packaging_and_delivery_val,
            "out_price_and_preference": price_and_preference_val,
            "out_customer_service": customer_service_val,
            "out_overall_experience": overall_experience_val
        }
    ),
    batch_size=BATCH_SIZE,
    epochs=100,
    callbacks=EarlyStopping(
        monitor='val_loss', 
        patience=3,
        min_delta=0.001,
        mode='min',
        verbose=1
    ),
    verbose=1
)
# Out:
# Epoch 1/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 19s 66ms/step - loss: 9.8028 - out_aspect_accuracy: 0.0665 - out_author_accuracy: 0.4886 - out_content_related_accuracy: 0.5483 - out_customer_service_accuracy: 0.8361 - out_manufacture_and_distribution_accuracy: 0.5288 - out_overall_experience_accuracy: 0.2934 - out_packaging_and_delivery_accuracy: 0.4148 - out_price_and_preference_accuracy: 0.5882 - out_quality_and_appearance_accuracy: 0.2842 - val_loss: 5.7160 - val_out_aspect_accuracy: 0.0000e+00 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.4884 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4321
# Epoch 2/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 5.9006 - out_aspect_accuracy: 0.0137 - out_author_accuracy: 0.9528 - out_content_related_accuracy: 0.6286 - out_customer_service_accuracy: 0.9729 - out_manufacture_and_distribution_accuracy: 0.9866 - out_overall_experience_accuracy: 0.7194 - out_packaging_and_delivery_accuracy: 0.4863 - out_price_and_preference_accuracy: 0.9186 - out_quality_and_appearance_accuracy: 0.3673 - val_loss: 5.2344 - val_out_aspect_accuracy: 0.0000e+00 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.6561 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4321
# Epoch 3/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 5.2541 - out_aspect_accuracy: 0.0357 - out_author_accuracy: 0.9563 - out_content_related_accuracy: 0.6599 - out_customer_service_accuracy: 0.9723 - out_manufacture_and_distribution_accuracy: 0.9873 - out_overall_experience_accuracy: 0.7288 - out_packaging_and_delivery_accuracy: 0.6622 - out_price_and_preference_accuracy: 0.9119 - out_quality_and_appearance_accuracy: 0.4502 - val_loss: 4.6141 - val_out_aspect_accuracy: 0.0983 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6850 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7442 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4899
# Epoch 4/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 4.7053 - out_aspect_accuracy: 0.2068 - out_author_accuracy: 0.9603 - out_content_related_accuracy: 0.7031 - out_customer_service_accuracy: 0.9676 - out_manufacture_and_distribution_accuracy: 0.9860 - out_overall_experience_accuracy: 0.7261 - out_packaging_and_delivery_accuracy: 0.7432 - out_price_and_preference_accuracy: 0.9104 - out_quality_and_appearance_accuracy: 0.5231 - val_loss: 4.2424 - val_out_aspect_accuracy: 0.4566 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7861 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7442 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5376
# Epoch 5/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 4.3010 - out_aspect_accuracy: 0.4252 - out_author_accuracy: 0.9558 - out_content_related_accuracy: 0.7728 - out_customer_service_accuracy: 0.9703 - out_manufacture_and_distribution_accuracy: 0.9882 - out_overall_experience_accuracy: 0.7208 - out_packaging_and_delivery_accuracy: 0.7650 - out_price_and_preference_accuracy: 0.9076 - out_quality_and_appearance_accuracy: 0.5773 - val_loss: 4.0219 - val_out_aspect_accuracy: 0.5318 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7948 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7789 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5809
# Epoch 6/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 3.9929 - out_aspect_accuracy: 0.5266 - out_author_accuracy: 0.9549 - out_content_related_accuracy: 0.7991 - out_customer_service_accuracy: 0.9711 - out_manufacture_and_distribution_accuracy: 0.9862 - out_overall_experience_accuracy: 0.7173 - out_packaging_and_delivery_accuracy: 0.7779 - out_price_and_preference_accuracy: 0.9135 - out_quality_and_appearance_accuracy: 0.6244 - val_loss: 3.8467 - val_out_aspect_accuracy: 0.5332 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7962 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7702 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6127
# Epoch 7/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 3.7115 - out_aspect_accuracy: 0.5675 - out_author_accuracy: 0.9579 - out_content_related_accuracy: 0.8096 - out_customer_service_accuracy: 0.9726 - out_manufacture_and_distribution_accuracy: 0.9908 - out_overall_experience_accuracy: 0.7226 - out_packaging_and_delivery_accuracy: 0.7960 - out_price_and_preference_accuracy: 0.9050 - out_quality_and_appearance_accuracy: 0.6637 - val_loss: 3.5925 - val_out_aspect_accuracy: 0.5462 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8237 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7370 - val_out_packaging_and_delivery_accuracy: 0.7962 - val_out_price_and_preference_accuracy: 0.9147 - val_out_quality_and_appearance_accuracy: 0.6734
# Epoch 8/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 3.4575 - out_aspect_accuracy: 0.5459 - out_author_accuracy: 0.9601 - out_content_related_accuracy: 0.8251 - out_customer_service_accuracy: 0.9685 - out_manufacture_and_distribution_accuracy: 0.9876 - out_overall_experience_accuracy: 0.7202 - out_packaging_and_delivery_accuracy: 0.8460 - out_price_and_preference_accuracy: 0.9135 - out_quality_and_appearance_accuracy: 0.6987 - val_loss: 3.3484 - val_out_aspect_accuracy: 0.5679 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8165 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.8439 - val_out_price_and_preference_accuracy: 0.9133 - val_out_quality_and_appearance_accuracy: 0.7095
# Epoch 9/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 3.1096 - out_aspect_accuracy: 0.5974 - out_author_accuracy: 0.9558 - out_content_related_accuracy: 0.8440 - out_customer_service_accuracy: 0.9706 - out_manufacture_and_distribution_accuracy: 0.9864 - out_overall_experience_accuracy: 0.7284 - out_packaging_and_delivery_accuracy: 0.8755 - out_price_and_preference_accuracy: 0.9183 - out_quality_and_appearance_accuracy: 0.7637 - val_loss: 3.1965 - val_out_aspect_accuracy: 0.5939 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8194 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7384 - val_out_packaging_and_delivery_accuracy: 0.8569 - val_out_price_and_preference_accuracy: 0.9191 - val_out_quality_and_appearance_accuracy: 0.7702
# Epoch 10/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 2.8235 - out_aspect_accuracy: 0.6150 - out_author_accuracy: 0.9619 - out_content_related_accuracy: 0.8564 - out_customer_service_accuracy: 0.9696 - out_manufacture_and_distribution_accuracy: 0.9874 - out_overall_experience_accuracy: 0.7481 - out_packaging_and_delivery_accuracy: 0.8904 - out_price_and_preference_accuracy: 0.9175 - out_quality_and_appearance_accuracy: 0.8002 - val_loss: 3.0853 - val_out_aspect_accuracy: 0.5925 - val_out_author_accuracy: 0.9509 - val_out_content_related_accuracy: 0.8251 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7327 - val_out_packaging_and_delivery_accuracy: 0.8555 - val_out_price_and_preference_accuracy: 0.9191 - val_out_quality_and_appearance_accuracy: 0.7688
# Epoch 11/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 2.6451 - out_aspect_accuracy: 0.6221 - out_author_accuracy: 0.9567 - out_content_related_accuracy: 0.8708 - out_customer_service_accuracy: 0.9689 - out_manufacture_and_distribution_accuracy: 0.9866 - out_overall_experience_accuracy: 0.7493 - out_packaging_and_delivery_accuracy: 0.9096 - out_price_and_preference_accuracy: 0.9191 - out_quality_and_appearance_accuracy: 0.8273 - val_loss: 3.0676 - val_out_aspect_accuracy: 0.5954 - val_out_author_accuracy: 0.9494 - val_out_content_related_accuracy: 0.8194 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7269 - val_out_packaging_and_delivery_accuracy: 0.8540 - val_out_price_and_preference_accuracy: 0.9176 - val_out_quality_and_appearance_accuracy: 0.7789
# Epoch 12/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 2.5169 - out_aspect_accuracy: 0.6195 - out_author_accuracy: 0.9544 - out_content_related_accuracy: 0.8772 - out_customer_service_accuracy: 0.9734 - out_manufacture_and_distribution_accuracy: 0.9856 - out_overall_experience_accuracy: 0.7628 - out_packaging_and_delivery_accuracy: 0.9094 - out_price_and_preference_accuracy: 0.9265 - out_quality_and_appearance_accuracy: 0.8353 - val_loss: 3.0379 - val_out_aspect_accuracy: 0.6243 - val_out_author_accuracy: 0.9509 - val_out_content_related_accuracy: 0.8223 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7095 - val_out_packaging_and_delivery_accuracy: 0.8642 - val_out_price_and_preference_accuracy: 0.9220 - val_out_quality_and_appearance_accuracy: 0.7919
# Epoch 13/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 2.3099 - out_aspect_accuracy: 0.6281 - out_author_accuracy: 0.9563 - out_content_related_accuracy: 0.8834 - out_customer_service_accuracy: 0.9720 - out_manufacture_and_distribution_accuracy: 0.9885 - out_overall_experience_accuracy: 0.7698 - out_packaging_and_delivery_accuracy: 0.9165 - out_price_and_preference_accuracy: 0.9316 - out_quality_and_appearance_accuracy: 0.8556 - val_loss: 3.0253 - val_out_aspect_accuracy: 0.6142 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8150 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7370 - val_out_packaging_and_delivery_accuracy: 0.8714 - val_out_price_and_preference_accuracy: 0.9263 - val_out_quality_and_appearance_accuracy: 0.7962
# Epoch 14/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 2.2347 - out_aspect_accuracy: 0.6415 - out_author_accuracy: 0.9547 - out_content_related_accuracy: 0.8836 - out_customer_service_accuracy: 0.9718 - out_manufacture_and_distribution_accuracy: 0.9878 - out_overall_experience_accuracy: 0.7738 - out_packaging_and_delivery_accuracy: 0.9297 - out_price_and_preference_accuracy: 0.9282 - out_quality_and_appearance_accuracy: 0.8654 - val_loss: 3.2152 - val_out_aspect_accuracy: 0.5867 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8237 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7182 - val_out_packaging_and_delivery_accuracy: 0.8801 - val_out_price_and_preference_accuracy: 0.9220 - val_out_quality_and_appearance_accuracy: 0.7948
# Epoch 15/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 2.0865 - out_aspect_accuracy: 0.6316 - out_author_accuracy: 0.9604 - out_content_related_accuracy: 0.9046 - out_customer_service_accuracy: 0.9721 - out_manufacture_and_distribution_accuracy: 0.9879 - out_overall_experience_accuracy: 0.7931 - out_packaging_and_delivery_accuracy: 0.9298 - out_price_and_preference_accuracy: 0.9390 - out_quality_and_appearance_accuracy: 0.8719 - val_loss: 3.1518 - val_out_aspect_accuracy: 0.5795 - val_out_author_accuracy: 0.9566 - val_out_content_related_accuracy: 0.8078 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7312 - val_out_packaging_and_delivery_accuracy: 0.8815 - val_out_price_and_preference_accuracy: 0.9191 - val_out_quality_and_appearance_accuracy: 0.7919
# Epoch 16/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 2.0381 - out_aspect_accuracy: 0.6340 - out_author_accuracy: 0.9570 - out_content_related_accuracy: 0.8940 - out_customer_service_accuracy: 0.9692 - out_manufacture_and_distribution_accuracy: 0.9841 - out_overall_experience_accuracy: 0.8088 - out_packaging_and_delivery_accuracy: 0.9346 - out_price_and_preference_accuracy: 0.9276 - out_quality_and_appearance_accuracy: 0.8811 - val_loss: 3.2737 - val_out_aspect_accuracy: 0.5853 - val_out_author_accuracy: 0.9566 - val_out_content_related_accuracy: 0.8078 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7182 - val_out_packaging_and_delivery_accuracy: 0.8728 - val_out_price_and_preference_accuracy: 0.9205 - val_out_quality_and_appearance_accuracy: 0.7731
# Epoch 16: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(padded_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step

# %%
pred_aspect_test = round(pd.DataFrame(pred_test[0]), 0)
aspect_true = label_aspect_test.flatten()
aspect_predict = pred_aspect_test.values.flatten()

weighted_f1_aspect = f1_score(aspect_true, aspect_predict, average='weighted')
print(f'Weighted F1 Score for aspect detection: {weighted_f1_aspect}')
# Out:
# Weighted F1 Score for aspect detection: 0.8778199264019297

# %%
pred_content_related_test = np.where(np.argmax(pred_test[1], axis=1)==3, -1, np.argmax(pred_test[1], axis=1))
pred_author_test = np.where(np.argmax(pred_test[2], axis=1)==3, -1, np.argmax(pred_test[2], axis=1))
pred_quality_and_appearance_test = np.where(np.argmax(pred_test[3], axis=1)==3, -1, np.argmax(pred_test[3], axis=1))
pred_manufacture_and_distribution_test = np.where(np.argmax(pred_test[4], axis=1)==3, -1, np.argmax(pred_test[4], axis=1))
pred_packaging_and_delivery_test = np.where(np.argmax(pred_test[5], axis=1)==3, -1, np.argmax(pred_test[5], axis=1))
pred_price_and_preference_test = np.where(np.argmax(pred_test[6], axis=1)==3, -1, np.argmax(pred_test[6], axis=1))
pred_customer_service_test = np.where(np.argmax(pred_test[7], axis=1)==3, -1, np.argmax(pred_test[7], axis=1))
pred_overall_experience_test = np.where(np.argmax(pred_test[8], axis=1)==3, -1, np.argmax(pred_test[8], axis=1))

predict_test = pd.DataFrame({
    'content_related': pred_content_related_test,
    'author': pred_author_test,
    'quality_and_appearance': pred_quality_and_appearance_test,
    'manufacture_and_distribution': pred_manufacture_and_distribution_test,
    'packaging_and_delivery': pred_packaging_and_delivery_test,
    'price_and_preference': pred_price_and_preference_test,
    'customer_service': pred_customer_service_test,
    'overall_experience': pred_overall_experience_test
})

sentiment_true = df_test.iloc[:, 1:].values.flatten()
sentiment_predict = predict_test.values.flatten()

weighted_f1_sentiment = f1_score(sentiment_true, sentiment_predict, average='weighted')
print(f'Weighted F1 Score for sentiment classification: {weighted_f1_sentiment}')
# Out:
# Weighted F1 Score for sentiment classification: 0.8646717812031753

# %%
del model

# %% [markdown]
# ## BiGRU

# %%
with device:

    # Number of labels
    num_label = 8

    # Input layer
    inputs = Input(shape=(MAX_LENGTH,))

    # Embedding layer
    embed = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        embeddings_initializer=Constant(embedding_matrix),
        trainable=True
    )(inputs)
    
    lstm = Bidirectional(GRU(units = 200, activation = 'tanh'))(embed)
    dense2 = Dense(units = 128, activation = 'relu')(lstm)
    dropout1 = Dropout(rate = 0.2)(dense2)
    dense3 = Dense(units = 64, activation = 'relu')(dropout1)
    dense4 = Dense(units = 32, activation = 'relu')(dense3)
    
    # Output layers
    out_aspect = Dense(units=num_label, activation='sigmoid', name='out_aspect')(dense4)

    # Helper function to concatenate aspect and dense4 output
    def create_output_layer(aspect_index, name):
        aspect_slice = out_aspect[:, aspect_index:aspect_index + 1]
        concatenated = tf.keras.layers.Concatenate(axis=1)([aspect_slice, dense4])
        output_layer = Dense(units=4, activation='softmax', name=name)(concatenated)
        return output_layer

    out_content_related = create_output_layer(0, 'out_content_related')
    out_author = create_output_layer(1, 'out_author')
    out_quality_and_appearance = create_output_layer(2, 'out_quality_and_appearance')
    out_manufacture_and_distribution = create_output_layer(3, 'out_manufacture_and_distribution')
    out_packaging_and_delivery = create_output_layer(4, 'out_packaging_and_delivery')
    out_price_and_preference = create_output_layer(5, 'out_price_and_preference')
    out_customer_service = create_output_layer(6, 'out_customer_service')
    out_overall_experience = create_output_layer(7, 'out_overall_experience')

    # Define the model
    model = Model(
        inputs=inputs,
        outputs=[
            out_aspect, out_content_related, out_author, out_quality_and_appearance,
            out_manufacture_and_distribution, out_packaging_and_delivery,
            out_price_and_preference, out_customer_service, out_overall_experience
        ]
    )
    
    losses = {
        "out_aspect": "binary_crossentropy",
        "out_content_related": "categorical_crossentropy",
        "out_author": "categorical_crossentropy",
        "out_quality_and_appearance": "categorical_crossentropy",
        "out_manufacture_and_distribution": "categorical_crossentropy",
        "out_packaging_and_delivery": "categorical_crossentropy",
        "out_price_and_preference": "categorical_crossentropy",
        "out_customer_service": "categorical_crossentropy",
        "out_overall_experience": "categorical_crossentropy"
    }
 
    metrics={
        "out_aspect": 'accuracy',
        "out_content_related": 'accuracy',
        "out_author": 'accuracy',
        "out_quality_and_appearance": 'accuracy',
        "out_manufacture_and_distribution": 'accuracy',
        "out_packaging_and_delivery": 'accuracy',
        "out_price_and_preference": 'accuracy',
        "out_customer_service": 'accuracy',
        "out_overall_experience": 'accuracy'
    }
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=losses,
        metrics=metrics
    )

model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 128, 1024) │ 65,537,024 │ input_layer_2[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_2     │ (None, 400)       │  1,471,200 │ embedding_2[0][0] │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │     51,328 │ bidirectional_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64)        │      8,256 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 32)        │      2,080 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_aspect (Dense)  │ (None, 8)         │        264 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_16         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_17         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_18         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_19         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_20         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_21         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_22         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_23         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 33)        │          0 │ get_item_16[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 33)        │          0 │ get_item_17[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 33)        │          0 │ get_item_18[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 33)        │          0 │ get_item_19[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 33)        │          0 │ get_item_20[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 33)        │          0 │ get_item_21[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 33)        │          0 │ get_item_22[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, 33)        │          0 │ get_item_23[0][0… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_content_related │ (None, 4)         │        136 │ concatenate_17[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_author (Dense)  │ (None, 4)         │        136 │ concatenate_18[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_quality_and_ap… │ (None, 4)         │        136 │ concatenate_19[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_manufacture_an… │ (None, 4)         │        136 │ concatenate_20[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_packaging_and_… │ (None, 4)         │        136 │ concatenate_21[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_price_and_pref… │ (None, 4)         │        136 │ concatenate_22[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_customer_servi… │ (None, 4)         │        136 │ concatenate_23[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_overall_experi… │ (None, 4)         │        136 │ concatenate_24[0… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 67,071,240 (255.86 MB)
#  Trainable params: 67,071,240 (255.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit model
history = model.fit(
    x=padded_train,
    y={
        "out_aspect": label_aspect_train,
        "out_content_related": content_related_train,
        "out_author": author_train,
        "out_quality_and_appearance": quality_and_appearance_train,
        "out_manufacture_and_distribution": manufacture_and_distribution_train,
        "out_packaging_and_delivery": packaging_and_delivery_train,
        "out_price_and_preference": price_and_preference_train,
        "out_customer_service": customer_service_train,
        "out_overall_experience": overall_experience_train
    },
    validation_data=(
        padded_val,
        {
            "out_aspect": label_aspect_val,
            "out_content_related": content_related_val,
            "out_author": author_val,
            "out_quality_and_appearance": quality_and_appearance_val,
            "out_manufacture_and_distribution": manufacture_and_distribution_val,
            "out_packaging_and_delivery": packaging_and_delivery_val,
            "out_price_and_preference": price_and_preference_val,
            "out_customer_service": customer_service_val,
            "out_overall_experience": overall_experience_val
        }
    ),
    batch_size=BATCH_SIZE,
    epochs=100,
    callbacks=EarlyStopping(
        monitor='val_loss', 
        patience=3,
        min_delta=0.001,
        mode='min',
        verbose=1
    ),
    verbose=1
)
# Out:
# Epoch 1/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 16s 59ms/step - loss: 10.5126 - out_aspect_accuracy: 0.0969 - out_author_accuracy: 0.6910 - out_content_related_accuracy: 0.2734 - out_customer_service_accuracy: 0.8815 - out_manufacture_and_distribution_accuracy: 0.0898 - out_overall_experience_accuracy: 0.4553 - out_packaging_and_delivery_accuracy: 0.4576 - out_price_and_preference_accuracy: 0.5822 - out_quality_and_appearance_accuracy: 0.2475 - val_loss: 5.5713 - val_out_aspect_accuracy: 0.3194 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.4884 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4321
# Epoch 2/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 5.6447 - out_aspect_accuracy: 0.3319 - out_author_accuracy: 0.9584 - out_content_related_accuracy: 0.6456 - out_customer_service_accuracy: 0.9712 - out_manufacture_and_distribution_accuracy: 0.9863 - out_overall_experience_accuracy: 0.6869 - out_packaging_and_delivery_accuracy: 0.4982 - out_price_and_preference_accuracy: 0.9176 - out_quality_and_appearance_accuracy: 0.3913 - val_loss: 4.7951 - val_out_aspect_accuracy: 0.4191 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7341 - val_out_packaging_and_delivery_accuracy: 0.7110 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4624
# Epoch 3/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 4.9601 - out_aspect_accuracy: 0.3543 - out_author_accuracy: 0.9567 - out_content_related_accuracy: 0.6503 - out_customer_service_accuracy: 0.9704 - out_manufacture_and_distribution_accuracy: 0.9881 - out_overall_experience_accuracy: 0.7016 - out_packaging_and_delivery_accuracy: 0.6982 - out_price_and_preference_accuracy: 0.9102 - out_quality_and_appearance_accuracy: 0.4706 - val_loss: 4.4493 - val_out_aspect_accuracy: 0.3136 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7095 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5650
# Epoch 4/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 4.5836 - out_aspect_accuracy: 0.3214 - out_author_accuracy: 0.9545 - out_content_related_accuracy: 0.6557 - out_customer_service_accuracy: 0.9733 - out_manufacture_and_distribution_accuracy: 0.9865 - out_overall_experience_accuracy: 0.7221 - out_packaging_and_delivery_accuracy: 0.7131 - out_price_and_preference_accuracy: 0.9118 - out_quality_and_appearance_accuracy: 0.5614 - val_loss: 4.3750 - val_out_aspect_accuracy: 0.3049 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7327 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5607
# Epoch 5/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 4.4130 - out_aspect_accuracy: 0.3183 - out_author_accuracy: 0.9584 - out_content_related_accuracy: 0.6517 - out_customer_service_accuracy: 0.9692 - out_manufacture_and_distribution_accuracy: 0.9817 - out_overall_experience_accuracy: 0.7151 - out_packaging_and_delivery_accuracy: 0.7427 - out_price_and_preference_accuracy: 0.9141 - out_quality_and_appearance_accuracy: 0.5947 - val_loss: 4.1803 - val_out_aspect_accuracy: 0.3179 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7471 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5882
# Epoch 6/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - loss: 4.1783 - out_aspect_accuracy: 0.3236 - out_author_accuracy: 0.9594 - out_content_related_accuracy: 0.6510 - out_customer_service_accuracy: 0.9727 - out_manufacture_and_distribution_accuracy: 0.9871 - out_overall_experience_accuracy: 0.7114 - out_packaging_and_delivery_accuracy: 0.7884 - out_price_and_preference_accuracy: 0.9143 - out_quality_and_appearance_accuracy: 0.5926 - val_loss: 3.9737 - val_out_aspect_accuracy: 0.3121 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7327 - val_out_packaging_and_delivery_accuracy: 0.8064 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6185
# Epoch 7/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 3.9134 - out_aspect_accuracy: 0.3293 - out_author_accuracy: 0.9559 - out_content_related_accuracy: 0.6603 - out_customer_service_accuracy: 0.9711 - out_manufacture_and_distribution_accuracy: 0.9845 - out_overall_experience_accuracy: 0.7237 - out_packaging_and_delivery_accuracy: 0.8160 - out_price_and_preference_accuracy: 0.9103 - out_quality_and_appearance_accuracy: 0.6480 - val_loss: 3.7486 - val_out_aspect_accuracy: 0.3367 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7327 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7211 - val_out_packaging_and_delivery_accuracy: 0.8121 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6488
# Epoch 8/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 3.6405 - out_aspect_accuracy: 0.3304 - out_author_accuracy: 0.9570 - out_content_related_accuracy: 0.6792 - out_customer_service_accuracy: 0.9649 - out_manufacture_and_distribution_accuracy: 0.9898 - out_overall_experience_accuracy: 0.7253 - out_packaging_and_delivery_accuracy: 0.8440 - out_price_and_preference_accuracy: 0.9103 - out_quality_and_appearance_accuracy: 0.6960 - val_loss: 3.6017 - val_out_aspect_accuracy: 0.3613 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7457 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7153 - val_out_packaging_and_delivery_accuracy: 0.8382 - val_out_price_and_preference_accuracy: 0.9205 - val_out_quality_and_appearance_accuracy: 0.6908
# Epoch 9/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - loss: 3.4939 - out_aspect_accuracy: 0.3535 - out_author_accuracy: 0.9578 - out_content_related_accuracy: 0.7094 - out_customer_service_accuracy: 0.9715 - out_manufacture_and_distribution_accuracy: 0.9861 - out_overall_experience_accuracy: 0.7177 - out_packaging_and_delivery_accuracy: 0.8694 - out_price_and_preference_accuracy: 0.9078 - out_quality_and_appearance_accuracy: 0.7356 - val_loss: 3.5347 - val_out_aspect_accuracy: 0.4610 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7457 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7153 - val_out_packaging_and_delivery_accuracy: 0.8410 - val_out_price_and_preference_accuracy: 0.9191 - val_out_quality_and_appearance_accuracy: 0.7298
# Epoch 10/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 3.2858 - out_aspect_accuracy: 0.4179 - out_author_accuracy: 0.9559 - out_content_related_accuracy: 0.7259 - out_customer_service_accuracy: 0.9711 - out_manufacture_and_distribution_accuracy: 0.9846 - out_overall_experience_accuracy: 0.7187 - out_packaging_and_delivery_accuracy: 0.8793 - out_price_and_preference_accuracy: 0.9160 - out_quality_and_appearance_accuracy: 0.7805 - val_loss: 3.4666 - val_out_aspect_accuracy: 0.4104 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7645 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.6908 - val_out_packaging_and_delivery_accuracy: 0.8353 - val_out_price_and_preference_accuracy: 0.9205 - val_out_quality_and_appearance_accuracy: 0.7211
# Epoch 11/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 3.1350 - out_aspect_accuracy: 0.4548 - out_author_accuracy: 0.9554 - out_content_related_accuracy: 0.7420 - out_customer_service_accuracy: 0.9681 - out_manufacture_and_distribution_accuracy: 0.9879 - out_overall_experience_accuracy: 0.7153 - out_packaging_and_delivery_accuracy: 0.8907 - out_price_and_preference_accuracy: 0.9169 - out_quality_and_appearance_accuracy: 0.8076 - val_loss: 3.3596 - val_out_aspect_accuracy: 0.4523 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7673 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7052 - val_out_packaging_and_delivery_accuracy: 0.8483 - val_out_price_and_preference_accuracy: 0.9234 - val_out_quality_and_appearance_accuracy: 0.7500
# Epoch 12/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 2.9745 - out_aspect_accuracy: 0.4856 - out_author_accuracy: 0.9565 - out_content_related_accuracy: 0.7573 - out_customer_service_accuracy: 0.9728 - out_manufacture_and_distribution_accuracy: 0.9864 - out_overall_experience_accuracy: 0.7108 - out_packaging_and_delivery_accuracy: 0.9050 - out_price_and_preference_accuracy: 0.9208 - out_quality_and_appearance_accuracy: 0.8285 - val_loss: 3.3686 - val_out_aspect_accuracy: 0.4841 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7760 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7095 - val_out_packaging_and_delivery_accuracy: 0.8425 - val_out_price_and_preference_accuracy: 0.9191 - val_out_quality_and_appearance_accuracy: 0.7428
# Epoch 13/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.8573 - out_aspect_accuracy: 0.5033 - out_author_accuracy: 0.9536 - out_content_related_accuracy: 0.7726 - out_customer_service_accuracy: 0.9698 - out_manufacture_and_distribution_accuracy: 0.9833 - out_overall_experience_accuracy: 0.7166 - out_packaging_and_delivery_accuracy: 0.9102 - out_price_and_preference_accuracy: 0.9209 - out_quality_and_appearance_accuracy: 0.8467 - val_loss: 3.3647 - val_out_aspect_accuracy: 0.4812 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7861 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7124 - val_out_packaging_and_delivery_accuracy: 0.8454 - val_out_price_and_preference_accuracy: 0.9205 - val_out_quality_and_appearance_accuracy: 0.7327
# Epoch 14/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.6960 - out_aspect_accuracy: 0.5137 - out_author_accuracy: 0.9578 - out_content_related_accuracy: 0.7920 - out_customer_service_accuracy: 0.9727 - out_manufacture_and_distribution_accuracy: 0.9869 - out_overall_experience_accuracy: 0.7195 - out_packaging_and_delivery_accuracy: 0.9058 - out_price_and_preference_accuracy: 0.9244 - out_quality_and_appearance_accuracy: 0.8595 - val_loss: 3.3434 - val_out_aspect_accuracy: 0.4870 - val_out_author_accuracy: 0.9509 - val_out_content_related_accuracy: 0.7977 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7110 - val_out_packaging_and_delivery_accuracy: 0.8439 - val_out_price_and_preference_accuracy: 0.9191 - val_out_quality_and_appearance_accuracy: 0.7688
# Epoch 15/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.5687 - out_aspect_accuracy: 0.5188 - out_author_accuracy: 0.9564 - out_content_related_accuracy: 0.8149 - out_customer_service_accuracy: 0.9689 - out_manufacture_and_distribution_accuracy: 0.9868 - out_overall_experience_accuracy: 0.7218 - out_packaging_and_delivery_accuracy: 0.9097 - out_price_and_preference_accuracy: 0.9227 - out_quality_and_appearance_accuracy: 0.8780 - val_loss: 3.3703 - val_out_aspect_accuracy: 0.4928 - val_out_author_accuracy: 0.9509 - val_out_content_related_accuracy: 0.8035 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7023 - val_out_packaging_and_delivery_accuracy: 0.8324 - val_out_price_and_preference_accuracy: 0.9220 - val_out_quality_and_appearance_accuracy: 0.7702
# Epoch 16/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 2.5094 - out_aspect_accuracy: 0.5238 - out_author_accuracy: 0.9627 - out_content_related_accuracy: 0.8215 - out_customer_service_accuracy: 0.9703 - out_manufacture_and_distribution_accuracy: 0.9863 - out_overall_experience_accuracy: 0.7291 - out_packaging_and_delivery_accuracy: 0.9075 - out_price_and_preference_accuracy: 0.9300 - out_quality_and_appearance_accuracy: 0.8829 - val_loss: 3.3887 - val_out_aspect_accuracy: 0.5072 - val_out_author_accuracy: 0.9509 - val_out_content_related_accuracy: 0.8035 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7153 - val_out_packaging_and_delivery_accuracy: 0.8353 - val_out_price_and_preference_accuracy: 0.9205 - val_out_quality_and_appearance_accuracy: 0.7659
# Epoch 17/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 2.4245 - out_aspect_accuracy: 0.5349 - out_author_accuracy: 0.9608 - out_content_related_accuracy: 0.8363 - out_customer_service_accuracy: 0.9718 - out_manufacture_and_distribution_accuracy: 0.9854 - out_overall_experience_accuracy: 0.7318 - out_packaging_and_delivery_accuracy: 0.9190 - out_price_and_preference_accuracy: 0.9304 - out_quality_and_appearance_accuracy: 0.8921 - val_loss: 3.3733 - val_out_aspect_accuracy: 0.4899 - val_out_author_accuracy: 0.9509 - val_out_content_related_accuracy: 0.8165 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7009 - val_out_packaging_and_delivery_accuracy: 0.8353 - val_out_price_and_preference_accuracy: 0.9118 - val_out_quality_and_appearance_accuracy: 0.7514
# Epoch 17: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(padded_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
pred_aspect_test = round(pd.DataFrame(pred_test[0]), 0)
aspect_true = label_aspect_test.flatten()
aspect_predict = pred_aspect_test.values.flatten()

weighted_f1_aspect = f1_score(aspect_true, aspect_predict, average='weighted')
print(f'Weighted F1 Score for aspect detection: {weighted_f1_aspect}')
# Out:
# Weighted F1 Score for aspect detection: 0.8646809756505044

# %%
pred_content_related_test = np.where(np.argmax(pred_test[1], axis=1)==3, -1, np.argmax(pred_test[1], axis=1))
pred_author_test = np.where(np.argmax(pred_test[2], axis=1)==3, -1, np.argmax(pred_test[2], axis=1))
pred_quality_and_appearance_test = np.where(np.argmax(pred_test[3], axis=1)==3, -1, np.argmax(pred_test[3], axis=1))
pred_manufacture_and_distribution_test = np.where(np.argmax(pred_test[4], axis=1)==3, -1, np.argmax(pred_test[4], axis=1))
pred_packaging_and_delivery_test = np.where(np.argmax(pred_test[5], axis=1)==3, -1, np.argmax(pred_test[5], axis=1))
pred_price_and_preference_test = np.where(np.argmax(pred_test[6], axis=1)==3, -1, np.argmax(pred_test[6], axis=1))
pred_customer_service_test = np.where(np.argmax(pred_test[7], axis=1)==3, -1, np.argmax(pred_test[7], axis=1))
pred_overall_experience_test = np.where(np.argmax(pred_test[8], axis=1)==3, -1, np.argmax(pred_test[8], axis=1))

predict_test = pd.DataFrame({
    'content_related': pred_content_related_test,
    'author': pred_author_test,
    'quality_and_appearance': pred_quality_and_appearance_test,
    'manufacture_and_distribution': pred_manufacture_and_distribution_test,
    'packaging_and_delivery': pred_packaging_and_delivery_test,
    'price_and_preference': pred_price_and_preference_test,
    'customer_service': pred_customer_service_test,
    'overall_experience': pred_overall_experience_test
})

sentiment_true = df_test.iloc[:, 1:].values.flatten()
sentiment_predict = predict_test.values.flatten()

weighted_f1_sentiment = f1_score(sentiment_true, sentiment_predict, average='weighted')
print(f'Weighted F1 Score for sentiment classification: {weighted_f1_sentiment}')
# Out:
# Weighted F1 Score for sentiment classification: 0.8512215527270572

# %%
del model

# %% [markdown]
# ## BiGRU + Conv1D

# %%
class ApplyAttentionMask(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(ApplyAttentionMask, self).__init__(**kwargs)

    def call(self, inputs):
        embed, attention_mask = inputs
        # Expand attention_mask to match the embedding dimensions
        attention_mask = tf.expand_dims(tf.cast(attention_mask, tf.float32), -1)
        # Apply attention mask to embeddings
        masked_embed = tf.multiply(embed, attention_mask)
        return masked_embed

# %%
with device:

    # Number of labels
    num_label = 8

    # Input layer
    inputs = Input(shape=(MAX_LENGTH,))

    # Embedding layer
    embed = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        embeddings_initializer=Constant(embedding_matrix),
        trainable=True
    )(inputs)
    
    dropout1 = SpatialDropout1D(0.2)(embed)

    lstm = Bidirectional(GRU(units = 200, activation = 'tanh', return_sequences = True))(dropout1)
    conv = Conv1D(128, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(lstm)

    avg_pool1 = GlobalAveragePooling1D()(conv)
    max_pool1 = GlobalMaxPooling1D()(conv)


    concat = Concatenate(axis=-1)([avg_pool1, max_pool1])

    dense2 = Dense(units = 128, activation = 'relu')(concat)
    dropout1 = Dropout(rate = 0.2)(dense2)
    dense3 = Dense(units = 64, activation = 'relu')(dropout1)
    dense4 = Dense(units = 32, activation = 'relu')(dense3)
    
    # Output layers
    out_aspect = Dense(units=num_label, activation='sigmoid', name='out_aspect')(dense4)

    # Helper function to concatenate aspect and dense4 output
    def create_output_layer(aspect_index, name):
        aspect_slice = out_aspect[:, aspect_index:aspect_index + 1]
        concatenated = tf.keras.layers.Concatenate(axis=1)([aspect_slice, dense4])
        output_layer = Dense(units=4, activation='softmax', name=name)(concatenated)
        return output_layer

    out_content_related = create_output_layer(0, 'out_content_related')
    out_author = create_output_layer(1, 'out_author')
    out_quality_and_appearance = create_output_layer(2, 'out_quality_and_appearance')
    out_manufacture_and_distribution = create_output_layer(3, 'out_manufacture_and_distribution')
    out_packaging_and_delivery = create_output_layer(4, 'out_packaging_and_delivery')
    out_price_and_preference = create_output_layer(5, 'out_price_and_preference')
    out_customer_service = create_output_layer(6, 'out_customer_service')
    out_overall_experience = create_output_layer(7, 'out_overall_experience')

    # Define the model
    model = Model(
        inputs=inputs,
        outputs=[
            out_aspect, out_content_related, out_author, out_quality_and_appearance,
            out_manufacture_and_distribution, out_packaging_and_delivery,
            out_price_and_preference, out_customer_service, out_overall_experience
        ]
    )
    
    losses = {
        "out_aspect": "binary_crossentropy",
        "out_content_related": "categorical_crossentropy",
        "out_author": "categorical_crossentropy",
        "out_quality_and_appearance": "categorical_crossentropy",
        "out_manufacture_and_distribution": "categorical_crossentropy",
        "out_packaging_and_delivery": "categorical_crossentropy",
        "out_price_and_preference": "categorical_crossentropy",
        "out_customer_service": "categorical_crossentropy",
        "out_overall_experience": "categorical_crossentropy"
    }
 
    metrics={
        "out_aspect": 'accuracy',
        "out_content_related": 'accuracy',
        "out_author": 'accuracy',
        "out_quality_and_appearance": 'accuracy',
        "out_manufacture_and_distribution": 'accuracy',
        "out_packaging_and_delivery": 'accuracy',
        "out_price_and_preference": 'accuracy',
        "out_customer_service": 'accuracy',
        "out_overall_experience": 'accuracy'
    }
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=losses,
        metrics=metrics
    )

model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, 128, 1024) │ 65,537,024 │ input_layer_3[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_1 │ (None, 128, 1024) │          0 │ embedding_3[0][0] │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_3     │ (None, 128, 400)  │  1,471,200 │ spatial_dropout1… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 127, 128)  │    102,528 │ bidirectional_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv1d_1[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ conv1d_1[0][0]    │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_25      │ (None, 256)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 128)       │     32,896 │ concatenate_25[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 64)        │      8,256 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 32)        │      2,080 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_aspect (Dense)  │ (None, 8)         │        264 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_24         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_25         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_26         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_27         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_28         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_29         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_30         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_31         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, 33)        │          0 │ get_item_24[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_27      │ (None, 33)        │          0 │ get_item_25[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_28      │ (None, 33)        │          0 │ get_item_26[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_29      │ (None, 33)        │          0 │ get_item_27[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_30      │ (None, 33)        │          0 │ get_item_28[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_31      │ (None, 33)        │          0 │ get_item_29[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_32      │ (None, 33)        │          0 │ get_item_30[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_33      │ (None, 33)        │          0 │ get_item_31[0][0… │
# │ (Concatenate)       │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_content_related │ (None, 4)         │        136 │ concatenate_26[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_author (Dense)  │ (None, 4)         │        136 │ concatenate_27[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_quality_and_ap… │ (None, 4)         │        136 │ concatenate_28[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_manufacture_an… │ (None, 4)         │        136 │ concatenate_29[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_packaging_and_… │ (None, 4)         │        136 │ concatenate_30[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_price_and_pref… │ (None, 4)         │        136 │ concatenate_31[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_customer_servi… │ (None, 4)         │        136 │ concatenate_32[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_overall_experi… │ (None, 4)         │        136 │ concatenate_33[0… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 67,155,336 (256.18 MB)
#  Trainable params: 67,155,336 (256.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit model
history = model.fit(
    x=padded_train,
    y={
        "out_aspect": label_aspect_train,
        "out_content_related": content_related_train,
        "out_author": author_train,
        "out_quality_and_appearance": quality_and_appearance_train,
        "out_manufacture_and_distribution": manufacture_and_distribution_train,
        "out_packaging_and_delivery": packaging_and_delivery_train,
        "out_price_and_preference": price_and_preference_train,
        "out_customer_service": customer_service_train,
        "out_overall_experience": overall_experience_train
    },
    validation_data=(
        padded_val,
        {
            "out_aspect": label_aspect_val,
            "out_content_related": content_related_val,
            "out_author": author_val,
            "out_quality_and_appearance": quality_and_appearance_val,
            "out_manufacture_and_distribution": manufacture_and_distribution_val,
            "out_packaging_and_delivery": packaging_and_delivery_val,
            "out_price_and_preference": price_and_preference_val,
            "out_customer_service": customer_service_val,
            "out_overall_experience": overall_experience_val
        }
    ),
    batch_size=BATCH_SIZE,
    epochs=100,
    callbacks=EarlyStopping(
        monitor='val_loss', 
        patience=3,
        min_delta=0.001,
        mode='min',
        verbose=1
    ),
    verbose=1
)
# Out:
# Epoch 1/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 17s 61ms/step - loss: 9.9533 - out_aspect_accuracy: 0.3056 - out_author_accuracy: 0.5229 - out_content_related_accuracy: 0.2472 - out_customer_service_accuracy: 0.4659 - out_manufacture_and_distribution_accuracy: 0.5535 - out_overall_experience_accuracy: 0.6476 - out_packaging_and_delivery_accuracy: 0.2716 - out_price_and_preference_accuracy: 0.4651 - out_quality_and_appearance_accuracy: 0.3951 - val_loss: 5.7462 - val_out_aspect_accuracy: 0.4133 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.4884 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4321
# Epoch 2/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 5.9314 - out_aspect_accuracy: 0.4252 - out_author_accuracy: 0.9545 - out_content_related_accuracy: 0.6583 - out_customer_service_accuracy: 0.9681 - out_manufacture_and_distribution_accuracy: 0.9847 - out_overall_experience_accuracy: 0.7129 - out_packaging_and_delivery_accuracy: 0.4714 - out_price_and_preference_accuracy: 0.9040 - out_quality_and_appearance_accuracy: 0.3509 - val_loss: 4.9751 - val_out_aspect_accuracy: 0.4133 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.4884 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4321
# Epoch 3/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 5.1919 - out_aspect_accuracy: 0.3932 - out_author_accuracy: 0.9605 - out_content_related_accuracy: 0.6570 - out_customer_service_accuracy: 0.9698 - out_manufacture_and_distribution_accuracy: 0.9848 - out_overall_experience_accuracy: 0.7139 - out_packaging_and_delivery_accuracy: 0.5168 - out_price_and_preference_accuracy: 0.9122 - out_quality_and_appearance_accuracy: 0.3893 - val_loss: 4.5943 - val_out_aspect_accuracy: 0.4133 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6850 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.6749 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4408
# Epoch 4/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 4.7064 - out_aspect_accuracy: 0.3710 - out_author_accuracy: 0.9576 - out_content_related_accuracy: 0.6712 - out_customer_service_accuracy: 0.9730 - out_manufacture_and_distribution_accuracy: 0.9896 - out_overall_experience_accuracy: 0.7269 - out_packaging_and_delivery_accuracy: 0.6651 - out_price_and_preference_accuracy: 0.9065 - out_quality_and_appearance_accuracy: 0.4541 - val_loss: 4.1039 - val_out_aspect_accuracy: 0.4249 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7760 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7413 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5376
# Epoch 5/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 4.2693 - out_aspect_accuracy: 0.3927 - out_author_accuracy: 0.9549 - out_content_related_accuracy: 0.7577 - out_customer_service_accuracy: 0.9684 - out_manufacture_and_distribution_accuracy: 0.9860 - out_overall_experience_accuracy: 0.7180 - out_packaging_and_delivery_accuracy: 0.7780 - out_price_and_preference_accuracy: 0.9030 - out_quality_and_appearance_accuracy: 0.5324 - val_loss: 3.8088 - val_out_aspect_accuracy: 0.4162 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7977 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7370 - val_out_packaging_and_delivery_accuracy: 0.8251 - val_out_price_and_preference_accuracy: 0.9147 - val_out_quality_and_appearance_accuracy: 0.5564
# Epoch 6/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 3.8582 - out_aspect_accuracy: 0.4386 - out_author_accuracy: 0.9536 - out_content_related_accuracy: 0.8001 - out_customer_service_accuracy: 0.9700 - out_manufacture_and_distribution_accuracy: 0.9876 - out_overall_experience_accuracy: 0.7221 - out_packaging_and_delivery_accuracy: 0.8255 - out_price_and_preference_accuracy: 0.9111 - out_quality_and_appearance_accuracy: 0.6070 - val_loss: 3.6434 - val_out_aspect_accuracy: 0.4292 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8049 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.8121 - val_out_price_and_preference_accuracy: 0.9205 - val_out_quality_and_appearance_accuracy: 0.5939
# Epoch 7/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 3.6717 - out_aspect_accuracy: 0.4803 - out_author_accuracy: 0.9544 - out_content_related_accuracy: 0.8097 - out_customer_service_accuracy: 0.9721 - out_manufacture_and_distribution_accuracy: 0.9853 - out_overall_experience_accuracy: 0.7301 - out_packaging_and_delivery_accuracy: 0.8298 - out_price_and_preference_accuracy: 0.9062 - out_quality_and_appearance_accuracy: 0.6337 - val_loss: 3.5114 - val_out_aspect_accuracy: 0.5549 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8136 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.8353 - val_out_price_and_preference_accuracy: 0.9205 - val_out_quality_and_appearance_accuracy: 0.6185
# Epoch 8/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 3.4621 - out_aspect_accuracy: 0.5277 - out_author_accuracy: 0.9572 - out_content_related_accuracy: 0.8105 - out_customer_service_accuracy: 0.9742 - out_manufacture_and_distribution_accuracy: 0.9881 - out_overall_experience_accuracy: 0.7185 - out_packaging_and_delivery_accuracy: 0.8562 - out_price_and_preference_accuracy: 0.9063 - out_quality_and_appearance_accuracy: 0.6626 - val_loss: 3.4291 - val_out_aspect_accuracy: 0.5390 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8092 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.8280 - val_out_price_and_preference_accuracy: 0.9234 - val_out_quality_and_appearance_accuracy: 0.6431
# Epoch 9/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 3.3139 - out_aspect_accuracy: 0.5483 - out_author_accuracy: 0.9545 - out_content_related_accuracy: 0.8392 - out_customer_service_accuracy: 0.9711 - out_manufacture_and_distribution_accuracy: 0.9885 - out_overall_experience_accuracy: 0.7243 - out_packaging_and_delivery_accuracy: 0.8582 - out_price_and_preference_accuracy: 0.9211 - out_quality_and_appearance_accuracy: 0.7015 - val_loss: 3.3303 - val_out_aspect_accuracy: 0.5246 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8136 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7370 - val_out_packaging_and_delivery_accuracy: 0.8454 - val_out_price_and_preference_accuracy: 0.9234 - val_out_quality_and_appearance_accuracy: 0.6749
# Epoch 10/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 3.1297 - out_aspect_accuracy: 0.5431 - out_author_accuracy: 0.9546 - out_content_related_accuracy: 0.8515 - out_customer_service_accuracy: 0.9725 - out_manufacture_and_distribution_accuracy: 0.9876 - out_overall_experience_accuracy: 0.7199 - out_packaging_and_delivery_accuracy: 0.8724 - out_price_and_preference_accuracy: 0.9297 - out_quality_and_appearance_accuracy: 0.7243 - val_loss: 3.2888 - val_out_aspect_accuracy: 0.5246 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8136 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7370 - val_out_packaging_and_delivery_accuracy: 0.8468 - val_out_price_and_preference_accuracy: 0.9234 - val_out_quality_and_appearance_accuracy: 0.6922
# Epoch 11/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - loss: 3.0115 - out_aspect_accuracy: 0.5580 - out_author_accuracy: 0.9529 - out_content_related_accuracy: 0.8583 - out_customer_service_accuracy: 0.9706 - out_manufacture_and_distribution_accuracy: 0.9862 - out_overall_experience_accuracy: 0.7350 - out_packaging_and_delivery_accuracy: 0.8773 - out_price_and_preference_accuracy: 0.9230 - out_quality_and_appearance_accuracy: 0.7395 - val_loss: 3.2013 - val_out_aspect_accuracy: 0.5043 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8251 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7457 - val_out_packaging_and_delivery_accuracy: 0.8425 - val_out_price_and_preference_accuracy: 0.9277 - val_out_quality_and_appearance_accuracy: 0.7095
# Epoch 12/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.8224 - out_aspect_accuracy: 0.5540 - out_author_accuracy: 0.9611 - out_content_related_accuracy: 0.8718 - out_customer_service_accuracy: 0.9711 - out_manufacture_and_distribution_accuracy: 0.9873 - out_overall_experience_accuracy: 0.7342 - out_packaging_and_delivery_accuracy: 0.8901 - out_price_and_preference_accuracy: 0.9313 - out_quality_and_appearance_accuracy: 0.7561 - val_loss: 3.1509 - val_out_aspect_accuracy: 0.5260 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8295 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7413 - val_out_packaging_and_delivery_accuracy: 0.8396 - val_out_price_and_preference_accuracy: 0.9292 - val_out_quality_and_appearance_accuracy: 0.7225
# Epoch 13/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.7177 - out_aspect_accuracy: 0.5711 - out_author_accuracy: 0.9599 - out_content_related_accuracy: 0.8874 - out_customer_service_accuracy: 0.9692 - out_manufacture_and_distribution_accuracy: 0.9875 - out_overall_experience_accuracy: 0.7466 - out_packaging_and_delivery_accuracy: 0.8851 - out_price_and_preference_accuracy: 0.9356 - out_quality_and_appearance_accuracy: 0.7737 - val_loss: 3.1001 - val_out_aspect_accuracy: 0.5332 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8324 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7327 - val_out_packaging_and_delivery_accuracy: 0.8497 - val_out_price_and_preference_accuracy: 0.9379 - val_out_quality_and_appearance_accuracy: 0.7370
# Epoch 14/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.5830 - out_aspect_accuracy: 0.5978 - out_author_accuracy: 0.9578 - out_content_related_accuracy: 0.8884 - out_customer_service_accuracy: 0.9704 - out_manufacture_and_distribution_accuracy: 0.9870 - out_overall_experience_accuracy: 0.7526 - out_packaging_and_delivery_accuracy: 0.8966 - out_price_and_preference_accuracy: 0.9415 - out_quality_and_appearance_accuracy: 0.7954 - val_loss: 3.1216 - val_out_aspect_accuracy: 0.5564 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8208 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7486 - val_out_packaging_and_delivery_accuracy: 0.8540 - val_out_price_and_preference_accuracy: 0.9379 - val_out_quality_and_appearance_accuracy: 0.7529
# Epoch 15/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.5398 - out_aspect_accuracy: 0.6090 - out_author_accuracy: 0.9545 - out_content_related_accuracy: 0.8872 - out_customer_service_accuracy: 0.9680 - out_manufacture_and_distribution_accuracy: 0.9852 - out_overall_experience_accuracy: 0.7584 - out_packaging_and_delivery_accuracy: 0.8990 - out_price_and_preference_accuracy: 0.9455 - out_quality_and_appearance_accuracy: 0.8183 - val_loss: 3.0629 - val_out_aspect_accuracy: 0.5520 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8208 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7572 - val_out_packaging_and_delivery_accuracy: 0.8555 - val_out_price_and_preference_accuracy: 0.9451 - val_out_quality_and_appearance_accuracy: 0.7601
# Epoch 16/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.3405 - out_aspect_accuracy: 0.6375 - out_author_accuracy: 0.9593 - out_content_related_accuracy: 0.8967 - out_customer_service_accuracy: 0.9715 - out_manufacture_and_distribution_accuracy: 0.9876 - out_overall_experience_accuracy: 0.7715 - out_packaging_and_delivery_accuracy: 0.9093 - out_price_and_preference_accuracy: 0.9546 - out_quality_and_appearance_accuracy: 0.8389 - val_loss: 3.0154 - val_out_aspect_accuracy: 0.5708 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8251 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7457 - val_out_packaging_and_delivery_accuracy: 0.8584 - val_out_price_and_preference_accuracy: 0.9451 - val_out_quality_and_appearance_accuracy: 0.8006
# Epoch 17/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.2177 - out_aspect_accuracy: 0.6498 - out_author_accuracy: 0.9564 - out_content_related_accuracy: 0.9065 - out_customer_service_accuracy: 0.9679 - out_manufacture_and_distribution_accuracy: 0.9858 - out_overall_experience_accuracy: 0.7825 - out_packaging_and_delivery_accuracy: 0.9141 - out_price_and_preference_accuracy: 0.9609 - out_quality_and_appearance_accuracy: 0.8535 - val_loss: 3.0416 - val_out_aspect_accuracy: 0.5621 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8237 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7399 - val_out_packaging_and_delivery_accuracy: 0.8613 - val_out_price_and_preference_accuracy: 0.9465 - val_out_quality_and_appearance_accuracy: 0.7934
# Epoch 18/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - loss: 2.0790 - out_aspect_accuracy: 0.6528 - out_author_accuracy: 0.9550 - out_content_related_accuracy: 0.9066 - out_customer_service_accuracy: 0.9707 - out_manufacture_and_distribution_accuracy: 0.9897 - out_overall_experience_accuracy: 0.7883 - out_packaging_and_delivery_accuracy: 0.9176 - out_price_and_preference_accuracy: 0.9630 - out_quality_and_appearance_accuracy: 0.8521 - val_loss: 2.9951 - val_out_aspect_accuracy: 0.5795 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8208 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7486 - val_out_packaging_and_delivery_accuracy: 0.8642 - val_out_price_and_preference_accuracy: 0.9465 - val_out_quality_and_appearance_accuracy: 0.8020
# Epoch 19/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 2.0065 - out_aspect_accuracy: 0.6594 - out_author_accuracy: 0.9558 - out_content_related_accuracy: 0.9057 - out_customer_service_accuracy: 0.9722 - out_manufacture_and_distribution_accuracy: 0.9866 - out_overall_experience_accuracy: 0.7996 - out_packaging_and_delivery_accuracy: 0.9276 - out_price_and_preference_accuracy: 0.9648 - out_quality_and_appearance_accuracy: 0.8799 - val_loss: 3.1294 - val_out_aspect_accuracy: 0.5535 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7977 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7428 - val_out_packaging_and_delivery_accuracy: 0.8613 - val_out_price_and_preference_accuracy: 0.9436 - val_out_quality_and_appearance_accuracy: 0.8064
# Epoch 20/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 1.8394 - out_aspect_accuracy: 0.6692 - out_author_accuracy: 0.9554 - out_content_related_accuracy: 0.9188 - out_customer_service_accuracy: 0.9743 - out_manufacture_and_distribution_accuracy: 0.9891 - out_overall_experience_accuracy: 0.8160 - out_packaging_and_delivery_accuracy: 0.9244 - out_price_and_preference_accuracy: 0.9664 - out_quality_and_appearance_accuracy: 0.8931 - val_loss: 3.1335 - val_out_aspect_accuracy: 0.5751 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8150 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7514 - val_out_packaging_and_delivery_accuracy: 0.8598 - val_out_price_and_preference_accuracy: 0.9451 - val_out_quality_and_appearance_accuracy: 0.7991
# Epoch 21/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - loss: 1.8324 - out_aspect_accuracy: 0.6758 - out_author_accuracy: 0.9529 - out_content_related_accuracy: 0.9144 - out_customer_service_accuracy: 0.9745 - out_manufacture_and_distribution_accuracy: 0.9883 - out_overall_experience_accuracy: 0.8187 - out_packaging_and_delivery_accuracy: 0.9292 - out_price_and_preference_accuracy: 0.9657 - out_quality_and_appearance_accuracy: 0.8971 - val_loss: 3.1854 - val_out_aspect_accuracy: 0.6012 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8194 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7558 - val_out_packaging_and_delivery_accuracy: 0.8656 - val_out_price_and_preference_accuracy: 0.9494 - val_out_quality_and_appearance_accuracy: 0.7962
# Epoch 21: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(padded_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step

# %%
pred_aspect_test = round(pd.DataFrame(pred_test[0]), 0)
aspect_true = label_aspect_test.flatten()
aspect_predict = pred_aspect_test.values.flatten()

weighted_f1_aspect = f1_score(aspect_true, aspect_predict, average='weighted')
print(f'Weighted F1 Score for aspect detection: {weighted_f1_aspect}')
# Out:
# Weighted F1 Score for aspect detection: 0.8958719185060834

# %%
pred_content_related_test = np.where(np.argmax(pred_test[1], axis=1)==3, -1, np.argmax(pred_test[1], axis=1))
pred_author_test = np.where(np.argmax(pred_test[2], axis=1)==3, -1, np.argmax(pred_test[2], axis=1))
pred_quality_and_appearance_test = np.where(np.argmax(pred_test[3], axis=1)==3, -1, np.argmax(pred_test[3], axis=1))
pred_manufacture_and_distribution_test = np.where(np.argmax(pred_test[4], axis=1)==3, -1, np.argmax(pred_test[4], axis=1))
pred_packaging_and_delivery_test = np.where(np.argmax(pred_test[5], axis=1)==3, -1, np.argmax(pred_test[5], axis=1))
pred_price_and_preference_test = np.where(np.argmax(pred_test[6], axis=1)==3, -1, np.argmax(pred_test[6], axis=1))
pred_customer_service_test = np.where(np.argmax(pred_test[7], axis=1)==3, -1, np.argmax(pred_test[7], axis=1))
pred_overall_experience_test = np.where(np.argmax(pred_test[8], axis=1)==3, -1, np.argmax(pred_test[8], axis=1))

predict_test = pd.DataFrame({
    'content_related': pred_content_related_test,
    'author': pred_author_test,
    'quality_and_appearance': pred_quality_and_appearance_test,
    'manufacture_and_distribution': pred_manufacture_and_distribution_test,
    'packaging_and_delivery': pred_packaging_and_delivery_test,
    'price_and_preference': pred_price_and_preference_test,
    'customer_service': pred_customer_service_test,
    'overall_experience': pred_overall_experience_test
})

sentiment_true = df_test.iloc[:, 1:].values.flatten()
sentiment_predict = predict_test.values.flatten()

weighted_f1_sentiment = f1_score(sentiment_true, sentiment_predict, average='weighted')
print(f'Weighted F1 Score for sentiment classification: {weighted_f1_sentiment}')
# Out:
# Weighted F1 Score for sentiment classification: 0.877344441482388

# %%
df_true = pd.DataFrame(label_aspect_test, columns=['content_related', 'author', 'quality_and_appearance', 'manufacture_and_distribution', 'packaging_and_delivery', 'price_and_preference', 'customer_service', 'overall_experience'])
df_pred = pd.DataFrame(pred_aspect_test.values, columns=['content_related', 'author', 'quality_and_appearance', 'manufacture_and_distribution', 'packaging_and_delivery', 'price_and_preference', 'customer_service', 'overall_experience'])

for aspect in ['content_related', 'author', 'quality_and_appearance', 'manufacture_and_distribution', 'packaging_and_delivery', 'price_and_preference', 'customer_service', 'overall_experience']:
    print(f'Classification report for aspect: {aspect}\n')
    print(classification_report(df_true[aspect], df_pred[aspect], digits=5))
    print()
# Out:
# Classification report for aspect: content_related
#
#               precision    recall  f1-score   support
#
#            0    0.88170   0.87196   0.87680       453
#            1    0.76230   0.77824   0.77019       239
#
#     accuracy                        0.83960       692
#    macro avg    0.82200   0.82510   0.82349       692
# weighted avg    0.84046   0.83960   0.83998       692
#
#
# Classification report for aspect: author
#
#               precision    recall  f1-score   support
#
#            0    0.96243   1.00000   0.98085       666
#            1    0.00000   0.00000   0.00000        26
#
#     accuracy                        0.96243       692
#    macro avg    0.48121   0.50000   0.49043       692
# weighted avg    0.92627   0.96243   0.94400       692
#
#
# Classification report for aspect: quality_and_appearance
#
#               precision    recall  f1-score   support
#
#            0    0.85211   0.78827   0.81895       307
#            1    0.84069   0.89091   0.86507       385
#
#     accuracy                        0.84538       692
#    macro avg    0.84640   0.83959   0.84201       692
# weighted avg    0.84576   0.84538   0.84461       692
#
#
# Classification report for aspect: manufacture_and_distribution
#
#               precision    recall  f1-score   support
#
#            0    0.97977   1.00000   0.98978       678
#            1    0.00000   0.00000   0.00000        14
#
#     accuracy                        0.97977       692
#    macro avg    0.48988   0.50000   0.49489       692
# weighted avg    0.95995   0.97977   0.96976       692
#
#
# Classification report for aspect: packaging_and_delivery
#
#               precision    recall  f1-score   support
#
#            0    0.93466   0.88679   0.91010       371
#            1    0.87647   0.92835   0.90166       321
#
#     accuracy                        0.90607       692
#    macro avg    0.90556   0.90757   0.90588       692
# weighted avg    0.90767   0.90607   0.90619       692
#
#
# Classification report for aspect: price_and_preference
#
#               precision    recall  f1-score   support
#
#            0    0.94954   0.98571   0.96729       630
#            1    0.76316   0.46774   0.58000        62
#
#     accuracy                        0.93931       692
#    macro avg    0.85635   0.72673   0.77364       692
# weighted avg    0.93284   0.93931   0.93259       692
#
#
# Classification report for aspect: customer_service
#
#               precision    recall  f1-score   support
#
#            0    0.97110   1.00000   0.98534       672
#            1    0.00000   0.00000   0.00000        20
#
#     accuracy                        0.97110       692
#    macro avg    0.48555   0.50000   0.49267       692
# weighted avg    0.94303   0.97110   0.95686       692
#
#
# Classification report for aspect: overall_experience
#
#               precision    recall  f1-score   support
#
#            0    0.78114   0.87976   0.82752       499
#            1    0.53846   0.36269   0.43344       193
#
#     accuracy                        0.73555       692
#    macro avg    0.65980   0.62123   0.63048       692
# weighted avg    0.71346   0.73555   0.71761       692

# %%
df_true = df_test.iloc[:, 1:]
df_pred = predict_test

for aspect in ['content_related', 'author', 'quality_and_appearance', 'manufacture_and_distribution', 'packaging_and_delivery', 'price_and_preference', 'customer_service', 'overall_experience']:
    print(f'Classification report for aspect: {aspect}\n')
    print(classification_report(df_true[aspect], df_pred[aspect], digits=5))
    print()
# Out:
# Classification report for aspect: content_related
#
#               precision    recall  f1-score   support
#
#           -1    0.00000   0.00000   0.00000         0
#            0    0.87609   0.88962   0.88280       453
#            1    0.68020   0.74860   0.71277       179
#            2    0.50000   0.42500   0.45946        40
#            3    0.00000   0.00000   0.00000        20
#
#     accuracy                        0.80058       692
#    macro avg    0.41126   0.41265   0.41101       692
# weighted avg    0.77836   0.80058   0.78883       692
#
#
# Classification report for aspect: author
#
#               precision    recall  f1-score   support
#
#            0    0.96243   1.00000   0.98085       666
#            1    0.00000   0.00000   0.00000        19
#            2    0.00000   0.00000   0.00000         6
#            3    0.00000   0.00000   0.00000         1
#
#     accuracy                        0.96243       692
#    macro avg    0.24061   0.25000   0.24521       692
# weighted avg    0.92627   0.96243   0.94400       692
#
#
# Classification report for aspect: quality_and_appearance
#
#               precision    recall  f1-score   support
#
#            0    0.84483   0.79805   0.82077       307
#            1    0.71264   0.85714   0.77824       217
#            2    0.81560   0.70122   0.75410       164
#            3    0.00000   0.00000   0.00000         4
#
#     accuracy                        0.78902       692
#    macro avg    0.59327   0.58910   0.58828       692
# weighted avg    0.79157   0.78902   0.78689       692
#
#
# Classification report for aspect: manufacture_and_distribution
#
#               precision    recall  f1-score   support
#
#            0    0.97977   1.00000   0.98978       678
#            1    0.00000   0.00000   0.00000        12
#            2    0.00000   0.00000   0.00000         2
#
#     accuracy                        0.97977       692
#    macro avg    0.32659   0.33333   0.32993       692
# weighted avg    0.95995   0.97977   0.96976       692
#
#
# Classification report for aspect: packaging_and_delivery
#
#               precision    recall  f1-score   support
#
#            0    0.91803   0.90566   0.91180       371
#            1    0.86512   0.88152   0.87324       211
#            2    0.71171   0.72477   0.71818       109
#            3    0.00000   0.00000   0.00000         1
#
#     accuracy                        0.86850       692
#    macro avg    0.62372   0.62799   0.62581       692
# weighted avg    0.86807   0.86850   0.86823       692
#
#
# Classification report for aspect: price_and_preference
#
#               precision    recall  f1-score   support
#
#            0    0.95518   0.98095   0.96789       630
#            1    0.70455   0.62000   0.65957        50
#            2    0.00000   0.00000   0.00000        11
#            3    0.00000   0.00000   0.00000         1
#
#     accuracy                        0.93786       692
#    macro avg    0.41493   0.40024   0.40687       692
# weighted avg    0.92050   0.93786   0.92883       692
#
#
# Classification report for aspect: customer_service
#
#               precision    recall  f1-score   support
#
#            0    0.97250   1.00000   0.98606       672
#            1    0.00000   0.00000   0.00000         7
#            2    0.00000   0.00000   0.00000        12
#            3    0.00000   0.00000   0.00000         1
#
#     accuracy                        0.97110       692
#    macro avg    0.24313   0.25000   0.24652       692
# weighted avg    0.94440   0.97110   0.95756       692
#
#
# Classification report for aspect: overall_experience
#
#               precision    recall  f1-score   support
#
#            0    0.78731   0.91984   0.84843       499
#            1    0.60417   0.38158   0.46774       152
#            2    0.38462   0.14286   0.20833        35
#            3    0.00000   0.00000   0.00000         6
#
#     accuracy                        0.75434       692
#    macro avg    0.44402   0.36107   0.38113       692
# weighted avg    0.71989   0.75434   0.72508       692

# %%
del model

# %% [markdown]
# ## BiLSTM + BiGRU + Conv1D

# %%
with device:

    # Number of labels
    num_label = 8

    # Input layer
    inputs = Input(shape=(MAX_LENGTH,))

    # Embedding layer
    embed = Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        embeddings_initializer=Constant(embedding_matrix),
        trainable=True
    )(inputs)
    
    dropout1 = SpatialDropout1D(0.2)(embed)

    lstm = Bidirectional(LSTM(units = 200, activation = 'tanh', return_sequences = True))(dropout1)
    conv_lstm = Conv1D(128, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(lstm)

    gru = Bidirectional(GRU(units = 200, activation = 'tanh', return_sequences = True))(dropout1)
    conv_gru = Conv1D(128, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(gru)


    avg_pool1 = GlobalAveragePooling1D()(conv_lstm)
    max_pool1 = GlobalMaxPooling1D()(conv_lstm)

    avg_pool2 = GlobalAveragePooling1D()(conv_gru)
    max_pool2 = GlobalMaxPooling1D()(conv_gru)


    concat = Concatenate(axis=-1)([avg_pool1, max_pool1, avg_pool2, max_pool2])
    dense1 = Dense(units = 256, activation = 'relu')(concat)
    dense2 = Dense(units = 128, activation = 'relu')(dense1)
    dropout1 = Dropout(rate = 0.2)(dense2)
    dense3 = Dense(units = 64, activation = 'relu')(dropout1)
    dense4 = Dense(units = 32, activation = 'relu')(dense3)
    
    # Output layers
    out_aspect = Dense(units=num_label, activation='sigmoid', name='out_aspect')(dense4)

    # Helper function to concatenate aspect and dense4 output
    def create_output_layer(aspect_index, name):
        aspect_slice = out_aspect[:, aspect_index:aspect_index + 1]
        concatenated = tf.keras.layers.Concatenate(axis=1)([aspect_slice, dense4])
        output_layer = Dense(units=4, activation='softmax', name=name)(concatenated)
        return output_layer

    out_content_related = create_output_layer(0, 'out_content_related')
    out_author = create_output_layer(1, 'out_author')
    out_quality_and_appearance = create_output_layer(2, 'out_quality_and_appearance')
    out_manufacture_and_distribution = create_output_layer(3, 'out_manufacture_and_distribution')
    out_packaging_and_delivery = create_output_layer(4, 'out_packaging_and_delivery')
    out_price_and_preference = create_output_layer(5, 'out_price_and_preference')
    out_customer_service = create_output_layer(6, 'out_customer_service')
    out_overall_experience = create_output_layer(7, 'out_overall_experience')

    # Define the model
    model = Model(
        inputs=inputs,
        outputs=[
            out_aspect, out_content_related, out_author, out_quality_and_appearance,
            out_manufacture_and_distribution, out_packaging_and_delivery,
            out_price_and_preference, out_customer_service, out_overall_experience
        ]
    )
    
    losses = {
        "out_aspect": "binary_crossentropy",
        "out_content_related": "categorical_crossentropy",
        "out_author": "categorical_crossentropy",
        "out_quality_and_appearance": "categorical_crossentropy",
        "out_manufacture_and_distribution": "categorical_crossentropy",
        "out_packaging_and_delivery": "categorical_crossentropy",
        "out_price_and_preference": "categorical_crossentropy",
        "out_customer_service": "categorical_crossentropy",
        "out_overall_experience": "categorical_crossentropy"
    }
 
    metrics={
        "out_aspect": 'accuracy',
        "out_content_related": 'accuracy',
        "out_author": 'accuracy',
        "out_quality_and_appearance": 'accuracy',
        "out_manufacture_and_distribution": 'accuracy',
        "out_packaging_and_delivery": 'accuracy',
        "out_price_and_preference": 'accuracy',
        "out_customer_service": 'accuracy',
        "out_overall_experience": 'accuracy'
    }
    
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=losses,
        metrics=metrics
    )

model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 128)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_4         │ (None, 128, 1024) │ 65,537,024 │ input_layer_4[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_2 │ (None, 128, 1024) │          0 │ embedding_4[0][0] │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_4     │ (None, 128, 400)  │  1,960,000 │ spatial_dropout1… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_5     │ (None, 128, 400)  │  1,471,200 │ spatial_dropout1… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 127, 128)  │    102,528 │ bidirectional_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 127, 128)  │    102,528 │ bidirectional_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv1d_2[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ conv1d_2[0][0]    │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv1d_3[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ conv1d_3[0][0]    │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_34      │ (None, 512)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# │                     │                   │            │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 256)       │    131,328 │ concatenate_34[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 128)       │     32,896 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 64)        │      8,256 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 32)        │      2,080 │ dense_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_aspect (Dense)  │ (None, 8)         │        264 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_32         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_33         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_34         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_35         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_36         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_37         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_38         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_39         │ (None, 1)         │          0 │ out_aspect[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_35      │ (None, 33)        │          0 │ get_item_32[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_36      │ (None, 33)        │          0 │ get_item_33[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_37      │ (None, 33)        │          0 │ get_item_34[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_38      │ (None, 33)        │          0 │ get_item_35[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_39      │ (None, 33)        │          0 │ get_item_36[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_40      │ (None, 33)        │          0 │ get_item_37[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_41      │ (None, 33)        │          0 │ get_item_38[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_42      │ (None, 33)        │          0 │ get_item_39[0][0… │
# │ (Concatenate)       │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_content_related │ (None, 4)         │        136 │ concatenate_35[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_author (Dense)  │ (None, 4)         │        136 │ concatenate_36[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_quality_and_ap… │ (None, 4)         │        136 │ concatenate_37[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_manufacture_an… │ (None, 4)         │        136 │ concatenate_38[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_packaging_and_… │ (None, 4)         │        136 │ concatenate_39[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_price_and_pref… │ (None, 4)         │        136 │ concatenate_40[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_customer_servi… │ (None, 4)         │        136 │ concatenate_41[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_overall_experi… │ (None, 4)         │        136 │ concatenate_42[0… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 69,349,192 (264.55 MB)
#  Trainable params: 69,349,192 (264.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit model
history = model.fit(
    x=padded_train,
    y={
        "out_aspect": label_aspect_train,
        "out_content_related": content_related_train,
        "out_author": author_train,
        "out_quality_and_appearance": quality_and_appearance_train,
        "out_manufacture_and_distribution": manufacture_and_distribution_train,
        "out_packaging_and_delivery": packaging_and_delivery_train,
        "out_price_and_preference": price_and_preference_train,
        "out_customer_service": customer_service_train,
        "out_overall_experience": overall_experience_train
    },
    validation_data=(
        padded_val,
        {
            "out_aspect": label_aspect_val,
            "out_content_related": content_related_val,
            "out_author": author_val,
            "out_quality_and_appearance": quality_and_appearance_val,
            "out_manufacture_and_distribution": manufacture_and_distribution_val,
            "out_packaging_and_delivery": packaging_and_delivery_val,
            "out_price_and_preference": price_and_preference_val,
            "out_customer_service": customer_service_val,
            "out_overall_experience": overall_experience_val
        }
    ),
    batch_size=BATCH_SIZE,
    epochs=100,
    callbacks=EarlyStopping(
        monitor='val_loss', 
        patience=3,
        min_delta=0.001,
        mode='min',
        verbose=1
    ),
    verbose=1
)
# Out:
# Epoch 1/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - loss: 8.5512 - out_aspect_accuracy: 0.0076 - out_author_accuracy: 0.7940 - out_content_related_accuracy: 0.4864 - out_customer_service_accuracy: 0.8019 - out_manufacture_and_distribution_accuracy: 0.7756 - out_overall_experience_accuracy: 0.7035 - out_packaging_and_delivery_accuracy: 0.3236 - out_price_and_preference_accuracy: 0.8849 - out_quality_and_appearance_accuracy: 0.3008 - val_loss: 5.5133 - val_out_aspect_accuracy: 0.0101 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.4870 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4321
# Epoch 2/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - loss: 5.7156 - out_aspect_accuracy: 0.0085 - out_author_accuracy: 0.9561 - out_content_related_accuracy: 0.6682 - out_customer_service_accuracy: 0.9705 - out_manufacture_and_distribution_accuracy: 0.9881 - out_overall_experience_accuracy: 0.7125 - out_packaging_and_delivery_accuracy: 0.4641 - out_price_and_preference_accuracy: 0.9093 - out_quality_and_appearance_accuracy: 0.3956 - val_loss: 5.1521 - val_out_aspect_accuracy: 0.0101 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.4884 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.4321
# Epoch 3/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - loss: 5.2898 - out_aspect_accuracy: 0.1423 - out_author_accuracy: 0.9587 - out_content_related_accuracy: 0.6656 - out_customer_service_accuracy: 0.9698 - out_manufacture_and_distribution_accuracy: 0.9857 - out_overall_experience_accuracy: 0.7267 - out_packaging_and_delivery_accuracy: 0.5031 - out_price_and_preference_accuracy: 0.9181 - out_quality_and_appearance_accuracy: 0.4163 - val_loss: 4.5880 - val_out_aspect_accuracy: 0.3280 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.6806 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7081 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.5939
# Epoch 4/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - loss: 4.5878 - out_aspect_accuracy: 0.3424 - out_author_accuracy: 0.9593 - out_content_related_accuracy: 0.6954 - out_customer_service_accuracy: 0.9723 - out_manufacture_and_distribution_accuracy: 0.9859 - out_overall_experience_accuracy: 0.7087 - out_packaging_and_delivery_accuracy: 0.7073 - out_price_and_preference_accuracy: 0.9125 - out_quality_and_appearance_accuracy: 0.5881 - val_loss: 3.8123 - val_out_aspect_accuracy: 0.3960 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7919 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.7991 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6604
# Epoch 5/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 81ms/step - loss: 3.8685 - out_aspect_accuracy: 0.3884 - out_author_accuracy: 0.9565 - out_content_related_accuracy: 0.7676 - out_customer_service_accuracy: 0.9709 - out_manufacture_and_distribution_accuracy: 0.9900 - out_overall_experience_accuracy: 0.6993 - out_packaging_and_delivery_accuracy: 0.8264 - out_price_and_preference_accuracy: 0.9116 - out_quality_and_appearance_accuracy: 0.6730 - val_loss: 3.4847 - val_out_aspect_accuracy: 0.5549 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7890 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.8382 - val_out_price_and_preference_accuracy: 0.9162 - val_out_quality_and_appearance_accuracy: 0.6893
# Epoch 6/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - loss: 3.6043 - out_aspect_accuracy: 0.4937 - out_author_accuracy: 0.9549 - out_content_related_accuracy: 0.7705 - out_customer_service_accuracy: 0.9665 - out_manufacture_and_distribution_accuracy: 0.9865 - out_overall_experience_accuracy: 0.7060 - out_packaging_and_delivery_accuracy: 0.8438 - out_price_and_preference_accuracy: 0.9122 - out_quality_and_appearance_accuracy: 0.7204 - val_loss: 3.3435 - val_out_aspect_accuracy: 0.5968 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7702 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7370 - val_out_packaging_and_delivery_accuracy: 0.8483 - val_out_price_and_preference_accuracy: 0.9205 - val_out_quality_and_appearance_accuracy: 0.7298
# Epoch 7/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - loss: 3.2751 - out_aspect_accuracy: 0.5764 - out_author_accuracy: 0.9604 - out_content_related_accuracy: 0.7974 - out_customer_service_accuracy: 0.9664 - out_manufacture_and_distribution_accuracy: 0.9859 - out_overall_experience_accuracy: 0.7077 - out_packaging_and_delivery_accuracy: 0.8735 - out_price_and_preference_accuracy: 0.9197 - out_quality_and_appearance_accuracy: 0.7492 - val_loss: 3.1955 - val_out_aspect_accuracy: 0.5997 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7847 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.8497 - val_out_price_and_preference_accuracy: 0.9335 - val_out_quality_and_appearance_accuracy: 0.7543
# Epoch 8/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - loss: 3.0757 - out_aspect_accuracy: 0.5881 - out_author_accuracy: 0.9565 - out_content_related_accuracy: 0.7927 - out_customer_service_accuracy: 0.9683 - out_manufacture_and_distribution_accuracy: 0.9882 - out_overall_experience_accuracy: 0.7063 - out_packaging_and_delivery_accuracy: 0.8868 - out_price_and_preference_accuracy: 0.9274 - out_quality_and_appearance_accuracy: 0.7721 - val_loss: 3.0983 - val_out_aspect_accuracy: 0.6040 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.7832 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7471 - val_out_packaging_and_delivery_accuracy: 0.8569 - val_out_price_and_preference_accuracy: 0.9249 - val_out_quality_and_appearance_accuracy: 0.7717
# Epoch 9/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - loss: 2.8740 - out_aspect_accuracy: 0.5976 - out_author_accuracy: 0.9482 - out_content_related_accuracy: 0.8114 - out_customer_service_accuracy: 0.9727 - out_manufacture_and_distribution_accuracy: 0.9869 - out_overall_experience_accuracy: 0.7214 - out_packaging_and_delivery_accuracy: 0.8939 - out_price_and_preference_accuracy: 0.9198 - out_quality_and_appearance_accuracy: 0.8064 - val_loss: 3.0116 - val_out_aspect_accuracy: 0.6185 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8107 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7355 - val_out_packaging_and_delivery_accuracy: 0.8656 - val_out_price_and_preference_accuracy: 0.9321 - val_out_quality_and_appearance_accuracy: 0.7861
# Epoch 10/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - loss: 2.6500 - out_aspect_accuracy: 0.6362 - out_author_accuracy: 0.9564 - out_content_related_accuracy: 0.8380 - out_customer_service_accuracy: 0.9712 - out_manufacture_and_distribution_accuracy: 0.9869 - out_overall_experience_accuracy: 0.7273 - out_packaging_and_delivery_accuracy: 0.8968 - out_price_and_preference_accuracy: 0.9275 - out_quality_and_appearance_accuracy: 0.8335 - val_loss: 3.0029 - val_out_aspect_accuracy: 0.6358 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8194 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7413 - val_out_packaging_and_delivery_accuracy: 0.8555 - val_out_price_and_preference_accuracy: 0.9364 - val_out_quality_and_appearance_accuracy: 0.7818
# Epoch 11/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - loss: 2.4189 - out_aspect_accuracy: 0.6416 - out_author_accuracy: 0.9630 - out_content_related_accuracy: 0.8511 - out_customer_service_accuracy: 0.9736 - out_manufacture_and_distribution_accuracy: 0.9874 - out_overall_experience_accuracy: 0.7527 - out_packaging_and_delivery_accuracy: 0.9178 - out_price_and_preference_accuracy: 0.9381 - out_quality_and_appearance_accuracy: 0.8425 - val_loss: 3.0230 - val_out_aspect_accuracy: 0.5997 - val_out_author_accuracy: 0.9552 - val_out_content_related_accuracy: 0.8194 - val_out_customer_service_accuracy: 0.9725 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7370 - val_out_packaging_and_delivery_accuracy: 0.8569 - val_out_price_and_preference_accuracy: 0.9350 - val_out_quality_and_appearance_accuracy: 0.7876
# Epoch 12/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 81ms/step - loss: 2.3644 - out_aspect_accuracy: 0.6229 - out_author_accuracy: 0.9558 - out_content_related_accuracy: 0.8525 - out_customer_service_accuracy: 0.9734 - out_manufacture_and_distribution_accuracy: 0.9877 - out_overall_experience_accuracy: 0.7634 - out_packaging_and_delivery_accuracy: 0.9213 - out_price_and_preference_accuracy: 0.9394 - out_quality_and_appearance_accuracy: 0.8540 - val_loss: 3.0446 - val_out_aspect_accuracy: 0.6272 - val_out_author_accuracy: 0.9523 - val_out_content_related_accuracy: 0.8266 - val_out_customer_service_accuracy: 0.9740 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7457 - val_out_packaging_and_delivery_accuracy: 0.8526 - val_out_price_and_preference_accuracy: 0.9408 - val_out_quality_and_appearance_accuracy: 0.8006
# Epoch 13/100
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 81ms/step - loss: 2.2221 - out_aspect_accuracy: 0.6552 - out_author_accuracy: 0.9556 - out_content_related_accuracy: 0.8646 - out_customer_service_accuracy: 0.9711 - out_manufacture_and_distribution_accuracy: 0.9869 - out_overall_experience_accuracy: 0.7738 - out_packaging_and_delivery_accuracy: 0.9192 - out_price_and_preference_accuracy: 0.9458 - out_quality_and_appearance_accuracy: 0.8630 - val_loss: 3.0820 - val_out_aspect_accuracy: 0.6156 - val_out_author_accuracy: 0.9538 - val_out_content_related_accuracy: 0.8295 - val_out_customer_service_accuracy: 0.9740 - val_out_manufacture_and_distribution_accuracy: 0.9957 - val_out_overall_experience_accuracy: 0.7384 - val_out_packaging_and_delivery_accuracy: 0.8656 - val_out_price_and_preference_accuracy: 0.9422 - val_out_quality_and_appearance_accuracy: 0.8035
# Epoch 13: early stopping

# %% [markdown]
# ### Evaluation

# %%
pred_test = model.predict(padded_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step

# %%
pred_aspect_test = round(pd.DataFrame(pred_test[0]), 0)
aspect_true = label_aspect_test.flatten()
aspect_predict = pred_aspect_test.values.flatten()

weighted_f1_aspect = f1_score(aspect_true, aspect_predict, average='weighted')
print(f'Weighted F1 Score for aspect detection: {weighted_f1_aspect}')
# Out:
# Weighted F1 Score for aspect detection: 0.8874597759407614

# %%
pred_content_related_test = np.where(np.argmax(pred_test[1], axis=1)==3, -1, np.argmax(pred_test[1], axis=1))
pred_author_test = np.where(np.argmax(pred_test[2], axis=1)==3, -1, np.argmax(pred_test[2], axis=1))
pred_quality_and_appearance_test = np.where(np.argmax(pred_test[3], axis=1)==3, -1, np.argmax(pred_test[3], axis=1))
pred_manufacture_and_distribution_test = np.where(np.argmax(pred_test[4], axis=1)==3, -1, np.argmax(pred_test[4], axis=1))
pred_packaging_and_delivery_test = np.where(np.argmax(pred_test[5], axis=1)==3, -1, np.argmax(pred_test[5], axis=1))
pred_price_and_preference_test = np.where(np.argmax(pred_test[6], axis=1)==3, -1, np.argmax(pred_test[6], axis=1))
pred_customer_service_test = np.where(np.argmax(pred_test[7], axis=1)==3, -1, np.argmax(pred_test[7], axis=1))
pred_overall_experience_test = np.where(np.argmax(pred_test[8], axis=1)==3, -1, np.argmax(pred_test[8], axis=1))

predict_test = pd.DataFrame({
    'content_related': pred_content_related_test,
    'author': pred_author_test,
    'quality_and_appearance': pred_quality_and_appearance_test,
    'manufacture_and_distribution': pred_manufacture_and_distribution_test,
    'packaging_and_delivery': pred_packaging_and_delivery_test,
    'price_and_preference': pred_price_and_preference_test,
    'customer_service': pred_customer_service_test,
    'overall_experience': pred_overall_experience_test
})

sentiment_true = df_test.iloc[:, 1:].values.flatten()
sentiment_predict = predict_test.values.flatten()

weighted_f1_sentiment = f1_score(sentiment_true, sentiment_predict, average='weighted')
print(f'Weighted F1 Score for sentiment classification: {weighted_f1_sentiment}')
# Out:
# Weighted F1 Score for sentiment classification: 0.8740874757156175

# %%
del model
